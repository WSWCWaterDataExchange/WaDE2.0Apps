# %%
import requests
import json

import numpy as np
import pandas as pd

# %%
# URL
url = "https://wade-api-uat.azure-api.net/v1/SiteVariableAmounts?SiteUUID=UTssps_S5239&key=38f422d1ada34907a91aff4532fa4669"
rD = json.loads(requests.get(url).text)
print(type(rD))
rD
# Out:
# <class 'dict'>
# {'TotalSiteVariableAmountsCount': 194,
#  'Organizations': [{'OrganizationName': 'Utah Division of Water Rights',
#    'OrganizationPurview': 'The Utah Division of Water Rights (UDWRi) publishes its water right data on-demand.',
#    'OrganizationWebsite': 'https://waterrights.utah.gov/',
#    'OrganizationPhoneNumber': '801-538-7240',
#    'OrganizationContactName': 'James Greer',
#    'OrganizationContactEmail': 'waterrights@utah.gov',
#    'OrganizationState': 'UT',
#    'WaterSources': [{'WaterSourceName': 'Unspecified',
#      'WaterSourceNativeID': 'WaDEUT_WS1',
#      'WaterSourceUUID': 'UTssps_WS1',
#      'WaterSourceTypeCV': 'Unspecified',
#      'FreshSalineIndicatorCV': 'Fresh',
#      'WaterSourceGeometry': None}],
#    'VariableSpecifics': [{'VariableSpecificTypeCV': 'Delivered Water Use_Annual_Domestic_Unspecified',
#      'VariableCV': 'Delivered Water Use',
#      'AmountUnitCV': 'G',
#      'AggregationStatisticCV': 'Cumulative',
# ...

# %%
rDL = rD['Organizations']
print(type(rDL))
rDL
# Out:
# <class 'list'>
# [{'OrganizationName': 'Utah Division of Water Rights',
#   'OrganizationPurview': 'The Utah Division of Water Rights (UDWRi) publishes its water right data on-demand.',
#   'OrganizationWebsite': 'https://waterrights.utah.gov/',
#   'OrganizationPhoneNumber': '801-538-7240',
#   'OrganizationContactName': 'James Greer',
#   'OrganizationContactEmail': 'waterrights@utah.gov',
#   'OrganizationState': 'UT',
#   'WaterSources': [{'WaterSourceName': 'Unspecified',
#     'WaterSourceNativeID': 'WaDEUT_WS1',
#     'WaterSourceUUID': 'UTssps_WS1',
#     'WaterSourceTypeCV': 'Unspecified',
#     'FreshSalineIndicatorCV': 'Fresh',
#     'WaterSourceGeometry': None}],
#   'VariableSpecifics': [{'VariableSpecificTypeCV': 'Delivered Water Use_Annual_Domestic_Unspecified',
#     'VariableCV': 'Delivered Water Use',
#     'AmountUnitCV': 'G',
#     'AggregationStatisticCV': 'Cumulative',
#     'AggregationInterval': '1.0',
#     'AggregationIntervalUnitCV': 'Year',
# ...

# %%
rDLD = rDL[0]
print(type(rDLD))
rDLD
# Out:
# <class 'dict'>
# {'OrganizationName': 'Utah Division of Water Rights',
#  'OrganizationPurview': 'The Utah Division of Water Rights (UDWRi) publishes its water right data on-demand.',
#  'OrganizationWebsite': 'https://waterrights.utah.gov/',
#  'OrganizationPhoneNumber': '801-538-7240',
#  'OrganizationContactName': 'James Greer',
#  'OrganizationContactEmail': 'waterrights@utah.gov',
#  'OrganizationState': 'UT',
#  'WaterSources': [{'WaterSourceName': 'Unspecified',
#    'WaterSourceNativeID': 'WaDEUT_WS3',
#    'WaterSourceUUID': 'UTssps_WS3',
#    'WaterSourceTypeCV': 'Groundwater',
#    'FreshSalineIndicatorCV': 'Fresh',
#    'WaterSourceGeometry': None}],
#  'VariableSpecifics': [{'VariableSpecificTypeCV': 'Withdrawal_Annual_DCII_Groundwater',
#    'VariableCV': 'Withdrawal',
#    'AmountUnitCV': 'G',
#    'AggregationStatisticCV': 'Cumulative',
#    'AggregationInterval': '1.0',
#    'AggregationIntervalUnitCV': 'Year',
#    'ReportYearStartMonth': '1',
# ...

# %%
rDLD_OrganizationName = rDLD['OrganizationName']
print(type(rDLD_OrganizationName))
rDLD_OrganizationName
# Out:
# <class 'str'>
# 'Utah Division of Water Rights'

# %%
rD['Organizations'][0]['OrganizationName']
# Out:
# 'Utah Division of Water Rights'
