# %% [markdown]
# # Creating 2 Tables: Sites for Map, Allocations for Table

# %% [markdown]
# #### General Approach:
# 1) Read in csv sheet of data.  Export fields into new database.
# 2) Remove bad rows and elements.
# 3) Fix date datatype.
# 4) Include ID int value for beneficial use.
# 5) Fix and remove misisng or nan values for allocatoin flow and volume.
# 6) Remove duplicates based on AllocationNativeID.
# 7) Create API link for each siteUUID.
# 8) Export completed df as processed csv.
#
#
#
# #### Files Needed
# 1) dontopen_SiteLJAllow.csv,
# 2) dontopen_AlloLFSite.csv

# %% [markdown]
# ### Sites LF Allow, for creating Site Points, Popups and Legend Colors on Map Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Sites LeftJoin Allo Input
SitefileInput = "dontopen_SiteLJAllow.csv"
dfsite = pd.read_csv(SitefileInput)
dfsite
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5,10,11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           SiteID  SiteUUID   Longitude   Latitude  AllocationAmountID  \
# 0        5987443      CA_1 -124.100000  40.963100           3582161.0
# 1        5987444     CA_10 -121.173807  39.875367           3583769.0
# 2        5987445   CA_1000 -122.716594  41.730083           3587847.0
# 3        5987446  CA_10000 -120.647606  40.636866           3594308.0
# 4        5987447  CA_10001 -120.895545  38.450445           3594345.0
# ...          ...       ...         ...        ...                 ...
# 1252357  5768281   WA_9995 -120.162283  46.016114           3384138.0
# 1252358  5768282   WA_9996 -120.162290  46.019457           3383038.0
# 1252359  5768283   WA_9997 -120.122189  46.021328           3395072.0
# 1252360  5768284   WA_9998 -120.122641  46.006227           3393054.0
# 1252361  5768285   WA_9999 -120.130926  46.008851           3380697.0
#
#         AllocationNativeID  AllocationAmount  AllocationMaximum  \
# 0                  A010767               NaN                0.0
# 1                  A014760               NaN                0.0
# 2                  A021986               NaN                0.0
# 3                  C000897               NaN                0.0
# 4                  C000934               NaN                0.0
# ...                    ...               ...                ...
# 1252357        2.05850e+06          0.000000             -999.0
# 1252358        2.05594e+06          0.011140                1.0
# 1252359        2.08828e+06          0.020000                0.2
# 1252360        2.07502e+06          0.015596                2.0
# 1252361        2.05128e+06          0.000000             -999.0
#
#          IrrigatedAcreage  AllocationPriorityDateID PrimaryUseCategoryCV  \
# 0                     0.0                   33567.0           Irrigation
# 1                     0.0                   22293.0           Irrigation
# 2                     0.0                    2282.0           Irrigation
# 3                     0.0                   11225.0           Irrigation
# 4                     0.0                   10198.0           Irrigation
# ...                   ...                       ...                  ...
# 1252357            -999.0                   12754.0           Irrigation
# 1252358            -999.0                    7776.0           Irrigation
# 1252359               0.0                    5707.0           Irrigation
# 1252360            -999.0                   20339.0           Irrigation
# 1252361            -999.0                    1425.0           Irrigation
#
#         AllocationLegalStatusCV AllocationTypeCV        BeneficialUseCV  \
# 0                      Licensed    Appropriative               Domestic
# 1                      Licensed    Appropriative               Domestic
# 2                      Licensed    Appropriative               Domestic
# 3                     Certified        Stockpond          Stockwatering
# 4                     Certified        Stockpond          Stockwatering
# ...                         ...              ...                    ...
# 1252357                  Active            Claim            Stock water
# 1252358                  Active            Claim            Stock water
# 1252359                  Active            Claim            Stock water
# 1252360                  Active            Claim       Domestic general
# 1252361                  Active            Claim  No Purpose Identified
#
#                Date  WaterSourceID WaterSourceName  OrganizationID  \
# 0        1944-02-14       546831.0            UNSP            17.0
# 1        1952-04-17       546831.0            UNSP            17.0
# 2        1964-12-01       546829.0        UNSP (2)            17.0
# 3        1977-09-07       546844.0            UNST            17.0
# 4        1977-09-21       546844.0            UNST            17.0
# ...             ...            ...             ...             ...
# 1252357  1974-04-29       462900.0     Unspecified            11.0
# 1252358  1946-10-01       462900.0     Unspecified            11.0
# 1252359  1913-01-01       462901.0     Unspecified            11.0
# 1252360  1947-12-01       462900.0     Unspecified            11.0
# 1252361  1974-06-01       462900.0     Unspecified            11.0
#
#         OrganizationUUID State
# 0                 CSWRCB    CA
# 1                 CSWRCB    CA
# 2                 CSWRCB    CA
# 3                 CSWRCB    CA
# 4                 CSWRCB    CA
# ...                  ...   ...
# 1252357             WSDE    WA
# 1252358             WSDE    WA
# 1252359             WSDE    WA
# 1252360             WSDE    WA
# 1252361             WSDE    WA
#
# [1252362 rows x 20 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfsite = dfsite[(dfsite.WaterSourceName != 'test')]
dfsite = dfsite[dfsite['SiteUUID'].notna()]
dfsite = dfsite[dfsite['AllocationPriorityDateID'].notna()]
dfsite = dfsite[dfsite['BeneficialUseCV'].notna()]
dfsite = dfsite[dfsite['Longitude'].notna()]
dfsite = dfsite[dfsite['Latitude'].notna()]
dfsite.reset_index()
# Out:
#           index   SiteID  SiteUUID   Longitude   Latitude  AllocationAmountID  \
# 0             0  5987443      CA_1 -124.100000  40.963100           3582161.0
# 1             1  5987444     CA_10 -121.173807  39.875367           3583769.0
# 2             2  5987445   CA_1000 -122.716594  41.730083           3587847.0
# 3             3  5987446  CA_10000 -120.647606  40.636866           3594308.0
# 4             4  5987447  CA_10001 -120.895545  38.450445           3594345.0
# ...         ...      ...       ...         ...        ...                 ...
# 939206  1252357  5768281   WA_9995 -120.162283  46.016114           3384138.0
# 939207  1252358  5768282   WA_9996 -120.162290  46.019457           3383038.0
# 939208  1252359  5768283   WA_9997 -120.122189  46.021328           3395072.0
# 939209  1252360  5768284   WA_9998 -120.122641  46.006227           3393054.0
# 939210  1252361  5768285   WA_9999 -120.130926  46.008851           3380697.0
#
#        AllocationNativeID  AllocationAmount  AllocationMaximum  \
# 0                 A010767               NaN                0.0
# 1                 A014760               NaN                0.0
# 2                 A021986               NaN                0.0
# 3                 C000897               NaN                0.0
# 4                 C000934               NaN                0.0
# ...                   ...               ...                ...
# 939206        2.05850e+06          0.000000             -999.0
# 939207        2.05594e+06          0.011140                1.0
# 939208        2.08828e+06          0.020000                0.2
# 939209        2.07502e+06          0.015596                2.0
# 939210        2.05128e+06          0.000000             -999.0
#
#         IrrigatedAcreage  ...  PrimaryUseCategoryCV AllocationLegalStatusCV  \
# 0                    0.0  ...            Irrigation                Licensed
# 1                    0.0  ...            Irrigation                Licensed
# 2                    0.0  ...            Irrigation                Licensed
# 3                    0.0  ...            Irrigation               Certified
# 4                    0.0  ...            Irrigation               Certified
# ...                  ...  ...                   ...                     ...
# 939206            -999.0  ...            Irrigation                  Active
# 939207            -999.0  ...            Irrigation                  Active
# 939208               0.0  ...            Irrigation                  Active
# 939209            -999.0  ...            Irrigation                  Active
# 939210            -999.0  ...            Irrigation                  Active
#
#        AllocationTypeCV        BeneficialUseCV        Date WaterSourceID  \
# 0         Appropriative               Domestic  1944-02-14      546831.0
# 1         Appropriative               Domestic  1952-04-17      546831.0
# 2         Appropriative               Domestic  1964-12-01      546829.0
# 3             Stockpond          Stockwatering  1977-09-07      546844.0
# 4             Stockpond          Stockwatering  1977-09-21      546844.0
# ...                 ...                    ...         ...           ...
# 939206            Claim            Stock water  1974-04-29      462900.0
# 939207            Claim            Stock water  1946-10-01      462900.0
# 939208            Claim            Stock water  1913-01-01      462901.0
# 939209            Claim       Domestic general  1947-12-01      462900.0
# 939210            Claim  No Purpose Identified  1974-06-01      462900.0
#
#         WaterSourceName OrganizationID  OrganizationUUID State
# 0                  UNSP           17.0            CSWRCB    CA
# 1                  UNSP           17.0            CSWRCB    CA
# 2              UNSP (2)           17.0            CSWRCB    CA
# 3                  UNST           17.0            CSWRCB    CA
# 4                  UNST           17.0            CSWRCB    CA
# ...                 ...            ...               ...   ...
# 939206      Unspecified           11.0              WSDE    WA
# 939207      Unspecified           11.0              WSDE    WA
# 939208      Unspecified           11.0              WSDE    WA
# 939209      Unspecified           11.0              WSDE    WA
# 939210      Unspecified           11.0              WSDE    WA
#
# [939211 rows x 21 columns]

# %%
SiteWSWCBenUseDict = {
"Agricultural Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Agriculture Uses" : "Agricultural",
"Agricutural Spraying" : "Agricultural",
"Cranberry" : "Agricultural",
"Dairy" : "Agricultural",
"Dairy Barn Uses" : "Agricultural",
"Feed pen operation" : "Agricultural",
"Harvesting of Cranberries" : "Agricultural",
"Individual Irrigation" : "Agricultural",
"Irrigated agriculture_ground" : "Agricultural",
"Irrigated agriculture_reuse" : "Agricultural",
"Irrigated agriculture_surface" : "Agricultural",
"Irrigation" : "Agricultural",
"Irrigation and Domestic" : "Agricultural",
"Irrigation and Livestock" : "Agricultural",
"Irrigation Livestock and Domestic" : "Agricultural",
"Irrigation of Cranberries" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Irrigation Unknown" : "Agricultural",
"Irrigation-Carey Act" : "Agricultural",
"Irrigation-DLE" : "Agricultural",
"Livestock" : "Agricultural",
"Livestock and Wildlife" : "Agricultural",
"Livestock_ground" : "Agricultural",
"Livestock_reuse" : "Agricultural",
"Livestock_surface" : "Agricultural",
"Nursery Uses" : "Agricultural",
"Practicably Irrigable Acreage" : "Agricultural",
"Primary and Supplemental Irrigation" : "Agricultural",
"Recharge For Irrigation" : "Agricultural",
"Subirrigation" : "Agricultural",
"Supplemental Irrigation" : "Agricultural",
"Aquaculture" : "Aquaculture",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Commercial" : "Commercial",
"Commercial & indust" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"Commercial Uses" : "Commercial",
"Community type use - mdwca, private or commercial supplied" : "Commercial",
"Sale" : "Commercial",
"Shop" : "Commercial",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 multiple domestic households" : "Domestic",
"Domestic" : "Domestic",
"Domestic and Livestock" : "Domestic",
"Domestic construction" : "Domestic",
"Domestic Expanded" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic general" : "Domestic",
"Domestic Including Lawn and Garden" : "Domestic",
"Domestic multiple" : "Domestic",
"Domestic single" : "Domestic",
"Domestic Storage" : "Domestic",
"Group Domestic" : "Domestic",
"Household Use Only" : "Domestic",
"Human Consumption" : "Domestic",
"Human Consumption and Livestock" : "Domestic",
"Institutional" : "Domestic",
"Lawn And Garden" : "Domestic",
"Mobile home parks" : "Domestic",
"Multiple Domestic" : "Domestic",
"Public Supply" : "Domestic",
"Public utility" : "Domestic",
"Rural Water" : "Domestic",
"Subdivision" : "Domestic",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"Augmentation well" : "Environmental",
"Average Annual Flow" : "Environmental",
"Bankfull Flow" : "Environmental",
"Base Flow" : "Environmental",
"Brine production well" : "Environmental",
"Channel Maintenance" : "Environmental",
"Cumulative Accretion To River" : "Environmental",
"Cumulative Depletion From River" : "Environmental",
"Dust Control" : "Environmental",
"Environmental" : "Environmental",
"Environmental quality" : "Environmental",
"Erosion Control" : "Environmental",
"Evaporation" : "Environmental",
"Frost Protection" : "Environmental",
"Greenhouse" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Lake Level Maintenance" : "Environmental",
"Minimum Stream Flow" : "Environmental",
"Minimum Stream Flow From Storage" : "Environmental",
"Minimum Stream Flow Storage" : "Environmental",
"Minimum Streamflow" : "Environmental",
"Mitigation" : "Environmental",
"Net Effect On River" : "Environmental",
"Sediment Control" : "Environmental",
"Water Quality Improvement" : "Environmental",
"Water Quality Improvement From Storage" : "Environmental",
"Water Quality Improvement Storage" : "Environmental",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection (Instream)" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Anadromous and Resident Fish Habitat (Instream)" : "Fish",
"Fish and game propogation" : "Fish",
"Fish And Wildlife" : "Fish",
"Fish and Wildlife Preservation and Enhancement" : "Fish",
"Fish Culture" : "Fish",
"Fish Habitat" : "Fish",
"Fish Habitat From Storage" : "Fish",
"Fish Habitat Storage" : "Fish",
"Fish Propagation" : "Fish",
"Fish Propagation From Storage" : "Fish",
"Fish Propagation Storage" : "Fish",
"Fish Raceways" : "Fish",
"Fishery" : "Fish",
"Fishery Enhancement (Instream)" : "Fish",
"Recreation Fish Wildlife" : "Fish",
"100 Year Flood Flow" : "Flood Control",
"Flood Control" : "Flood Control",
"Flood Control Storage" : "Flood Control",
"Flow Augmentation" : "Flood Control",
"Flow Through Fish Pond" : "Flood Control",
"Mitigation By Delivery" : "Flood Control",
"Mitigation By Delivery From Storage" : "Flood Control",
"Mitigation By Delivery Storage" : "Flood Control",
"Mitigation By NonUse" : "Flood Control",
"Stream augmentation" : "Flood Control",
"Supplemental Flood Harvesting" : "Flood Control",
"Air Conditioning or Heating" : "Heating and Cooling",
"Cooling" : "Heating and Cooling",
"Cooling for indust proces" : "Heating and Cooling",
"Cooling From Storage" : "Heating and Cooling",
"Cooling Storage" : "Heating and Cooling",
"Geo-Thermal (Heating & Cooling)" : "Heating and Cooling",
"Geothermal Heating" : "Heating and Cooling",
"Geo-Thermal(Energy Production)" : "Heating and Cooling",
"Heat Control" : "Heating and Cooling",
"Heat Exchange" : "Heating and Cooling",
"Heat protection for crops" : "Heating and Cooling",
"Heating" : "Heating and Cooling",
"Heating From Storage" : "Heating and Cooling",
"Heating Storage" : "Heating and Cooling",
"Temperature Control" : "Heating and Cooling",
"72-12-1 Construction of public works" : "Industrial",
"Cemetery" : "Industrial",
"Construction" : "Industrial",
"Dairy operation" : "Industrial",
"Highway" : "Industrial",
"Highway construction" : "Industrial",
"Industrial" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Industrial/Manufacturing Uses" : "Industrial",
"Irrigation From Storage" : "Industrial",
"Log Deck Sprinkling" : "Industrial",
"Manufacturing" : "Industrial",
"Manufacturing_ground" : "Industrial",
"Manufacturing_reuse" : "Industrial",
"Manufacturing_surface" : "Industrial",
"Meat packing plant" : "Industrial",
"Milling" : "Industrial",
"Oil field maintenance" : "Industrial",
"Oil production" : "Industrial",
"Oil Well Flooding" : "Industrial",
"Petroleum processing plant" : "Industrial",
"Poultry and egg operation" : "Industrial",
"Railway" : "Industrial",
"Ram" : "Industrial",
"Road Construction" : "Industrial",
"Sawmill" : "Industrial",
"Secondary recovery of oil" : "Industrial",
"Use in a Mint Still" : "Industrial",
"Aquatic Habitat" : "Instream Flow",
"Aquatic Life Instream" : "Instream Flow",
"Instream Flow" : "Instream Flow",
"Multiple Instream Uses" : "Instream Flow",
"Pollution Abatement" : "Instream Flow",
"Pollution Abatement (Instream)" : "Instream Flow",
"Pollution control well" : "Instream Flow",
"Riparian Habitat (Instream)" : "Instream Flow",
"Riparian Habitat Restoration Project" : "Instream Flow",
"Riparian Maintenance" : "Instream Flow",
"72-12-1 livestock watering" : "Livestock",
"Stock" : "Livestock",
"Stock water" : "Livestock",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"Stockwatering" : "Livestock",
"Mining" : "Mining",
"Mining and Milling" : "Mining",
"Mining From Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Mining Storage" : "Mining",
"Mining, Milling, and Dewatering" : "Mining",
"Mining_ground" : "Mining",
"Mining_reuse" : "Mining",
"Mining_surface" : "Mining",
"Municipal" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal Storage" : "Municipal",
"Municipal Uses" : "Municipal",
"Municipal_ground" : "Municipal",
"Municipal_reuse" : "Municipal",
"Municipal_surface" : "Municipal",
"Pond Maintenance" : "Municipal",
"Quasi-Municipal" : "Municipal",
"Restroom" : "Municipal",
"School use - public, private, parochial, & universities" : "Municipal",
"Use Within a School" : "Municipal",
"508-14" : "Other",
"Administrative" : "Other",
"Aesthetic" : "Other",
"Aesthetic From Storage" : "Other",
"Aesthetic Storage" : "Other",
"Aesthetics" : "Other",
"All Beneficial Uses" : "Other",
"As Decreed" : "Other",
"Augmentation" : "Other",
"Cathodic protection well" : "Other",
"Closed file" : "Other",
"Dewatering" : "Other",
"Dewatering well" : "Other",
"Diversion To Storage" : "Other",
"Evaporative" : "Other",
"Exploration" : "Other",
"Export From Basin" : "Other",
"Export From State" : "Other",
"Federal Reserved" : "Other",
"Federal Reserved Use" : "Other",
"Forest Management" : "Other",
"Injection" : "Other",
"Laboratory" : "Other",
"Military - military installations" : "Other",
"Monitoring well" : "Other",
"Multiple Purpose" : "Other",
"Multiple Use" : "Other",
"Municipal inter-tie system" : "Other",
"Navigation" : "Other",
"No pre-1907 water right exists on this land" : "Other",
"Non 72-12-1 domestic and livestock watering" : "Other",
"Non 72-12-1 domestic one household" : "Other",
"Non 72-12-1 livestock watering" : "Other",
"Non 72-12-1 multiple domestic households" : "Other",
"Non-profit organizational use" : "Other",
"Observation" : "Other",
"Observation And Testing" : "Other",
"Other" : "Other",
"Other Purpose" : "Other",
"Quasi-Municipal Uses" : "Other",
"See Remarks" : "Other",
"Stacked water right" : "Other",
"Test Well" : "Other",
"Transmountain Export" : "Other",
"Trust water, Permanent" : "Other",
"Trust water, Temporary" : "Other",
"Geothermal" : "Power",
"Geothermal boreholes" : "Power",
"Incidental Power" : "Power",
"Power" : "Power",
"Power Development" : "Power",
"Power From Storage" : "Power",
"Power Generation" : "Power",
"Power Generation Nonconsumptive" : "Power",
"POWER GENERATION, NONCONSUMPTIVE" : "Power",
"Power Storage" : "Power",
"Steam-Electric Power_ground" : "Power",
"Steam-Electric Power_reuse" : "Power",
"Steam-Electric Power_surface" : "Power",
"Recharge" : "Recharge",
"Campsite" : "Recreation",
"Parks and Recreation" : "Recreation",
"Recreation" : "Recreation",
"Recreation - beautification" : "Recreation",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreational" : "Recreation",
"Swimming" : "Recreation",
"Snow Making" : "Snow Making",
"Groundwater Aquifer Storage & Recovery" : "Storage",
"Groundwater Preservation" : "Storage",
"Storage" : "Storage",
"Strategic water reserve" : "Storage",
"Streamflow Maintenance From Storage" : "Storage",
"Streamflow Maintenance Storage" : "Storage",
"No Purpose Identified" : "Unknown",
"No right" : "Unknown",
"No use of right or POD" : "Unknown",
"To be determined" : "Unknown",
"Unknown" : "Unknown",
"Water Fowl" : "Wildlife",
"Wild And Scenic River" : "Wildlife",
"Wildlife" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife refuge" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife Waterfowl" : "Wildlife",
"WILDLIFE/WATERFOWL" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = SiteWSWCBenUseDict[String1]
        except:
            outList = "Other"
    return outList

dfsite['WSWCBeneficialUse'] = dfsite.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#Site Map Color per point
#Mapdeck uses a build color pacakge called 'colourvalues library', which does use HEX color code, but has to end in an "FF".
WSWCBenUseColorDict = { 
"Agricultural" : "#006400FF",
"Aquaculture" : "#9ACD32FF",
"Commercial" : "#FFFF00FF",
"Domestic" : "#0000FFFF",
"Environmental" : "#32CD32FF",
"Fire" : "#FF4500FF",
"Fish" : "#9370DBFF",
"Flood Control" : "#00FFFFFF",
"Heating and Cooling" : "#FF69B4FF",
"Industrial" : "#800080FF",
"Instream Flow" : "#00BFFFFF",
"Livestock" : "#FFD700FF",
"Mining" : "#A52A2AFF",
"Municipal" : "#4B0082FF",
"Power" : "#FFA500FF",
"Recharge" : "#D2691EFF",
"Recreation" : "#FFC0CBFF",
"Snow Making" : "#F0FFF0FF",
"Storage" : "#F5DEB3FF",
"Wildlife" : "#FF0000FF",
"Other" : "#808080FF",
"Unknown" : "#D3D3D3FF"}
 
def assignWSWCBUColor(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "#D3D3D3FF"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = WSWCBenUseColorDict[String1]
        except:
            outList = "#D3D3D3FF"
    return outList

dfsite['WBenUseColor'] = dfsite.apply(lambda row: assignWSWCBUColor(row['WSWCBeneficialUse']), axis=1)

# %%
#AllowcationTypeCv
allowTypeCVDict = {
"(GRDA)" : "Other",
"62-73 GROUND WATER RECORD" : "Other",
"Adjudicated" : "Adjudicated",
"AdjudicatedCertificate" : "Adjudicated",
"Adjudication Decree" : "Adjudicated",
"Adverse Use" : "Adverse",
"Application to Appropriate" : "Application / Change / Permit / Temporary",
"Appropriative" : "Appropriative",
"Appropriative (State Filing)" : "Appropriative",
"Cert of Right - Power" : "Certificate / Decree / Vested",
"Certificate" : "Certificate / Decree / Vested",
"CertificateOfChange" : "Certificate / Decree / Vested",
"ChangeApplication" : "In Review",
"ChangeROE" : "Application / Change / Permit / Temporary",
"Claim" : "Claim",
"ClaimAmendment" : "Claim",
"CONSERVATION DISTRICT RECORD" : "Other",
"CONVERTED TERMINATES" : "Other",
"Decree" : "Certificate / Decree / Vested",
"Diligence Claim" : "In Review",
"ENV - MONITOR" : "Environmental",
"ENV - MONITOR OR PIEZOMETER" : "Environmental",
"ENV - PIEZOMETER" : "Environmental",
"EXEMPT" : "Exempt",
"EXEMPT - DOMESTIC STOCK" : "Exempt",
"EXEMPT - NON-DOMESTIC" : "Exempt",
"EXEMPT RIGHT" : "Exempt",
"Federal Claims" : "Federal",
"Federal Reserved Water Right" : "Federal",
"Federal Stockponds" : "Federal",
"Fixed-Time Application" : "Application / Change / Permit / Temporary",
"GROUND WATER CERTIFICATE" : "Certificate / Decree / Vested",
"Groundwater Recordation" : "Certificate / Decree / Vested",
"groundwater registrations" : "Certificate / Decree / Vested",
"INTER-STATE CLAIM" : "Claim",
"IRRIGATION DISTRICT" : "Certificate / Decree / Vested",
"Klamath Adjudication" : "Adjudicated",
"Klamath Adjudication claim" : "Adjudicated",
"MitigatedPermit" : "Application / Change / Permit / Temporary",
"NewApp" : "Other",
"Non Jurisdictional" : "Other",
"NON- EXEMPT - AQUIFER STORAGE & RECOVERY (ASR)" : "Groundwater Non-Exempt",
"NON-EXEMPT" : "Groundwater Non-Exempt",
"NON-EXEMPT - NON-SERVICE" : "Groundwater Non-Exempt",
"NON-EXEMPT - RECOVERY" : "Groundwater Non-Exempt",
"NON-EXEMPT - REPLACEMENT WELL IN NEW LOCATION" : "Groundwater Non-Exempt",
"NON-EXEMPT - SERVICE" : "Groundwater Non-Exempt",
"NON-EXEMPT - WITHDRAWAL PERMIT" : "Groundwater Non-Exempt",
"Not Determined" : "In Review",
"Pending Adjudication Claim" : "Claim",
"Permit" : "Application / Change / Permit / Temporary",
"POWDER RIVER DECLARATION" : "Other",
"power claim" : "Claim",
"Prior Right" : "Other",
"PROVISIONAL PERMIT" : "Application / Change / Permit / Temporary",
"QuincyBasinPermit" : "Application / Change / Permit / Temporary",
"Registration Cannabis" : "Certificate / Decree / Vested",
"Registration Domestic" : "Certificate / Decree / Vested",
"Registration Irrigation" : "Certificate / Decree / Vested",
"Registration Livestock" : "Certificate / Decree / Vested",
"Regular" : "Other",
"RESERVED CLAIM" : "Federal",
"ROE" : "In Review",
"Seasonal" : "Application / Change / Permit / Temporary",
"Section 12 File" : "Other",
"ShortTerm" : "Application / Change / Permit / Temporary",
"SPCL - CATHODIC PROTECTION" : "Other",
"SPCL - EXPLORATION" : "Other",
"SPCL - GEOTECHNICAL" : "Other",
"SPCL - MINERAL EXPLORATION" : "Other",
"SPCL - OTHER" : "Other",
"Special" : "Other",
"STATEMENT OF CLAIM" : "Claim",
"Statement of Div and Use" : "Other",
"Stockpond" : "Certificate / Decree / Vested",
"STOCKWATER PERMIT" : "Certificate / Decree / Vested",
"SupersedingCertificate" : "Superseding",
"SupersedingPermit" : "Superseding",
"SupersedingQuincyBasinPermit" : "Superseding",
"surface water registrations" : "Certificate / Decree / Vested",
"Temporary" : "Application / Change / Permit / Temporary",
"Temporary Application" : "Application / Change / Permit / Temporary",
"TEMPORARY PERMIT" : "Application / Change / Permit / Temporary",
"Temporary Permit" : "Application / Change / Permit / Temporary",
"TemporaryDonation" : "Application / Change / Permit / Temporary",
"Term" : "Other",
"Underground Water Claim" : "Other",
"Vested" : "Certificate / Decree / Vested",
"Waste Water Change" : "Application / Change / Permit / Temporary",
"Water Company Shares" : "Other",
"WATER RESERVATION" : "Other"}

def assignWaDEATCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "Other"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = allowTypeCVDict[String1]
        except:
            outList = "Other"
    return outList

dfsite['AllocationType'] = dfsite.apply(lambda row: assignWaDEATCV(row['AllocationTypeCV']), axis=1)

# %%
#AllocationLegalStatusCV
allowLegalStatusCVDict = {
"Abrogated" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Adjudicated" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Active" : "Active",
"Application In Processing" : "Pending / Processing / Under Review",
"Cancelled" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Conditionally Approved" : "Conditional / Deferred / Permit",
"Deferred" : "Conditional / Deferred / Permit",
"Denied" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Held In Abeyance" : "Other",
"Inactive" : "Closed File / Dismissed /  Inactive / Retired",
"Pending Review" : "Pending / Processing / Under Review",
"Perfected" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Under Review" : "Pending / Processing / Under Review",
"Void" : "Expired / Lapsed / Terminated / Void",
"Certified" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Claimed" : "Claim / Declaration",
"Claimed - Local Oversight" : "Claim / Declaration",
"Closed" : "Closed File / Dismissed /  Inactive / Retired",
"Completed" : "Other",
"Permitted" : "Conditional / Deferred / Permit",
"Registered" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Canceled" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Certificate" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Curtailed" : "Other",
"Decreed" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Expired" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Licensed" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"DISMISSED" : "Closed File / Dismissed /  Inactive / Retired",
"NO STATUS ( may not be any of these)" : "Closed File / Dismissed /  Inactive / Retired",
"SEVERED" : "Closed File / Dismissed /  Inactive / Retired",
"SUSPENDED" : "Exempt / Supersceded",
"Administrative" : "Other",
"Application" : "Pending / Processing / Under Review",
"Application Being Protested" : "Pending / Processing / Under Review",
"Closed File" : "Closed File / Dismissed /  Inactive / Retired",
"Declaration" : "Claim / Declaration",
"Dedicated" : "Other",
"Hydrographic Survey" : "Other",
"Notice of Intention" : "Other",
"Not implies that there is no status" : "Other",
"Owner Management Status" : "Other",
"Offer of Judgment" : "Other",
"Proof of Beneficial Use" : "Other",
"Permit" : "Conditional / Deferred / Permit",
"Purged Conversion Record" : "Other",
"Retired" : "Closed File / Dismissed /  Inactive / Retired",
"Transferred" : "Other",
"Water Master Status" : "Other",
"PENDING" : "Pending / Processing / Under Review",
"Ready For Action" : "Pending / Processing / Under Review",
"Ready for Action (Protested)" : "Pending / Processing / Under Review",
"Rejected" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Relinquish a Portion" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Relinquished" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Rescinded" : "Other",
"Reserved" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Revocable Permit" : "Conditional / Deferred / Permit",
"Renumbered" : "Pending / Processing / Under Review",
"REVOKED" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Supersceded" : "Exempt / Supersceded",
"Unknown" : "Unknown",
"Abandoned" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Adjudication Decree" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Approved" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Certificated" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Disallowed" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Forfeited" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Lapsed" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Lapsed(Destroyed), Currently NOT Used" : "Expired / Lapsed / Terminated / Void",
"No status" : "Other",
"No Proof Required" : "Exempt / Supersceded",
"Nonuse" : "Closed File / Dismissed /  Inactive / Retired",
"Rejected(Destroyed), Currently Not Used" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Terminated" : "Expired / Lapsed / Terminated / Void",
"Unapproved" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Withdrawn(Destroyed), Currently Not Used" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Water User`s Claim" : "Claim / Declaration",
"Vested Rights" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"InTrustTemp" : "Other",
"Withdrawn" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Absolute" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Conditional Absolute" : "Conditional / Deferred / Permit",
"Conditional" : "Conditional / Deferred / Permit"}

def assignWaDELSCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "Other"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = allowLegalStatusCVDict[String1]
        except:
            outList = "Other"
    return outList

dfsite['LegalStatusCV'] = dfsite.apply(lambda row: assignWaDELSCV(row['AllocationLegalStatusCV']), axis=1)

# %%
#Sort by SiteUUID and BenUse (this way Agriculture should show up first in the below list)
dfsite = dfsite.sort_values(by=['SiteUUID', 'WSWCBeneficialUse'], ascending=True).reset_index()
dfsite
# Out:
#           index   SiteID  SiteUUID   Longitude   Latitude  AllocationAmountID  \
# 0             0  5987443      CA_1 -124.100000  40.963100           3582161.0
# 1             1  5987444     CA_10 -121.173807  39.875367           3583769.0
# 2             2  5987445   CA_1000 -122.716594  41.730083           3587847.0
# 3             3  5987446  CA_10000 -120.647606  40.636866           3594308.0
# 4             4  5987447  CA_10001 -120.895545  38.450445           3594345.0
# ...         ...      ...       ...         ...        ...                 ...
# 939206  1252357  5768281   WA_9995 -120.162283  46.016114           3384138.0
# 939207  1252358  5768282   WA_9996 -120.162290  46.019457           3383038.0
# 939208  1252359  5768283   WA_9997 -120.122189  46.021328           3395072.0
# 939209  1252360  5768284   WA_9998 -120.122641  46.006227           3393054.0
# 939210  1252361  5768285   WA_9999 -120.130926  46.008851           3380697.0
#
#        AllocationNativeID  AllocationAmount  AllocationMaximum  \
# 0                 A010767               NaN                0.0
# 1                 A014760               NaN                0.0
# 2                 A021986               NaN                0.0
# 3                 C000897               NaN                0.0
# 4                 C000934               NaN                0.0
# ...                   ...               ...                ...
# 939206        2.05850e+06          0.000000             -999.0
# 939207        2.05594e+06          0.011140                1.0
# 939208        2.08828e+06          0.020000                0.2
# 939209        2.07502e+06          0.015596                2.0
# 939210        2.05128e+06          0.000000             -999.0
#
#         IrrigatedAcreage  ...        Date WaterSourceID WaterSourceName  \
# 0                    0.0  ...  1944-02-14      546831.0            UNSP
# 1                    0.0  ...  1952-04-17      546831.0            UNSP
# 2                    0.0  ...  1964-12-01      546829.0        UNSP (2)
# 3                    0.0  ...  1977-09-07      546844.0            UNST
# 4                    0.0  ...  1977-09-21      546844.0            UNST
# ...                  ...  ...         ...           ...             ...
# 939206            -999.0  ...  1974-04-29      462900.0     Unspecified
# 939207            -999.0  ...  1946-10-01      462900.0     Unspecified
# 939208               0.0  ...  1913-01-01      462901.0     Unspecified
# 939209            -999.0  ...  1947-12-01      462900.0     Unspecified
# 939210            -999.0  ...  1974-06-01      462900.0     Unspecified
#
#        OrganizationID OrganizationUUID State  WSWCBeneficialUse WBenUseColor  \
# 0                17.0           CSWRCB    CA           Domestic    #0000FFFF
# 1                17.0           CSWRCB    CA           Domestic    #0000FFFF
# 2                17.0           CSWRCB    CA           Domestic    #0000FFFF
# 3                17.0           CSWRCB    CA          Livestock    #FFD700FF
# 4                17.0           CSWRCB    CA          Livestock    #FFD700FF
# ...               ...              ...   ...                ...          ...
# 939206           11.0             WSDE    WA          Livestock    #FFD700FF
# 939207           11.0             WSDE    WA          Livestock    #FFD700FF
# 939208           11.0             WSDE    WA          Livestock    #FFD700FF
# 939209           11.0             WSDE    WA           Domestic    #0000FFFF
# 939210           11.0             WSDE    WA            Unknown    #D3D3D3FF
#
#                        AllocationType  \
# 0                       Appropriative
# 1                       Appropriative
# 2                       Appropriative
# 3       Certificate / Decree / Vested
# 4       Certificate / Decree / Vested
# ...                               ...
# 939206                          Claim
# 939207                          Claim
# 939208                          Claim
# 939209                          Claim
# 939210                          Claim
#
#                                             LegalStatusCV
# 0       Absolute / Approved / Certificated / Decreed /...
# 1       Absolute / Approved / Certificated / Decreed /...
# 2       Absolute / Approved / Certificated / Decreed /...
# 3       Absolute / Approved / Certificated / Decreed /...
# 4       Absolute / Approved / Certificated / Decreed /...
# ...                                                   ...
# 939206                                             Active
# 939207                                             Active
# 939208                                             Active
# 939209                                             Active
# 939210                                             Active
#
# [939211 rows x 25 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfSite = pd.DataFrame()

#The Columns
outdfSite['SiteUUID'] = dfsite['SiteUUID'].astype(str) 
outdfSite['Lat'] = dfsite['Latitude'].astype(float) 
outdfSite['Long'] = dfsite['Longitude'].astype(float)
outdfSite['WBenUse'] = dfsite['WSWCBeneficialUse'].astype(str)
outdfSite['WBenUseColor'] = dfsite['WBenUseColor'].astype(str)
outdfSite['AllocationType'] = dfsite['AllocationType'].astype(str)
outdfSite['LegalStatusCV'] = dfsite['LegalStatusCV'].astype(str)

#Drop Duplicates - SiteUUID
outdfSite = outdfSite.drop_duplicates(['SiteUUID'], keep="first").reset_index(drop=True)

outdfSite
# Out:
#         SiteUUID        Lat        Long    WBenUse WBenUseColor  \
# 0           CA_1  40.963100 -124.100000   Domestic    #0000FFFF
# 1          CA_10  39.875367 -121.173807   Domestic    #0000FFFF
# 2        CA_1000  41.730083 -122.716594   Domestic    #0000FFFF
# 3       CA_10000  40.636866 -120.647606  Livestock    #FFD700FF
# 4       CA_10001  38.450445 -120.895545  Livestock    #FFD700FF
# ...          ...        ...         ...        ...          ...
# 707211   WA_9995  46.016114 -120.162283  Livestock    #FFD700FF
# 707212   WA_9996  46.019457 -120.162290  Livestock    #FFD700FF
# 707213   WA_9997  46.021328 -120.122189  Livestock    #FFD700FF
# 707214   WA_9998  46.006227 -120.122641   Domestic    #0000FFFF
# 707215   WA_9999  46.008851 -120.130926    Unknown    #D3D3D3FF
#
#                        AllocationType  \
# 0                       Appropriative
# 1                       Appropriative
# 2                       Appropriative
# 3       Certificate / Decree / Vested
# 4       Certificate / Decree / Vested
# ...                               ...
# 707211                          Claim
# 707212                          Claim
# 707213                          Claim
# 707214                          Claim
# 707215                          Claim
#
#                                             LegalStatusCV
# 0       Absolute / Approved / Certificated / Decreed /...
# 1       Absolute / Approved / Certificated / Decreed /...
# 2       Absolute / Approved / Certificated / Decreed /...
# 3       Absolute / Approved / Certificated / Decreed /...
# 4       Absolute / Approved / Certificated / Decreed /...
# ...                                                   ...
# 707211                                             Active
# 707212                                             Active
# 707213                                             Active
# 707214                                             Active
# 707215                                             Active
#
# [707216 rows x 7 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfSite.to_csv('P_SiteLFAllo.csv', index=False)  # The output

# %% [markdown]
# ### Allo LF Site, for filtering and Table Return Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Allo LeftJoin Sites Input
AllofileInput = "dontopen_AllowLJSite.csv"
dfallo = pd.read_csv(AllofileInput)
dfallo
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1,6,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          AllocationAmountID AllocationNativeID  AllocationAmount  \
# 0                   3582161            A010767               NaN
# 1                   3583769            A014760               NaN
# 2                   3587847            A021986               NaN
# 3                   3594308            C000897               NaN
# 4                   3594345            C000934               NaN
# ...                     ...                ...               ...
# 1043367             3384138        2.05850e+06          0.000000
# 1043368             3383038        2.05594e+06          0.011140
# 1043369             3395072        2.08828e+06          0.020000
# 1043370             3393054        2.07502e+06          0.015596
# 1043371             3380697        2.05128e+06          0.000000
#
#          AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                      0.0               0.0                     33567
# 1                      0.0               0.0                     22293
# 2                      0.0               0.0                      2282
# 3                      0.0               0.0                     11225
# 4                      0.0               0.0                     10198
# ...                    ...               ...                       ...
# 1043367             -999.0            -999.0                     12754
# 1043368                1.0            -999.0                      7776
# 1043369                0.2               0.0                      5707
# 1043370                2.0            -999.0                     20339
# 1043371             -999.0            -999.0                      1425
#
#         PrimaryUseCategoryCV AllocationLegalStatusCV AllocationTypeCV  \
# 0                 Irrigation                Licensed    Appropriative
# 1                 Irrigation                Licensed    Appropriative
# 2                 Irrigation                Licensed    Appropriative
# 3                 Irrigation               Certified        Stockpond
# 4                 Irrigation               Certified        Stockpond
# ...                      ...                     ...              ...
# 1043367           Irrigation                  Active            Claim
# 1043368           Irrigation                  Active            Claim
# 1043369           Irrigation                  Active            Claim
# 1043370           Irrigation                  Active            Claim
# 1043371           Irrigation                  Active            Claim
#
#                BeneficialUseCV        Date   SiteID  SiteUUID   Longitude  \
# 0                     Domestic  1944-02-14  5987443      CA_1 -124.100000
# 1                     Domestic  1952-04-17  5987444     CA_10 -121.173807
# 2                     Domestic  1964-12-01  5987445   CA_1000 -122.716594
# 3                Stockwatering  1977-09-07  5987446  CA_10000 -120.647606
# 4                Stockwatering  1977-09-21  5987447  CA_10001 -120.895545
# ...                        ...         ...      ...       ...         ...
# 1043367            Stock water  1974-04-29  5768281   WA_9995 -120.162283
# 1043368            Stock water  1946-10-01  5768282   WA_9996 -120.162290
# 1043369            Stock water  1913-01-01  5768283   WA_9997 -120.122189
# 1043370       Domestic general  1947-12-01  5768284   WA_9998 -120.122641
# 1043371  No Purpose Identified  1974-06-01  5768285   WA_9999 -120.130926
#
#           Latitude  WaterSourceID WaterSourceName  OrganizationID  \
# 0        40.963100         546831            UNSP              17
# 1        39.875367         546831            UNSP              17
# 2        41.730083         546829        UNSP (2)              17
# 3        40.636866         546844            UNST              17
# 4        38.450445         546844            UNST              17
# ...            ...            ...             ...             ...
# 1043367  46.016114         462900     Unspecified              11
# 1043368  46.019457         462900     Unspecified              11
# 1043369  46.021328         462901     Unspecified              11
# 1043370  46.006227         462900     Unspecified              11
# 1043371  46.008851         462900     Unspecified              11
#
#         OrganizationUUID State
# 0                 CSWRCB    CA
# 1                 CSWRCB    CA
# 2                 CSWRCB    CA
# 3                 CSWRCB    CA
# 4                 CSWRCB    CA
# ...                  ...   ...
# 1043367             WSDE    WA
# 1043368             WSDE    WA
# 1043369             WSDE    WA
# 1043370             WSDE    WA
# 1043371             WSDE    WA
#
# [1043372 rows x 20 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfallo = dfallo[(dfallo.WaterSourceName != 'test')]
dfallo = dfallo[dfallo['SiteUUID'].notna()]
dfallo = dfallo[dfallo['AllocationPriorityDateID'].notna()]
dfallo = dfallo[dfallo['BeneficialUseCV'].notna()]
dfallo = dfallo[dfallo['Longitude'].notna()]
dfallo = dfallo[dfallo['Latitude'].notna()]
dfallo.reset_index()
# Out:
#           index  AllocationAmountID AllocationNativeID  AllocationAmount  \
# 0             0             3582161            A010767               NaN
# 1             1             3583769            A014760               NaN
# 2             2             3587847            A021986               NaN
# 3             3             3594308            C000897               NaN
# 4             4             3594345            C000934               NaN
# ...         ...                 ...                ...               ...
# 939206  1043367             3384138        2.05850e+06          0.000000
# 939207  1043368             3383038        2.05594e+06          0.011140
# 939208  1043369             3395072        2.08828e+06          0.020000
# 939209  1043370             3393054        2.07502e+06          0.015596
# 939210  1043371             3380697        2.05128e+06          0.000000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                     0.0               0.0                     33567
# 1                     0.0               0.0                     22293
# 2                     0.0               0.0                      2282
# 3                     0.0               0.0                     11225
# 4                     0.0               0.0                     10198
# ...                   ...               ...                       ...
# 939206             -999.0            -999.0                     12754
# 939207                1.0            -999.0                      7776
# 939208                0.2               0.0                      5707
# 939209                2.0            -999.0                     20339
# 939210             -999.0            -999.0                      1425
#
#        PrimaryUseCategoryCV AllocationLegalStatusCV AllocationTypeCV  ...  \
# 0                Irrigation                Licensed    Appropriative  ...
# 1                Irrigation                Licensed    Appropriative  ...
# 2                Irrigation                Licensed    Appropriative  ...
# 3                Irrigation               Certified        Stockpond  ...
# 4                Irrigation               Certified        Stockpond  ...
# ...                     ...                     ...              ...  ...
# 939206           Irrigation                  Active            Claim  ...
# 939207           Irrigation                  Active            Claim  ...
# 939208           Irrigation                  Active            Claim  ...
# 939209           Irrigation                  Active            Claim  ...
# 939210           Irrigation                  Active            Claim  ...
#
#               Date   SiteID  SiteUUID   Longitude   Latitude  WaterSourceID  \
# 0       1944-02-14  5987443      CA_1 -124.100000  40.963100         546831
# 1       1952-04-17  5987444     CA_10 -121.173807  39.875367         546831
# 2       1964-12-01  5987445   CA_1000 -122.716594  41.730083         546829
# 3       1977-09-07  5987446  CA_10000 -120.647606  40.636866         546844
# 4       1977-09-21  5987447  CA_10001 -120.895545  38.450445         546844
# ...            ...      ...       ...         ...        ...            ...
# 939206  1974-04-29  5768281   WA_9995 -120.162283  46.016114         462900
# 939207  1946-10-01  5768282   WA_9996 -120.162290  46.019457         462900
# 939208  1913-01-01  5768283   WA_9997 -120.122189  46.021328         462901
# 939209  1947-12-01  5768284   WA_9998 -120.122641  46.006227         462900
# 939210  1974-06-01  5768285   WA_9999 -120.130926  46.008851         462900
#
#         WaterSourceName OrganizationID  OrganizationUUID State
# 0                  UNSP             17            CSWRCB    CA
# 1                  UNSP             17            CSWRCB    CA
# 2              UNSP (2)             17            CSWRCB    CA
# 3                  UNST             17            CSWRCB    CA
# 4                  UNST             17            CSWRCB    CA
# ...                 ...            ...               ...   ...
# 939206      Unspecified             11              WSDE    WA
# 939207      Unspecified             11              WSDE    WA
# 939208      Unspecified             11              WSDE    WA
# 939209      Unspecified             11              WSDE    WA
# 939210      Unspecified             11              WSDE    WA
#
# [939211 rows x 21 columns]

# %%
#changing data type of 'Date' to datatype, then changing format of 'Date' to yyyy-mm-dd
dfallo['Date'] = pd.to_datetime(dfallo['Date'], errors = 'coerce')
dfallo['Date'] = pd.to_datetime(dfallo["Date"].dt.strftime('%m/%d/%Ym'))

# %%
#Removing NaN, and missing (999) values from AllocaitonAmount, AllocaitonMaxium, IrrigatedAcerage.
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].fillna(0)
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].replace(999, 0)

dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].fillna(0)
dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].replace(999, 0)

dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].fillna(0)
dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].replace(999, 0)

# %%
alloWSWCBenUseDict = {
"Agricultural Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Agriculture Uses" : "Agricultural",
"Agricutural Spraying" : "Agricultural",
"Cranberry" : "Agricultural",
"Dairy" : "Agricultural",
"Dairy Barn Uses" : "Agricultural",
"Feed pen operation" : "Agricultural",
"Harvesting of Cranberries" : "Agricultural",
"Individual Irrigation" : "Agricultural",
"Irrigated agriculture_ground" : "Agricultural",
"Irrigated agriculture_reuse" : "Agricultural",
"Irrigated agriculture_surface" : "Agricultural",
"Irrigation" : "Agricultural",
"Irrigation and Domestic" : "Agricultural",
"Irrigation and Livestock" : "Agricultural",
"Irrigation Livestock and Domestic" : "Agricultural",
"Irrigation of Cranberries" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Irrigation Unknown" : "Agricultural",
"Irrigation-Carey Act" : "Agricultural",
"Irrigation-DLE" : "Agricultural",
"Livestock" : "Agricultural",
"Livestock and Wildlife" : "Agricultural",
"Livestock_ground" : "Agricultural",
"Livestock_reuse" : "Agricultural",
"Livestock_surface" : "Agricultural",
"Nursery Uses" : "Agricultural",
"Practicably Irrigable Acreage" : "Agricultural",
"Primary and Supplemental Irrigation" : "Agricultural",
"Recharge For Irrigation" : "Agricultural",
"Subirrigation" : "Agricultural",
"Supplemental Irrigation" : "Agricultural",
"Aquaculture" : "Aquaculture",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Commercial" : "Commercial",
"Commercial & indust" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"Commercial Uses" : "Commercial",
"Community type use - mdwca, private or commercial supplied" : "Commercial",
"Sale" : "Commercial",
"Shop" : "Commercial",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 multiple domestic households" : "Domestic",
"Domestic" : "Domestic",
"Domestic and Livestock" : "Domestic",
"Domestic construction" : "Domestic",
"Domestic Expanded" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic general" : "Domestic",
"Domestic Including Lawn and Garden" : "Domestic",
"Domestic multiple" : "Domestic",
"Domestic single" : "Domestic",
"Domestic Storage" : "Domestic",
"Group Domestic" : "Domestic",
"Household Use Only" : "Domestic",
"Human Consumption" : "Domestic",
"Human Consumption and Livestock" : "Domestic",
"Institutional" : "Domestic",
"Lawn And Garden" : "Domestic",
"Mobile home parks" : "Domestic",
"Multiple Domestic" : "Domestic",
"Public Supply" : "Domestic",
"Public utility" : "Domestic",
"Rural Water" : "Domestic",
"Subdivision" : "Domestic",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"Augmentation well" : "Environmental",
"Average Annual Flow" : "Environmental",
"Bankfull Flow" : "Environmental",
"Base Flow" : "Environmental",
"Brine production well" : "Environmental",
"Channel Maintenance" : "Environmental",
"Cumulative Accretion To River" : "Environmental",
"Cumulative Depletion From River" : "Environmental",
"Dust Control" : "Environmental",
"Environmental" : "Environmental",
"Environmental quality" : "Environmental",
"Erosion Control" : "Environmental",
"Evaporation" : "Environmental",
"Frost Protection" : "Environmental",
"Greenhouse" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Lake Level Maintenance" : "Environmental",
"Minimum Stream Flow" : "Environmental",
"Minimum Stream Flow From Storage" : "Environmental",
"Minimum Stream Flow Storage" : "Environmental",
"Minimum Streamflow" : "Environmental",
"Mitigation" : "Environmental",
"Net Effect On River" : "Environmental",
"Sediment Control" : "Environmental",
"Water Quality Improvement" : "Environmental",
"Water Quality Improvement From Storage" : "Environmental",
"Water Quality Improvement Storage" : "Environmental",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection (Instream)" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Anadromous and Resident Fish Habitat (Instream)" : "Fish",
"Fish and game propogation" : "Fish",
"Fish And Wildlife" : "Fish",
"Fish and Wildlife Preservation and Enhancement" : "Fish",
"Fish Culture" : "Fish",
"Fish Habitat" : "Fish",
"Fish Habitat From Storage" : "Fish",
"Fish Habitat Storage" : "Fish",
"Fish Propagation" : "Fish",
"Fish Propagation From Storage" : "Fish",
"Fish Propagation Storage" : "Fish",
"Fish Raceways" : "Fish",
"Fishery" : "Fish",
"Fishery Enhancement (Instream)" : "Fish",
"Recreation Fish Wildlife" : "Fish",
"100 Year Flood Flow" : "Flood Control",
"Flood Control" : "Flood Control",
"Flood Control Storage" : "Flood Control",
"Flow Augmentation" : "Flood Control",
"Flow Through Fish Pond" : "Flood Control",
"Mitigation By Delivery" : "Flood Control",
"Mitigation By Delivery From Storage" : "Flood Control",
"Mitigation By Delivery Storage" : "Flood Control",
"Mitigation By NonUse" : "Flood Control",
"Stream augmentation" : "Flood Control",
"Supplemental Flood Harvesting" : "Flood Control",
"Air Conditioning or Heating" : "Heating and Cooling",
"Cooling" : "Heating and Cooling",
"Cooling for indust proces" : "Heating and Cooling",
"Cooling From Storage" : "Heating and Cooling",
"Cooling Storage" : "Heating and Cooling",
"Geo-Thermal (Heating & Cooling)" : "Heating and Cooling",
"Geothermal Heating" : "Heating and Cooling",
"Geo-Thermal(Energy Production)" : "Heating and Cooling",
"Heat Control" : "Heating and Cooling",
"Heat Exchange" : "Heating and Cooling",
"Heat protection for crops" : "Heating and Cooling",
"Heating" : "Heating and Cooling",
"Heating From Storage" : "Heating and Cooling",
"Heating Storage" : "Heating and Cooling",
"Temperature Control" : "Heating and Cooling",
"72-12-1 Construction of public works" : "Industrial",
"Cemetery" : "Industrial",
"Construction" : "Industrial",
"Dairy operation" : "Industrial",
"Highway" : "Industrial",
"Highway construction" : "Industrial",
"Industrial" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Industrial/Manufacturing Uses" : "Industrial",
"Irrigation From Storage" : "Industrial",
"Log Deck Sprinkling" : "Industrial",
"Manufacturing" : "Industrial",
"Manufacturing_ground" : "Industrial",
"Manufacturing_reuse" : "Industrial",
"Manufacturing_surface" : "Industrial",
"Meat packing plant" : "Industrial",
"Milling" : "Industrial",
"Oil field maintenance" : "Industrial",
"Oil production" : "Industrial",
"Oil Well Flooding" : "Industrial",
"Petroleum processing plant" : "Industrial",
"Poultry and egg operation" : "Industrial",
"Railway" : "Industrial",
"Ram" : "Industrial",
"Road Construction" : "Industrial",
"Sawmill" : "Industrial",
"Secondary recovery of oil" : "Industrial",
"Use in a Mint Still" : "Industrial",
"Aquatic Habitat" : "Instream Flow",
"Aquatic Life Instream" : "Instream Flow",
"Instream Flow" : "Instream Flow",
"Multiple Instream Uses" : "Instream Flow",
"Pollution Abatement" : "Instream Flow",
"Pollution Abatement (Instream)" : "Instream Flow",
"Pollution control well" : "Instream Flow",
"Riparian Habitat (Instream)" : "Instream Flow",
"Riparian Habitat Restoration Project" : "Instream Flow",
"Riparian Maintenance" : "Instream Flow",
"72-12-1 livestock watering" : "Livestock",
"Stock" : "Livestock",
"Stock water" : "Livestock",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"Stockwatering" : "Livestock",
"Mining" : "Mining",
"Mining and Milling" : "Mining",
"Mining From Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Mining Storage" : "Mining",
"Mining, Milling, and Dewatering" : "Mining",
"Mining_ground" : "Mining",
"Mining_reuse" : "Mining",
"Mining_surface" : "Mining",
"Municipal" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal Storage" : "Municipal",
"Municipal Uses" : "Municipal",
"Municipal_ground" : "Municipal",
"Municipal_reuse" : "Municipal",
"Municipal_surface" : "Municipal",
"Pond Maintenance" : "Municipal",
"Quasi-Municipal" : "Municipal",
"Restroom" : "Municipal",
"School use - public, private, parochial, & universities" : "Municipal",
"Use Within a School" : "Municipal",
"508-14" : "Other",
"Administrative" : "Other",
"Aesthetic" : "Other",
"Aesthetic From Storage" : "Other",
"Aesthetic Storage" : "Other",
"Aesthetics" : "Other",
"All Beneficial Uses" : "Other",
"As Decreed" : "Other",
"Augmentation" : "Other",
"Cathodic protection well" : "Other",
"Closed file" : "Other",
"Dewatering" : "Other",
"Dewatering well" : "Other",
"Diversion To Storage" : "Other",
"Evaporative" : "Other",
"Exploration" : "Other",
"Export From Basin" : "Other",
"Export From State" : "Other",
"Federal Reserved" : "Other",
"Federal Reserved Use" : "Other",
"Forest Management" : "Other",
"Injection" : "Other",
"Laboratory" : "Other",
"Military - military installations" : "Other",
"Monitoring well" : "Other",
"Multiple Purpose" : "Other",
"Multiple Use" : "Other",
"Municipal inter-tie system" : "Other",
"Navigation" : "Other",
"No pre-1907 water right exists on this land" : "Other",
"Non 72-12-1 domestic and livestock watering" : "Other",
"Non 72-12-1 domestic one household" : "Other",
"Non 72-12-1 livestock watering" : "Other",
"Non 72-12-1 multiple domestic households" : "Other",
"Non-profit organizational use" : "Other",
"Observation" : "Other",
"Observation And Testing" : "Other",
"Other" : "Other",
"Other Purpose" : "Other",
"Quasi-Municipal Uses" : "Other",
"See Remarks" : "Other",
"Stacked water right" : "Other",
"Test Well" : "Other",
"Transmountain Export" : "Other",
"Trust water, Permanent" : "Other",
"Trust water, Temporary" : "Other",
"Geothermal" : "Power",
"Geothermal boreholes" : "Power",
"Incidental Power" : "Power",
"Power" : "Power",
"Power Development" : "Power",
"Power From Storage" : "Power",
"Power Generation" : "Power",
"Power Generation Nonconsumptive" : "Power",
"POWER GENERATION, NONCONSUMPTIVE" : "Power",
"Power Storage" : "Power",
"Steam-Electric Power_ground" : "Power",
"Steam-Electric Power_reuse" : "Power",
"Steam-Electric Power_surface" : "Power",
"Recharge" : "Recharge",
"Campsite" : "Recreation",
"Parks and Recreation" : "Recreation",
"Recreation" : "Recreation",
"Recreation - beautification" : "Recreation",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreational" : "Recreation",
"Swimming" : "Recreation",
"Snow Making" : "Snow Making",
"Groundwater Aquifer Storage & Recovery" : "Storage",
"Groundwater Preservation" : "Storage",
"Storage" : "Storage",
"Strategic water reserve" : "Storage",
"Streamflow Maintenance From Storage" : "Storage",
"Streamflow Maintenance Storage" : "Storage",
"No Purpose Identified" : "Unknown",
"No right" : "Unknown",
"No use of right or POD" : "Unknown",
"To be determined" : "Unknown",
"Unknown" : "Unknown",
"Water Fowl" : "Wildlife",
"Wild And Scenic River" : "Wildlife",
"Wildlife" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife refuge" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife Waterfowl" : "Wildlife",
"WILDLIFE/WATERFOWL" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = alloWSWCBenUseDict[String1]
        except:
            outList = "Other"
    return outList

dfallo['WSWCBeneficialUse'] = dfallo.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#AllowcationTypeCv
allowTypeCVDict = {
"(GRDA)" : "Other",
"62-73 GROUND WATER RECORD" : "Other",
"Adjudicated" : "Adjudicated",
"AdjudicatedCertificate" : "Adjudicated",
"Adjudication Decree" : "Adjudicated",
"Adverse Use" : "Adverse",
"Application to Appropriate" : "Application / Change / Permit / Temporary",
"Appropriative" : "Appropriative",
"Appropriative (State Filing)" : "Appropriative",
"Cert of Right - Power" : "Certificate / Decree / Vested",
"Certificate" : "Certificate / Decree / Vested",
"CertificateOfChange" : "Certificate / Decree / Vested",
"ChangeApplication" : "In Review",
"ChangeROE" : "Application / Change / Permit / Temporary",
"Claim" : "Claim",
"ClaimAmendment" : "Claim",
"CONSERVATION DISTRICT RECORD" : "Other",
"CONVERTED TERMINATES" : "Other",
"Decree" : "Certificate / Decree / Vested",
"Diligence Claim" : "In Review",
"ENV - MONITOR" : "Environmental",
"ENV - MONITOR OR PIEZOMETER" : "Environmental",
"ENV - PIEZOMETER" : "Environmental",
"EXEMPT" : "Exempt",
"EXEMPT - DOMESTIC STOCK" : "Exempt",
"EXEMPT - NON-DOMESTIC" : "Exempt",
"EXEMPT RIGHT" : "Exempt",
"Federal Claims" : "Federal",
"Federal Reserved Water Right" : "Federal",
"Federal Stockponds" : "Federal",
"Fixed-Time Application" : "Application / Change / Permit / Temporary",
"GROUND WATER CERTIFICATE" : "Certificate / Decree / Vested",
"Groundwater Recordation" : "Certificate / Decree / Vested",
"groundwater registrations" : "Certificate / Decree / Vested",
"INTER-STATE CLAIM" : "Claim",
"IRRIGATION DISTRICT" : "Certificate / Decree / Vested",
"Klamath Adjudication" : "Adjudicated",
"Klamath Adjudication claim" : "Adjudicated",
"MitigatedPermit" : "Application / Change / Permit / Temporary",
"NewApp" : "Other",
"Non Jurisdictional" : "Other",
"NON- EXEMPT - AQUIFER STORAGE & RECOVERY (ASR)" : "Groundwater Non-Exempt",
"NON-EXEMPT" : "Groundwater Non-Exempt",
"NON-EXEMPT - NON-SERVICE" : "Groundwater Non-Exempt",
"NON-EXEMPT - RECOVERY" : "Groundwater Non-Exempt",
"NON-EXEMPT - REPLACEMENT WELL IN NEW LOCATION" : "Groundwater Non-Exempt",
"NON-EXEMPT - SERVICE" : "Groundwater Non-Exempt",
"NON-EXEMPT - WITHDRAWAL PERMIT" : "Groundwater Non-Exempt",
"Not Determined" : "In Review",
"Pending Adjudication Claim" : "Claim",
"Permit" : "Application / Change / Permit / Temporary",
"POWDER RIVER DECLARATION" : "Other",
"power claim" : "Claim",
"Prior Right" : "Other",
"PROVISIONAL PERMIT" : "Application / Change / Permit / Temporary",
"QuincyBasinPermit" : "Application / Change / Permit / Temporary",
"Registration Cannabis" : "Certificate / Decree / Vested",
"Registration Domestic" : "Certificate / Decree / Vested",
"Registration Irrigation" : "Certificate / Decree / Vested",
"Registration Livestock" : "Certificate / Decree / Vested",
"Regular" : "Other",
"RESERVED CLAIM" : "Federal",
"ROE" : "In Review",
"Seasonal" : "Application / Change / Permit / Temporary",
"Section 12 File" : "Other",
"ShortTerm" : "Application / Change / Permit / Temporary",
"SPCL - CATHODIC PROTECTION" : "Other",
"SPCL - EXPLORATION" : "Other",
"SPCL - GEOTECHNICAL" : "Other",
"SPCL - MINERAL EXPLORATION" : "Other",
"SPCL - OTHER" : "Other",
"Special" : "Other",
"STATEMENT OF CLAIM" : "Claim",
"Statement of Div and Use" : "Other",
"Stockpond" : "Certificate / Decree / Vested",
"STOCKWATER PERMIT" : "Certificate / Decree / Vested",
"SupersedingCertificate" : "Superseding",
"SupersedingPermit" : "Superseding",
"SupersedingQuincyBasinPermit" : "Superseding",
"surface water registrations" : "Certificate / Decree / Vested",
"Temporary" : "Application / Change / Permit / Temporary",
"Temporary Application" : "Application / Change / Permit / Temporary",
"TEMPORARY PERMIT" : "Application / Change / Permit / Temporary",
"Temporary Permit" : "Application / Change / Permit / Temporary",
"TemporaryDonation" : "Application / Change / Permit / Temporary",
"Term" : "Other",
"Underground Water Claim" : "Other",
"Vested" : "Certificate / Decree / Vested",
"Waste Water Change" : "Application / Change / Permit / Temporary",
"Water Company Shares" : "Other",
"WATER RESERVATION" : "Other"}

def assignWaDEATCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "Other"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = allowTypeCVDict[String1]
        except:
            outList = "Other"
    return outList

dfallo['AllocationType'] = dfallo.apply(lambda row: assignWaDEATCV(row['AllocationTypeCV']), axis=1)

# %%
#AllocationLegalStatusCV
allowLegalStatusCVDict = {
"Abrogated" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Adjudicated" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Active" : "Active",
"Application In Processing" : "Pending / Processing / Under Review",
"Cancelled" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Conditionally Approved" : "Conditional / Deferred / Permit",
"Deferred" : "Conditional / Deferred / Permit",
"Denied" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Held In Abeyance" : "Other",
"Inactive" : "Closed File / Dismissed /  Inactive / Retired",
"Pending Review" : "Pending / Processing / Under Review",
"Perfected" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Under Review" : "Pending / Processing / Under Review",
"Void" : "Expired / Lapsed / Terminated / Void",
"Certified" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Claimed" : "Claim / Declaration",
"Claimed - Local Oversight" : "Claim / Declaration",
"Closed" : "Closed File / Dismissed /  Inactive / Retired",
"Completed" : "Other",
"Permitted" : "Conditional / Deferred / Permit",
"Registered" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Canceled" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Certificate" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Curtailed" : "Other",
"Decreed" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Expired" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Licensed" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"DISMISSED" : "Closed File / Dismissed /  Inactive / Retired",
"NO STATUS ( may not be any of these)" : "Closed File / Dismissed /  Inactive / Retired",
"SEVERED" : "Closed File / Dismissed /  Inactive / Retired",
"SUSPENDED" : "Exempt / Supersceded",
"Administrative" : "Other",
"Application" : "Pending / Processing / Under Review",
"Application Being Protested" : "Pending / Processing / Under Review",
"Closed File" : "Closed File / Dismissed /  Inactive / Retired",
"Declaration" : "Claim / Declaration",
"Dedicated" : "Other",
"Hydrographic Survey" : "Other",
"Notice of Intention" : "Other",
"Not implies that there is no status" : "Other",
"Owner Management Status" : "Other",
"Offer of Judgment" : "Other",
"Proof of Beneficial Use" : "Other",
"Permit" : "Conditional / Deferred / Permit",
"Purged Conversion Record" : "Other",
"Retired" : "Closed File / Dismissed /  Inactive / Retired",
"Transferred" : "Other",
"Water Master Status" : "Other",
"PENDING" : "Pending / Processing / Under Review",
"Ready For Action" : "Pending / Processing / Under Review",
"Ready for Action (Protested)" : "Pending / Processing / Under Review",
"Rejected" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Relinquish a Portion" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Relinquished" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Rescinded" : "Other",
"Reserved" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Revocable Permit" : "Conditional / Deferred / Permit",
"Renumbered" : "Pending / Processing / Under Review",
"REVOKED" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Supersceded" : "Exempt / Supersceded",
"Unknown" : "Unknown",
"Abandoned" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Adjudication Decree" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Approved" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Certificated" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Disallowed" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Forfeited" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Lapsed" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Lapsed(Destroyed), Currently NOT Used" : "Expired / Lapsed / Terminated / Void",
"No status" : "Other",
"No Proof Required" : "Exempt / Supersceded",
"Nonuse" : "Closed File / Dismissed /  Inactive / Retired",
"Rejected(Destroyed), Currently Not Used" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Terminated" : "Expired / Lapsed / Terminated / Void",
"Unapproved" : "Abrogated / Denied / Disallowed / Rejected / Revoked / Unapproved",
"Withdrawn(Destroyed), Currently Not Used" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Water User`s Claim" : "Claim / Declaration",
"Vested Rights" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"InTrustTemp" : "Other",
"Withdrawn" : "Abandoned / Canceled / Forfeited / Relinquished / Withdrawn",
"Absolute" : "Absolute / Approved / Certificated / Decreed / Licensed / Registered / Reserved / Vested",
"Conditional Absolute" : "Conditional / Deferred / Permit",
"Conditional" : "Conditional / Deferred / Permit"}

def assignWaDELSCV(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "Other"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = allowLegalStatusCVDict[String1]
        except:
            outList = "Other"
    return outList

dfallo['LegalStatusCV'] = dfallo.apply(lambda row: assignWaDELSCV(row['AllocationLegalStatusCV']), axis=1)

# %%
#Sort by AllocationAmountID and SiteUUID
dfallo = dfallo.sort_values(by=['AllocationAmountID', 'SiteUUID'], ascending=True).reset_index()
dfallo
# Out:
#         index  AllocationAmountID             AllocationNativeID  \
# 0       93468             2734281  50769.493780000004-0-C-100503
# 1       93469             2734282             51356.0-0-C-100503
# 2       93470             2734283             53330.0-0-C-100503
# 3       93471             2734284             55637.0-0-C-100503
# 4       93472             2734285             55989.0-0-C-100503
# ...       ...                 ...                            ...
# 939206  29503             3617759                        S018621
# 939207  28242             3617760                        S017140
# 939208  35905             3617761                        S028209
# 939209  36472             3617762                        S010383
# 939210  12018             3617763                        S013682
#
#         AllocationAmount  AllocationMaximum  IrrigatedAcreage  \
# 0             150.000000                0.0               0.0
# 1             120.000000                0.0               0.0
# 2            1000.000000                0.0               0.0
# 3             358.000000                0.0               0.0
# 4            1080.000000                0.0               0.0
# ...                  ...                ...               ...
# 939206          0.000000                0.0               0.0
# 939207          0.000000                0.0               0.0
# 939208          0.445602                0.0               0.0
# 939209          0.000000                0.0               0.0
# 939210          0.000000                0.0               0.0
#
#         AllocationPriorityDateID PrimaryUseCategoryCV AllocationLegalStatusCV  \
# 0                           1446           Irrigation                Absolute
# 1                           1984           Irrigation                Absolute
# 2                          14095           Irrigation             Conditional
# 3                           5202           Irrigation             Conditional
# 4                           6100           Irrigation             Conditional
# ...                          ...                  ...                     ...
# 939206                     33418           Irrigation                 Claimed
# 939207                     37144           Irrigation                 Claimed
# 939208                     31819           Irrigation                 Claimed
# 939209                      6537           Irrigation                 Claimed
# 939210                      3860           Irrigation                 Claimed
#
#                 AllocationTypeCV  ...   Longitude   Latitude  WaterSourceID  \
# 0                            NaN  ... -104.468875  40.379142          38325
# 1                            NaN  ... -104.468875  40.379142          38325
# 2                            NaN  ... -104.468875  40.379142          38325
# 3                            NaN  ... -104.468875  40.379142          38325
# 4                            NaN  ... -104.468875  40.379142          38325
# ...                          ...  ...         ...        ...            ...
# 939206  Statement of Div and Use  ... -121.921600  38.212300         553179
# 939207  Statement of Div and Use  ... -121.898700  38.058100         553239
# 939208  Statement of Div and Use  ... -120.497520  39.604640         555392
# 939209  Statement of Div and Use  ... -121.856928  39.984789         549461
# 939210  Statement of Div and Use  ... -121.563635  40.033042         552760
#
#                                WaterSourceName  OrganizationID  \
# 0                           SOUTH PLATTE RIVER               1
# 1                           SOUTH PLATTE RIVER               1
# 2                           SOUTH PLATTE RIVER               1
# 3                           SOUTH PLATTE RIVER               1
# 4                           SOUTH PLATTE RIVER               1
# ...                                        ...             ...
# 939206                             LUCO SLOUGH              17
# 939207  SPOON BILL SLOUGH AND SACRAMENTO RIVER              17
# 939208                            Dorsey Creek              17
# 939209                            SINGER CREEK              17
# 939210                      RATTLE SNAKE CREEK              17
#
#         OrganizationUUID  State WSWCBeneficialUse  AllocationType  \
# 0                  CODWR     CO           Unknown           Other
# 1                  CODWR     CO           Storage           Other
# 2                  CODWR     CO           Unknown           Other
# 3                  CODWR     CO           Unknown           Other
# 4                  CODWR     CO           Unknown           Other
# ...                  ...    ...               ...             ...
# 939206            CSWRCB     CA              Fish           Other
# 939207            CSWRCB     CA      Agricultural           Other
# 939208            CSWRCB     CA     Environmental           Other
# 939209            CSWRCB     CA          Domestic           Other
# 939210            CSWRCB     CA     Environmental           Other
#
#                                             LegalStatusCV
# 0       Absolute / Approved / Certificated / Decreed /...
# 1       Absolute / Approved / Certificated / Decreed /...
# 2                         Conditional / Deferred / Permit
# 3                         Conditional / Deferred / Permit
# 4                         Conditional / Deferred / Permit
# ...                                                   ...
# 939206                                Claim / Declaration
# 939207                                Claim / Declaration
# 939208                                Claim / Declaration
# 939209                                Claim / Declaration
# 939210                                Claim / Declaration
#
# [939211 rows x 24 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfallo = pd.DataFrame()

#The Columns
outdfallo['AA_ID'] = dfallo['AllocationAmountID'].astype(str) 
outdfallo['SiteUUID'] = dfallo['SiteUUID'].astype(str)
outdfallo['SN_ID'] = dfallo['AllocationNativeID'].astype(str) 
outdfallo['Lat'] = dfallo['Latitude'].astype(float) 
outdfallo['Long'] = dfallo['Longitude'].astype(float)
outdfallo['WBenUse'] = dfallo['WSWCBeneficialUse'].astype(str)
outdfallo['State'] = dfallo['State'].astype(str) 
outdfallo['AA_CFS'] = dfallo['AllocationAmount'].astype(float) 
outdfallo['AA_AF'] = dfallo['IrrigatedAcreage'].astype(float) 
outdfallo['AAM_AF'] = dfallo['AllocationMaximum'].astype(float) 
outdfallo['PD'] = dfallo['Date']
outdfallo['WSN'] = dfallo['WaterSourceName'].astype(str)
outdfallo['AllocationType'] = dfallo['AllocationType']
outdfallo['LegalStatusCV'] = dfallo['LegalStatusCV'].astype(str)

outdfallo
# Out:
#           AA_ID  SiteUUID                          SN_ID        Lat  \
# 0       2734281      CO_2  50769.493780000004-0-C-100503  40.379142
# 1       2734282      CO_2             51356.0-0-C-100503  40.379142
# 2       2734283      CO_2             53330.0-0-C-100503  40.379142
# 3       2734284      CO_2             55637.0-0-C-100503  40.379142
# 4       2734285      CO_2             55989.0-0-C-100503  40.379142
# ...         ...       ...                            ...        ...
# 939206  3617759  CA_54747                        S018621  38.212300
# 939207  3617760  CA_53212                        S017140  38.058100
# 939208  3617761  CA_76185                        S028209  39.604640
# 939209  3617762   CA_8225                        S010383  39.984789
# 939210  3617763  CA_26177                        S013682  40.033042
#
#               Long        WBenUse State       AA_CFS  AA_AF  AAM_AF  \
# 0      -104.468875        Unknown    CO   150.000000    0.0     0.0
# 1      -104.468875        Storage    CO   120.000000    0.0     0.0
# 2      -104.468875        Unknown    CO  1000.000000    0.0     0.0
# 3      -104.468875        Unknown    CO   358.000000    0.0     0.0
# 4      -104.468875        Unknown    CO  1080.000000    0.0     0.0
# ...            ...            ...   ...          ...    ...     ...
# 939206 -121.921600           Fish    CA     0.000000    0.0     0.0
# 939207 -121.898700   Agricultural    CA     0.000000    0.0     0.0
# 939208 -120.497520  Environmental    CA     0.445602    0.0     0.0
# 939209 -121.856928       Domestic    CA     0.000000    0.0     0.0
# 939210 -121.563635  Environmental    CA     0.000000    0.0     0.0
#
#                PD                                     WSN AllocationType  \
# 0      1985-03-11                      SOUTH PLATTE RIVER          Other
# 1      1990-08-10                      SOUTH PLATTE RIVER          Other
# 2      1996-01-05                      SOUTH PLATTE RIVER          Other
# 3      2002-04-30                      SOUTH PLATTE RIVER          Other
# 4      2003-04-17                      SOUTH PLATTE RIVER          Other
# ...           ...                                     ...            ...
# 939206 2011-12-28                             LUCO SLOUGH          Other
# 939207 2011-07-19  SPOON BILL SLOUGH AND SACRAMENTO RIVER          Other
# 939208 2019-08-16                            Dorsey Creek          Other
# 939209 1981-06-02                            SINGER CREEK          Other
# 939210 1991-03-25                      RATTLE SNAKE CREEK          Other
#
#                                             LegalStatusCV
# 0       Absolute / Approved / Certificated / Decreed /...
# 1       Absolute / Approved / Certificated / Decreed /...
# 2                         Conditional / Deferred / Permit
# 3                         Conditional / Deferred / Permit
# 4                         Conditional / Deferred / Permit
# ...                                                   ...
# 939206                                Claim / Declaration
# 939207                                Claim / Declaration
# 939208                                Claim / Declaration
# 939209                                Claim / Declaration
# 939210                                Claim / Declaration
#
# [939211 rows x 14 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfallo.to_csv('P_AlloLFSite.csv', index=False)  # The output
