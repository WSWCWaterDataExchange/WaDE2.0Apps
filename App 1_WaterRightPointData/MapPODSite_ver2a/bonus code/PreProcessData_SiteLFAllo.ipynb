# %% [markdown]
# # Creating 2 Tables: Sites for Map, Allocations for Table

# %% [markdown]
# #### General Approach:
# 1) Read in csv sheet of data.  Export fields into new database.
# 2) Remove bad rows and elements.
# 3) Fix date datatype.
# 4) Include ID int value for beneficial use.
# 5) Fix and remove misisng or nan values for allocatoin flow and volume.
# 6) Remove duplicates based on AllocationNativeID.
# 7) Create API link for each siteUUID.
# 8) Export completed df as processed csv.

# %% [markdown]
# ### Sites LF Allow, for creating Site Points, Popups and Legend Colors on Map Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Sites LeftJoin Allo Input
SitefileInput = "dontopen_SiteLJAllow.csv"
dfsite = pd.read_csv(SitefileInput)
dfsite
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,10,11,12,14,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           SiteID     SiteUUID   Longitude   Latitude  \
# 0          59101  UT_43-11608 -110.049287  40.396818
# 1          59102    UT_a38359 -110.052293  40.166014
# 2          59103  UT_43-12386 -110.052293  40.166014
# 3          59104   UT_43-1725 -110.052293  40.166014
# 4          59105    UT_47-527 -110.047367  40.128161
# ...          ...          ...         ...        ...
# 1370155  3785957    CO_130777 -107.670153  38.765475
# 1370156  3785958    CO_130778 -107.663872  38.851722
# 1370157  3785959    CO_130779 -108.594927  38.174712
# 1370158  3785960    CO_130780 -106.995987  38.307656
# 1370159  3785961    CO_130781 -107.666734  38.953466
#
#                      AllocationNativeID  AllocationAmountID  AllocationAmount  \
# 0                                   NaN                 NaN               NaN
# 1                                   NaN                 NaN               NaN
# 2                                   NaN                 NaN               NaN
# 3                                   NaN                 NaN               NaN
# 4                                   NaN                 NaN               NaN
# ...                                 ...                 ...               ...
# 1370155   60996.60782999999-0-C-4006587           1698507.0            0.5000
# 1370156             61148.0-0-C-4006588           1711342.0            0.1000
# 1370157             61142.0-0-C-6002184           1711155.0            0.0022
# 1370158             59689.0-0-C-6201807           1705477.0            0.0200
# 1370159  58439.583889999994-0-A-4003174           1709512.0            0.0000
#
#          AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                      NaN               NaN                       NaN
# 1                      NaN               NaN                       NaN
# 2                      NaN               NaN                       NaN
# 3                      NaN               NaN                       NaN
# 4                      NaN               NaN                       NaN
# ...                    ...               ...                       ...
# 1370155               0.00               NaN                   24917.0
# 1370156               0.00               NaN                   24981.0
# 1370157               0.00               NaN                   24985.0
# 1370158               0.00               NaN                    1570.0
# 1370159               1.15               NaN                      59.0
#
#         PrimaryUseCategoryCV BeneficialUseCV        Date  WaterSourceID  \
# 0                        NaN             NaN         NaN            NaN
# 1                        NaN             NaN         NaN            NaN
# 2                        NaN             NaN         NaN            NaN
# 3                        NaN             NaN         NaN            NaN
# 4                        NaN             NaN         NaN            NaN
# ...                      ...             ...         ...            ...
# 1370155           Irrigation             NaN  2016-06-01        42597.0
# 1370156           Irrigation             NaN  2017-06-01        42597.0
# 1370157           Irrigation             NaN  2017-05-26        38375.0
# 1370158           Irrigation             NaN  2013-06-03        38357.0
# 1370159           Irrigation             NaN  2009-11-11        42799.0
#
#                    WaterSourceName  OrganizationID OrganizationUUID State
# 0                              NaN             NaN              NaN   NaN
# 1                              NaN             NaN              NaN   NaN
# 2                              NaN             NaN              NaN   NaN
# 3                              NaN             NaN              NaN   NaN
# 4                              NaN             NaN              NaN   NaN
# ...                            ...             ...              ...   ...
# 1370155  NORTH FORK GUNNISON RIVER             1.0            CODWR    CO
# 1370156  NORTH FORK GUNNISON RIVER             1.0            CODWR    CO
# 1370157                  DRY CREEK             1.0            CODWR    CO
# 1370158               WILLOW CREEK             1.0            CODWR    CO
# 1370159         WEST ROATCAP CREEK             1.0            CODWR    CO
#
# [1370160 rows x 18 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfsite = dfsite[(dfsite.WaterSourceName != 'test')]
dfsite = dfsite[dfsite['SiteUUID'].notna()]
dfsite = dfsite[dfsite['AllocationPriorityDateID'].notna()]
dfsite = dfsite[dfsite['BeneficialUseCV'].notna()]
dfsite = dfsite[dfsite['Longitude'].notna()]
dfsite = dfsite[dfsite['Latitude'].notna()]
dfsite.reset_index()
# Out:
#           index   SiteID      SiteUUID   Longitude   Latitude  \
# 0        185584  1438705      UTDWRE_1 -111.708363  40.091788
# 1        185585  1438705      UTDWRE_1 -111.708363  40.091788
# 2        185587  1438707    UTDWRE_100 -111.855231  41.717038
# 3        185589  1438709  UTDWRE_10000 -112.583150  37.420919
# 4        185594  1438714  UTDWRE_10005 -113.074973  38.258188
# ...         ...      ...           ...         ...        ...
# 857389  1370124  3785934     CO_130754 -107.622858  38.696379
# 857390  1370137  3785944     CO_130764 -107.997792  38.527989
# 857391  1370138  3785945     CO_130765 -107.758407  38.238939
# 857392  1370149  3785952     CO_130772 -107.907851  37.895417
# 857393  1370150  3785952     CO_130772 -107.907851  37.895417
#
#                     AllocationNativeID  AllocationAmountID  AllocationAmount  \
# 0                              51-8796            542566.0            0.0154
# 1                              51-8796            542566.0            0.0154
# 2                             25-11530            533151.0            0.0000
# 3                               81-908            553872.0            0.0000
# 4                              71-1930            550779.0            0.0000
# ...                                ...                 ...               ...
# 857389         29260.18141-0-C-4000545           1709824.0            1.2500
# 857390  60630.556489999995-0-C-4101224           1701266.0            0.5000
# 857391         57708.51654-0-C-6803675           1699790.0            0.0000
# 857392             61147.0-0-C-6008353           1707826.0            0.0000
# 857393             61147.0-0-A-6008353           1713505.0            0.0000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                    0.00               0.0                   13466.0
# 1                    0.00               0.0                   13466.0
# 2                    4.00               0.0                   13608.0
# 3                    0.25               0.0                   13608.0
# 4                  178.00             158.1                    4907.0
# ...                   ...               ...                       ...
# 857389               0.00               NaN                   19089.0
# 857390               0.00               NaN                   25000.0
# 857391               0.00               NaN                   10839.0
# 857392               0.00               NaN                   24952.0
# 857393               0.00               NaN                   24952.0
#
#        PrimaryUseCategoryCV BeneficialUseCV        Date  WaterSourceID  \
# 0                Irrigation        Domestic  1914-04-15       395582.0
# 1                Irrigation   Stockwatering  1914-04-15       395582.0
# 2                Irrigation      Irrigation  1903-01-01       395610.0
# 3                Irrigation        Domestic  1903-01-01       377378.0
# 4                Irrigation        Domestic  1928-01-01       395582.0
# ...                     ...             ...         ...            ...
# 857389           Irrigation      Irrigation  1899-09-01        42599.0
# 857390           Irrigation      Irrigation  2002-05-12        38367.0
# 857391           Irrigation       Municipal  1991-06-04        42824.0
# 857392           Irrigation    Augmentation  2017-05-31        43729.0
# 857393           Irrigation    Augmentation  2017-05-31        43729.0
#
#                             WaterSourceName  OrganizationID OrganizationUUID  \
# 0                    Underground Water Well             3.0           UTDWRE
# 1                    Underground Water Well             3.0           UTDWRE
# 2                     Unnamed Surface Drain             3.0           UTDWRE
# 3       Stout Canyon Creek Springs # 1 & #2             3.0           UTDWRE
# 4                    Underground Water Well             3.0           UTDWRE
# ...                                     ...             ...              ...
# 857389                           SMITH FORK             1.0            CODWR
# 857390                           COAL CREEK             1.0            CODWR
# 857391                    UNCOMPAHGRE RIVER             1.0            CODWR
# 857392          SOUTH FORK SAN MIGUEL RIVER             1.0            CODWR
# 857393          SOUTH FORK SAN MIGUEL RIVER             1.0            CODWR
#
#        State
# 0         UT
# 1         UT
# 2         UT
# 3         UT
# 4         UT
# ...      ...
# 857389    CO
# 857390    CO
# 857391    CO
# 857392    CO
# 857393    CO
#
# [857394 rows x 19 columns]

# %%
SiteWSWCBenUseDict = {
"Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Commercial" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Domestic" : "Domestic",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 multiple domestic households" : "Domestic",
"Mobile home parks" : "Domestic",
"Subdivision" : "Domestic",
"Household Use Only" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic Storage" : "Domestic",
"Public utility" : "Domestic",
"Minimum Streamflow" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Lake Level Maintenance" : "Environmental",
"Minimum Stream Flow" : "Environmental",
"Mitigation" : "Environmental",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"Pollution control well" : "Environmental",
"Pollution Abatement" : "Environmental",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Flood Control Storage" : "Flood Control",
"Flood Control" : "Flood Control",
"Industrial" : "Industrial",
"Cemetery" : "Industrial",
"Construction" : "Industrial",
"Dairy operation" : "Industrial",
"Domestic construction" : "Industrial",
"Highway construction" : "Industrial",
"Oil production" : "Industrial",
"Poultry and egg operation" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Irrigation From Storage" : "Industrial",
"72-12-1 Construction of public works" : "Industrial",
"Petroleum processing plant" : "Industrial",
"Secondary recovery of oil" : "Industrial",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"72-12-1 livestock watering" : "Livestock",
"Stock" : "Livestock",
"Stockwatering" : "Livestock",
"Mining" : "Mining",
"Mining From Storage" : "Mining",
"Mining Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Municipal" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal Storage" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Geothermal" : "Power",
"Power From Storage" : "Power",
"Power Storage" : "Power",
"Geothermal boreholes" : "Power",
"Power" : "Power",
"Power Generation" : "Power",
"Recharge" : "Recharge",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreation" : "Recreation",
"Snow Making" : "Snow Making",
"Storage" : "Storage",
"Fishery" : "Wildlife",
"Fish Habitat" : "Wildlife",
"Fish Habitat Storage" : "Wildlife",
"Fish Propagation" : "Wildlife",
"Fish Propagation From Storage" : "Wildlife",
"Fish Propagation Storage" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife" : "Wildlife",
"Fish And Wildlife" : "Wildlife",
"Fish and game propogation" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = SiteWSWCBenUseDict[String1]
        except:
            outList = "State Specific"
    return outList

dfsite['WSWCBeneficialUse'] = dfsite.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#Site Map Color per point
#Mapdeck uses a build color pacakge called 'colourvalues library', which does use HEX color code, but has to end in an "FF".
WSWCBenUseColorDict = { 
"Agricultural" : "#FFFF00FF",
"Commercial" : "#008000FF",
"Domestic" : "#0000FFFF",
"Environmental" : "#32CD32FF",
"Fire" : "#FF0000FF",
"Flood Control" : "#00FFFFFF",
"Industrial" : "#800080FF",
"Livestock" : "#FFD700FF",
"Mining" : "#A52A2AFF",
"Municipal" : "#4B0082FF",
"Power" : "#FFA500FF",
"Recharge" : "#D2691EFF",
"Recreation" : "#FFC0CBFF",
"Snow Making" : "#F0FFF0FF",
"Storage" : "#F5DEB3FF",
"Wildlife" : "#ADFF2FFF",
"State Specific" : "#808080FF"}
 
def assignWSWCBUColor(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "#708090"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = WSWCBenUseColorDict[String1]
        except:
            outList = "#708090"
    return outList

dfsite['WBenUseColor'] = dfsite.apply(lambda row: assignWSWCBUColor(row['WSWCBeneficialUse']), axis=1)

# %%
#Sort by SiteUUID and BenUse (this way Agriculture should show up first in the below list)
dfsite = dfsite.sort_values(by=['SiteUUID', 'WSWCBeneficialUse'], ascending=True).reset_index()
dfsite
# Out:
#          index   SiteID  SiteUUID   Longitude   Latitude AllocationNativeID  \
# 0       923167  3187043      CA_1 -124.100000  40.963100            A010767
# 1       923168  3187044     CA_10 -121.173807  39.875367            A014760
# 2       923169  3187045   CA_1000 -122.716594  41.730083            A021986
# 3       923170  3187046  CA_10000 -120.647606  40.636866            C000897
# 4       923171  3187047  CA_10001 -120.895545  38.450445            C000934
# ...        ...      ...       ...         ...        ...                ...
# 857389  772111  2865678  WA_99789 -120.672160  47.558204        4.73623e+06
# 857390  772118  2865685  WA_99815 -122.299651  48.128455        2.27416e+06
# 857391  772119  2865686  WA_99829 -122.224310  48.558903        2.27768e+06
# 857392  772120  2865687  WA_99830 -122.598476  47.365453        2.22324e+06
# 857393  772153  2865720  WA_99968 -117.496615  48.833648         2.1169e+06
#
#         AllocationAmountID  AllocationAmount  AllocationMaximum  \
# 0                1334631.0               NaN                0.0
# 1                1336239.0               NaN                0.0
# 2                1340317.0               NaN                0.0
# 3                1346778.0               NaN                0.0
# 4                1346815.0               NaN                0.0
# ...                    ...               ...                ...
# 857389           1051201.0         42.000000            27482.0
# 857390           1042284.0          0.005000                1.0
# 857391           1044223.0          0.020000                NaN
# 857392           1040767.0          2.228009             1000.0
# 857393           1016274.0          0.220000               42.0
#
#         IrrigatedAcreage  ...  PrimaryUseCategoryCV   BeneficialUseCV  \
# 0                   0.00  ...            Irrigation          Domestic
# 1                   0.00  ...            Irrigation          Domestic
# 2                   0.00  ...            Irrigation          Domestic
# 3                   0.00  ...            Irrigation     Stockwatering
# 4                   0.00  ...            Irrigation     Stockwatering
# ...                  ...  ...                   ...               ...
# 857389               NaN  ...            Irrigation  Fish Propagation
# 857390              0.25  ...            Irrigation        Irrigation
# 857391             20.00  ...            Irrigation        Irrigation
# 857392               NaN  ...            Irrigation         Municipal
# 857393             10.00  ...            Irrigation        Irrigation
#
#               Date WaterSourceID  WaterSourceName OrganizationID  \
# 0       1944-02-14      546831.0             UNSP           17.0
# 1       1952-04-17      546831.0             UNSP           17.0
# 2       1964-12-01      546829.0         UNSP (2)           17.0
# 3       1977-09-07      546844.0             UNST           17.0
# 4       1977-09-21      546844.0             UNST           17.0
# ...            ...           ...              ...            ...
# 857389  2011-05-16      462900.0      Unspecified           11.0
# 857390  1972-06-29      462900.0      Unspecified           11.0
# 857391  1931-01-19      462900.0      Unspecified           11.0
# 857392  2000-08-30      462901.0      Unspecified           11.0
# 857393  1975-01-01      462900.0      Unspecified           11.0
#
#         OrganizationUUID State WSWCBeneficialUse WBenUseColor
# 0                 CSWRCB    CA          Domestic    #0000FFFF
# 1                 CSWRCB    CA          Domestic    #0000FFFF
# 2                 CSWRCB    CA          Domestic    #0000FFFF
# 3                 CSWRCB    CA         Livestock    #FFD700FF
# 4                 CSWRCB    CA         Livestock    #FFD700FF
# ...                  ...   ...               ...          ...
# 857389              WSDE    WA          Wildlife    #ADFF2FFF
# 857390              WSDE    WA      Agricultural    #FFFF00FF
# 857391              WSDE    WA      Agricultural    #FFFF00FF
# 857392              WSDE    WA         Municipal    #4B0082FF
# 857393              WSDE    WA      Agricultural    #FFFF00FF
#
# [857394 rows x 21 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfSite = pd.DataFrame()

#The Columns
outdfSite['SiteUUID'] = dfsite['SiteUUID'].astype(str) 
outdfSite['Lat'] = dfsite['Latitude'].astype(float) 
outdfSite['Long'] = dfsite['Longitude'].astype(float)
outdfSite['WBenUse'] = dfsite['WSWCBeneficialUse'].astype(str)
outdfSite['WBenUseColor'] = dfsite['WBenUseColor'].astype(str)

#Drop Duplicates - SiteUUID
outdfSite = outdfSite.drop_duplicates(['SiteUUID'], keep="first").reset_index(drop=True)

outdfSite
# Out:
#         SiteUUID        Lat        Long       WBenUse WBenUseColor
# 0           CA_1  40.963100 -124.100000      Domestic    #0000FFFF
# 1          CA_10  39.875367 -121.173807      Domestic    #0000FFFF
# 2        CA_1000  41.730083 -122.716594      Domestic    #0000FFFF
# 3       CA_10000  40.636866 -120.647606     Livestock    #FFD700FF
# 4       CA_10001  38.450445 -120.895545     Livestock    #FFD700FF
# ...          ...        ...         ...           ...          ...
# 690637  WA_99789  47.558204 -120.672160      Wildlife    #ADFF2FFF
# 690638  WA_99815  48.128455 -122.299651  Agricultural    #FFFF00FF
# 690639  WA_99829  48.558903 -122.224310  Agricultural    #FFFF00FF
# 690640  WA_99830  47.365453 -122.598476     Municipal    #4B0082FF
# 690641  WA_99968  48.833648 -117.496615  Agricultural    #FFFF00FF
#
# [690642 rows x 5 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfSite.to_csv('P_SiteLFAllo.csv', index=False)  # The output

# %% [markdown]
# ### Allo LF Site, for filtering and Table Return Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Allo LeftJoin Sites Input
AllofileInput = "dontopen_AlloLFSite.csv"
dfallo = pd.read_csv(AllofileInput)
dfallo
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          AllocationAmountID       AllocationNativeID  AllocationAmount  \
# 0                    530436                   00-190             0.000
# 1                    530437                   00-276             0.000
# 2                    530437                   00-276             0.000
# 3                    530438                  01-1059             0.000
# 4                    530438                  01-1059             0.000
# ...                     ...                      ...               ...
# 1057908             1713759      57656.0-0-C-3005293             0.222
# 1057909             1713760  21523.18388-0-C-3903956             0.000
# 1057910             1713761       8157.0-9-C-1200520             1.690
# 1057911             1713762       20560.0-0-C-100902           400.000
# 1057912             1713763      59017.0-0-C-1900830             1.000
#
#          AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                    0.476             0.000                     25998
# 1                   69.160            13.832                     23216
# 2                   69.160            13.832                     23216
# 3                    0.250             0.000                     25216
# 4                    0.250             0.000                     25216
# ...                    ...               ...                       ...
# 1057908              0.000               NaN                     18921
# 1057909              0.000               NaN                     20362
# 1057910              0.000               NaN                      1867
# 1057911              0.000               NaN                     11636
# 1057912              0.000               NaN                      3315
#
#         PrimaryUseCategoryCV BeneficialUseCV        Date     SiteID  \
# 0                 Irrigation             NaN  2003-05-28  1443486.0
# 1                 Irrigation             NaN  2003-09-11  1442882.0
# 2                 Irrigation             NaN  2003-09-11  1442883.0
# 3                 Irrigation           Other  1861-01-01  1448482.0
# 4                 Irrigation   Stockwatering  1861-01-01  1448482.0
# ...                      ...             ...         ...        ...
# 1057908           Irrigation             NaN  2007-11-09  3776548.0
# 1057909           Irrigation             NaN  1900-05-06  3777047.0
# 1057910           Irrigation             NaN  1872-05-01  3782862.0
# 1057911           Irrigation      Irrigation  1906-04-17  3785783.0
# 1057912           Irrigation         Storage  2011-08-01  3779589.0
#
#              SiteUUID   Longitude   Latitude  WaterSourceID  \
# 0        UTDWRE_14300 -111.764086  40.129009         395582
# 1        UTDWRE_13758 -111.896981  40.359477         395584
# 2        UTDWRE_13759 -111.929898  40.457153         395584
# 3        UTDWRE_18799 -109.273909  39.450597         397115
# 4        UTDWRE_18799 -109.273909  39.450597         397115
# ...               ...         ...        ...            ...
# 1057908     CO_121368 -107.848170  37.392177          40836
# 1057909     CO_121867 -108.085283  39.472796          42718
# 1057910     CO_127682 -105.275700  38.788897          38576
# 1057911     CO_130603 -104.624246  40.595127          38351
# 1057912     CO_124409 -104.792529  37.082782          40430
#
#                     WaterSourceName  OrganizationID OrganizationUUID State
# 0            Underground Water Well               3           UTDWRE    UT
# 1        Utah Lake and Jordan River               3           UTDWRE    UT
# 2        Utah Lake and Jordan River               3           UTDWRE    UT
# 3           Middle Canyon Reservoir               3           UTDWRE    UT
# 4           Middle Canyon Reservoir               3           UTDWRE    UT
# ...                             ...             ...              ...   ...
# 1057908   GROUNDWATER: ANIMAS RIVER               1            CODWR    CO
# 1057909             PARACHUTE CREEK               1            CODWR    CO
# 1057910              FOURMILE CREEK               1            CODWR    CO
# 1057911                   OWL CREEK               1            CODWR    CO
# 1057912            LORENCITO CANYON               1            CODWR    CO
#
# [1057913 rows x 18 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfallo = dfallo[(dfallo.WaterSourceName != 'test')]
dfallo = dfallo[dfallo['SiteUUID'].notna()]
dfallo = dfallo[dfallo['AllocationPriorityDateID'].notna()]
dfallo = dfallo[dfallo['BeneficialUseCV'].notna()]
dfallo = dfallo[dfallo['Longitude'].notna()]
dfallo = dfallo[dfallo['Latitude'].notna()]
dfallo.reset_index()
# Out:
#           index  AllocationAmountID   AllocationNativeID  AllocationAmount  \
# 0             3              530438              01-1059             0.000
# 1             4              530438              01-1059             0.000
# 2             5              530439              01-1070             0.001
# 3             6              530440              01-1077             0.000
# 4             7              530441              01-1083             0.000
# ...         ...                 ...                  ...               ...
# 857389  1057902             1713753  56044.0-0-C-5109119             0.000
# 857390  1057903             1713754  19083.0-0-C-6202013             0.000
# 857391  1057905             1713756   57463.0-0-C-815234             2.450
# 857392  1057911             1713762   20560.0-0-C-100902           400.000
# 857393  1057912             1713763  59017.0-0-C-1900830             1.000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                    0.25               0.0                     25216
# 1                    0.25               0.0                     25216
# 2                    0.00               0.0                      5742
# 3                    1.00               0.0                      1083
# 4                    1.00               0.0                      1083
# ...                   ...               ...                       ...
# 857389               0.00               NaN                      7854
# 857390               0.00               NaN                      3298
# 857391               0.00               NaN                      6350
# 857392               0.00               NaN                     11636
# 857393               0.00               NaN                      3315
#
#        PrimaryUseCategoryCV BeneficialUseCV        Date     SiteID  \
# 0                Irrigation           Other  1861-01-01  1448482.0
# 1                Irrigation   Stockwatering  1861-01-01  1448482.0
# 2                Irrigation        Domestic  1880-01-01  1448888.0
# 3                Irrigation   Stockwatering  1902-01-01  1448903.0
# 4                Irrigation   Stockwatering  1902-01-01  1447221.0
# ...                     ...             ...         ...        ...
# 857389           Irrigation    Augmentation  2003-06-11  3776788.0
# 857390           Irrigation      Irrigation  1902-04-01  3783708.0
# 857391           Irrigation    Augmentation  2007-04-30  3780193.0
# 857392           Irrigation      Irrigation  1906-04-17  3785783.0
# 857393           Irrigation         Storage  2011-08-01  3779589.0
#
#             SiteUUID   Longitude   Latitude  WaterSourceID  \
# 0       UTDWRE_18799 -109.273909  39.450597         397115
# 1       UTDWRE_18799 -109.273909  39.450597         397115
# 2       UTDWRE_19163 -109.296417  38.818917         381126
# 3       UTDWRE_19177 -109.682581  39.014020         395710
# 4       UTDWRE_17663 -109.298072  39.206648         395704
# ...              ...         ...        ...            ...
# 857389     CO_121608 -105.815685  39.960386          43312
# 857390     CO_128528 -107.157303  38.348835          43737
# 857391     CO_125013 -104.768761  39.416507          38359
# 857392     CO_130603 -104.624246  40.595127          38351
# 857393     CO_124409 -104.792529  37.082782          40430
#
#                         WaterSourceName  OrganizationID OrganizationUUID State
# 0               Middle Canyon Reservoir               3           UTDWRE    UT
# 1               Middle Canyon Reservoir               3           UTDWRE    UT
# 2                          Dewey Spring               3           UTDWRE    UT
# 3                          Unnamed Wash               3           UTDWRE    UT
# 4                        Unnamed Stream               3           UTDWRE    UT
# ...                                 ...             ...              ...   ...
# 857389                     FRASER RIVER               1            CODWR    CO
# 857390                    CEBOLLA CREEK               1            CODWR    CO
# 857391  GROUNDWATER: SOUTH PLATTE RIVER               1            CODWR    CO
# 857392                        OWL CREEK               1            CODWR    CO
# 857393                 LORENCITO CANYON               1            CODWR    CO
#
# [857394 rows x 19 columns]

# %%
#changing data type of 'Date' to datatype, then changing format of 'Date' to yyyy-mm-dd
dfallo['Date'] = pd.to_datetime(dfallo['Date'], errors = 'coerce')
dfallo['Date'] = pd.to_datetime(dfallo["Date"].dt.strftime('%m/%d/%Ym'))

# %%
#Removing NaN, and missing (999) values from AllocaitonAmount, AllocaitonMaxium, IrrigatedAcerage.
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].fillna(0)
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].replace(999, 0)

dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].fillna(0)
dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].replace(999, 0)

dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].fillna(0)
dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].replace(999, 0)

# %%
alloWSWCBenUseDict = {
"Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Commercial" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Domestic" : "Domestic",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 multiple domestic households" : "Domestic",
"Mobile home parks" : "Domestic",
"Subdivision" : "Domestic",
"Household Use Only" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic Storage" : "Domestic",
"Public utility" : "Domestic",
"Minimum Streamflow" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Lake Level Maintenance" : "Environmental",
"Minimum Stream Flow" : "Environmental",
"Mitigation" : "Environmental",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"Pollution control well" : "Environmental",
"Pollution Abatement" : "Environmental",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Flood Control Storage" : "Flood Control",
"Flood Control" : "Flood Control",
"Industrial" : "Industrial",
"Cemetery" : "Industrial",
"Construction" : "Industrial",
"Dairy operation" : "Industrial",
"Domestic construction" : "Industrial",
"Highway construction" : "Industrial",
"Oil production" : "Industrial",
"Poultry and egg operation" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Irrigation From Storage" : "Industrial",
"72-12-1 Construction of public works" : "Industrial",
"Petroleum processing plant" : "Industrial",
"Secondary recovery of oil" : "Industrial",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"72-12-1 livestock watering" : "Livestock",
"Stock" : "Livestock",
"Stockwatering" : "Livestock",
"Mining" : "Mining",
"Mining From Storage" : "Mining",
"Mining Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Municipal" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal Storage" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Geothermal" : "Power",
"Power From Storage" : "Power",
"Power Storage" : "Power",
"Geothermal boreholes" : "Power",
"Power" : "Power",
"Power Generation" : "Power",
"Recharge" : "Recharge",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreation" : "Recreation",
"Snow Making" : "Snow Making",
"Storage" : "Storage",
"Fishery" : "Wildlife",
"Fish Habitat" : "Wildlife",
"Fish Habitat Storage" : "Wildlife",
"Fish Propagation" : "Wildlife",
"Fish Propagation From Storage" : "Wildlife",
"Fish Propagation Storage" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife" : "Wildlife",
"Fish And Wildlife" : "Wildlife",
"Fish and game propogation" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = alloWSWCBenUseDict[String1]
        except:
            outList = "State Specific"
    return outList

dfallo['WSWCBeneficialUse'] = dfallo.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#Sort by AllocationAmountID and SiteUUID
dfallo = dfallo.sort_values(by=['AllocationAmountID', 'SiteUUID'], ascending=True).reset_index()
dfallo
# Out:
#           index  AllocationAmountID   AllocationNativeID  AllocationAmount  \
# 0             3              530438              01-1059             0.000
# 1             4              530438              01-1059             0.000
# 2             5              530439              01-1070             0.001
# 3             6              530440              01-1077             0.000
# 4             7              530441              01-1083             0.000
# ...         ...                 ...                  ...               ...
# 857389  1057902             1713753  56044.0-0-C-5109119             0.000
# 857390  1057903             1713754  19083.0-0-C-6202013             0.000
# 857391  1057905             1713756   57463.0-0-C-815234             2.450
# 857392  1057911             1713762   20560.0-0-C-100902           400.000
# 857393  1057912             1713763  59017.0-0-C-1900830             1.000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                    0.25               0.0                     25216
# 1                    0.25               0.0                     25216
# 2                    0.00               0.0                      5742
# 3                    1.00               0.0                      1083
# 4                    1.00               0.0                      1083
# ...                   ...               ...                       ...
# 857389               0.00               0.0                      7854
# 857390               0.00               0.0                      3298
# 857391               0.00               0.0                      6350
# 857392               0.00               0.0                     11636
# 857393               0.00               0.0                      3315
#
#        PrimaryUseCategoryCV BeneficialUseCV       Date     SiteID  \
# 0                Irrigation           Other 1861-01-01  1448482.0
# 1                Irrigation   Stockwatering 1861-01-01  1448482.0
# 2                Irrigation        Domestic 1880-01-01  1448888.0
# 3                Irrigation   Stockwatering 1902-01-01  1448903.0
# 4                Irrigation   Stockwatering 1902-01-01  1447221.0
# ...                     ...             ...        ...        ...
# 857389           Irrigation    Augmentation 2003-06-11  3776788.0
# 857390           Irrigation      Irrigation 1902-04-01  3783708.0
# 857391           Irrigation    Augmentation 2007-04-30  3780193.0
# 857392           Irrigation      Irrigation 1906-04-17  3785783.0
# 857393           Irrigation         Storage 2011-08-01  3779589.0
#
#             SiteUUID   Longitude   Latitude  WaterSourceID  \
# 0       UTDWRE_18799 -109.273909  39.450597         397115
# 1       UTDWRE_18799 -109.273909  39.450597         397115
# 2       UTDWRE_19163 -109.296417  38.818917         381126
# 3       UTDWRE_19177 -109.682581  39.014020         395710
# 4       UTDWRE_17663 -109.298072  39.206648         395704
# ...              ...         ...        ...            ...
# 857389     CO_121608 -105.815685  39.960386          43312
# 857390     CO_128528 -107.157303  38.348835          43737
# 857391     CO_125013 -104.768761  39.416507          38359
# 857392     CO_130603 -104.624246  40.595127          38351
# 857393     CO_124409 -104.792529  37.082782          40430
#
#                         WaterSourceName  OrganizationID OrganizationUUID  \
# 0               Middle Canyon Reservoir               3           UTDWRE
# 1               Middle Canyon Reservoir               3           UTDWRE
# 2                          Dewey Spring               3           UTDWRE
# 3                          Unnamed Wash               3           UTDWRE
# 4                        Unnamed Stream               3           UTDWRE
# ...                                 ...             ...              ...
# 857389                     FRASER RIVER               1            CODWR
# 857390                    CEBOLLA CREEK               1            CODWR
# 857391  GROUNDWATER: SOUTH PLATTE RIVER               1            CODWR
# 857392                        OWL CREEK               1            CODWR
# 857393                 LORENCITO CANYON               1            CODWR
#
#        State WSWCBeneficialUse
# 0         UT    State Specific
# 1         UT         Livestock
# 2         UT          Domestic
# 3         UT         Livestock
# 4         UT         Livestock
# ...      ...               ...
# 857389    CO    State Specific
# 857390    CO      Agricultural
# 857391    CO    State Specific
# 857392    CO      Agricultural
# 857393    CO           Storage
#
# [857394 rows x 20 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfallo = pd.DataFrame()

#The Columns
outdfallo['AA_ID'] = dfallo['AllocationAmountID'].astype(str) 
outdfallo['SiteUUID'] = dfallo['SiteUUID'].astype(str)
outdfallo['SN_ID'] = dfallo['AllocationNativeID'].astype(str) 
outdfallo['Lat'] = dfallo['Latitude'].astype(float) 
outdfallo['Long'] = dfallo['Longitude'].astype(float)
outdfallo['WBenUse'] = dfallo['WSWCBeneficialUse'].astype(str)
outdfallo['State'] = dfallo['State'].astype(str) 
outdfallo['AA_CFS'] = dfallo['AllocationAmount'].astype(float) 
outdfallo['AA_AF'] = dfallo['IrrigatedAcreage'].astype(float) 
outdfallo['AAM_AF'] = dfallo['AllocationMaximum'].astype(float) 
outdfallo['PD'] = dfallo['Date']
outdfallo['WSN'] = dfallo['WaterSourceName'].astype(str)

outdfallo
# Out:
#           AA_ID      SiteUUID                SN_ID        Lat        Long  \
# 0        530438  UTDWRE_18799              01-1059  39.450597 -109.273909
# 1        530438  UTDWRE_18799              01-1059  39.450597 -109.273909
# 2        530439  UTDWRE_19163              01-1070  38.818917 -109.296417
# 3        530440  UTDWRE_19177              01-1077  39.014020 -109.682581
# 4        530441  UTDWRE_17663              01-1083  39.206648 -109.298072
# ...         ...           ...                  ...        ...         ...
# 857389  1713753     CO_121608  56044.0-0-C-5109119  39.960386 -105.815685
# 857390  1713754     CO_128528  19083.0-0-C-6202013  38.348835 -107.157303
# 857391  1713756     CO_125013   57463.0-0-C-815234  39.416507 -104.768761
# 857392  1713762     CO_130603   20560.0-0-C-100902  40.595127 -104.624246
# 857393  1713763     CO_124409  59017.0-0-C-1900830  37.082782 -104.792529
#
#                WBenUse State   AA_CFS  AA_AF  AAM_AF         PD  \
# 0       State Specific    UT    0.000    0.0    0.25 1861-01-01
# 1            Livestock    UT    0.000    0.0    0.25 1861-01-01
# 2             Domestic    UT    0.001    0.0    0.00 1880-01-01
# 3            Livestock    UT    0.000    0.0    1.00 1902-01-01
# 4            Livestock    UT    0.000    0.0    1.00 1902-01-01
# ...                ...   ...      ...    ...     ...        ...
# 857389  State Specific    CO    0.000    0.0    0.00 2003-06-11
# 857390    Agricultural    CO    0.000    0.0    0.00 1902-04-01
# 857391  State Specific    CO    2.450    0.0    0.00 2007-04-30
# 857392    Agricultural    CO  400.000    0.0    0.00 1906-04-17
# 857393         Storage    CO    1.000    0.0    0.00 2011-08-01
#
#                                     WSN
# 0               Middle Canyon Reservoir
# 1               Middle Canyon Reservoir
# 2                          Dewey Spring
# 3                          Unnamed Wash
# 4                        Unnamed Stream
# ...                                 ...
# 857389                     FRASER RIVER
# 857390                    CEBOLLA CREEK
# 857391  GROUNDWATER: SOUTH PLATTE RIVER
# 857392                        OWL CREEK
# 857393                 LORENCITO CANYON
#
# [857394 rows x 12 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfallo.to_csv('P_AlloLFSite.csv', index=False)  # The output
