# %% [markdown]
# # Creating 2 Tables: Sites for Map, Allocations for Table

# %% [markdown]
# #### General Approach:
# 1) Read in csv sheet of data.  Export fields into new database.
# 2) Remove bad rows and elements.
# 3) Fix date datatype.
# 4) Include ID int value for beneficial use.
# 5) Fix and remove misisng or nan values for allocatoin flow and volume.
# 6) Remove duplicates based on AllocationNativeID.
# 7) Create API link for each siteUUID.
# 8) Export completed df as processed csv.
#
#
#
# #### Files Needed
# 1) dontopen_SiteLJAllow.csv
# 2) dontopen_AlloLFSite.csv

# %% [markdown]
# ### Sites LF Allow, for creating Site Points, Popups and Legend Colors on Map Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Sites LeftJoin Allo Input
SitefileInput = "dontopen_SiteLJAllow.csv"
dfsite = pd.read_csv(SitefileInput)
dfsite
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           SiteID  SiteUUID   Longitude   Latitude AllocationNativeID  \
# 0        4871731      CA_1 -124.100000  40.963100            A010767
# 1        4871732     CA_10 -121.173807  39.875367            A014760
# 2        4871733   CA_1000 -122.716594  41.730083            A021986
# 3        4871734  CA_10000 -120.647606  40.636866            C000897
# 4        4871735  CA_10001 -120.895545  38.450445            C000934
# ...          ...       ...         ...        ...                ...
# 1100995  5628773   WA_9995 -120.162283  46.016114        2.05850e+06
# 1100996  5628774   WA_9996 -120.162290  46.019457        2.05594e+06
# 1100997  5628775   WA_9997 -120.122189  46.021328        2.08828e+06
# 1100998  5628776   WA_9998 -120.122641  46.006227        2.07502e+06
# 1100999  5628777   WA_9999 -120.130926  46.008851        2.05128e+06
#
#          AllocationAmountID  AllocationAmount  AllocationMaximum  \
# 0                 2686353.0               NaN                0.0
# 1                 2685736.0               NaN                0.0
# 2                 2684961.0               NaN                0.0
# 3                 2698527.0               NaN                0.0
# 4                 2698264.0               NaN                0.0
# ...                     ...               ...                ...
# 1100995           3374421.0          0.000000             -999.0
# 1100996           3362641.0          0.011140                1.0
# 1100997           3381841.0          0.020000                0.2
# 1100998           3368483.0          0.015596                2.0
# 1100999           3380157.0          0.000000             -999.0
#
#          IrrigatedAcreage  AllocationPriorityDateID PrimaryUseCategoryCV  \
# 0                     0.0                   33567.0           Irrigation
# 1                     0.0                   22293.0           Irrigation
# 2                     0.0                    2282.0           Irrigation
# 3                     0.0                   11225.0           Irrigation
# 4                     0.0                   10198.0           Irrigation
# ...                   ...                       ...                  ...
# 1100995            -999.0                   12754.0           Irrigation
# 1100996            -999.0                    7776.0           Irrigation
# 1100997               0.0                    5707.0           Irrigation
# 1100998            -999.0                   20339.0           Irrigation
# 1100999            -999.0                    1425.0           Irrigation
#
#                BeneficialUseCV        Date  WaterSourceID WaterSourceName  \
# 0                     Domestic  1944-02-14       546831.0            UNSP
# 1                     Domestic  1952-04-17       546831.0            UNSP
# 2                     Domestic  1964-12-01       546829.0        UNSP (2)
# 3                Stockwatering  1977-09-07       546844.0            UNST
# 4                Stockwatering  1977-09-21       546844.0            UNST
# ...                        ...         ...            ...             ...
# 1100995            Stock water  1974-04-29       462900.0     Unspecified
# 1100996            Stock water  1946-10-01       462900.0     Unspecified
# 1100997            Stock water  1913-01-01       462901.0     Unspecified
# 1100998       Domestic general  1947-12-01       462900.0     Unspecified
# 1100999  No Purpose Identified  1974-06-01       462900.0     Unspecified
#
#          OrganizationID OrganizationUUID State
# 0                  17.0           CSWRCB    CA
# 1                  17.0           CSWRCB    CA
# 2                  17.0           CSWRCB    CA
# 3                  17.0           CSWRCB    CA
# 4                  17.0           CSWRCB    CA
# ...                 ...              ...   ...
# 1100995            11.0             WSDE    WA
# 1100996            11.0             WSDE    WA
# 1100997            11.0             WSDE    WA
# 1100998            11.0             WSDE    WA
# 1100999            11.0             WSDE    WA
#
# [1101000 rows x 18 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfsite = dfsite[(dfsite.WaterSourceName != 'test')]
dfsite = dfsite[dfsite['SiteUUID'].notna()]
dfsite = dfsite[dfsite['AllocationPriorityDateID'].notna()]
dfsite = dfsite[dfsite['BeneficialUseCV'].notna()]
dfsite = dfsite[dfsite['Longitude'].notna()]
dfsite = dfsite[dfsite['Latitude'].notna()]
dfsite.reset_index()
# Out:
#           index   SiteID  SiteUUID   Longitude   Latitude AllocationNativeID  \
# 0             0  4871731      CA_1 -124.100000  40.963100            A010767
# 1             1  4871732     CA_10 -121.173807  39.875367            A014760
# 2             2  4871733   CA_1000 -122.716594  41.730083            A021986
# 3             3  4871734  CA_10000 -120.647606  40.636866            C000897
# 4             4  4871735  CA_10001 -120.895545  38.450445            C000934
# ...         ...      ...       ...         ...        ...                ...
# 894370  1100995  5628773   WA_9995 -120.162283  46.016114        2.05850e+06
# 894371  1100996  5628774   WA_9996 -120.162290  46.019457        2.05594e+06
# 894372  1100997  5628775   WA_9997 -120.122189  46.021328        2.08828e+06
# 894373  1100998  5628776   WA_9998 -120.122641  46.006227        2.07502e+06
# 894374  1100999  5628777   WA_9999 -120.130926  46.008851        2.05128e+06
#
#         AllocationAmountID  AllocationAmount  AllocationMaximum  \
# 0                2686353.0               NaN                0.0
# 1                2685736.0               NaN                0.0
# 2                2684961.0               NaN                0.0
# 3                2698527.0               NaN                0.0
# 4                2698264.0               NaN                0.0
# ...                    ...               ...                ...
# 894370           3374421.0          0.000000             -999.0
# 894371           3362641.0          0.011140                1.0
# 894372           3381841.0          0.020000                0.2
# 894373           3368483.0          0.015596                2.0
# 894374           3380157.0          0.000000             -999.0
#
#         IrrigatedAcreage  AllocationPriorityDateID PrimaryUseCategoryCV  \
# 0                    0.0                   33567.0           Irrigation
# 1                    0.0                   22293.0           Irrigation
# 2                    0.0                    2282.0           Irrigation
# 3                    0.0                   11225.0           Irrigation
# 4                    0.0                   10198.0           Irrigation
# ...                  ...                       ...                  ...
# 894370            -999.0                   12754.0           Irrigation
# 894371            -999.0                    7776.0           Irrigation
# 894372               0.0                    5707.0           Irrigation
# 894373            -999.0                   20339.0           Irrigation
# 894374            -999.0                    1425.0           Irrigation
#
#               BeneficialUseCV        Date  WaterSourceID WaterSourceName  \
# 0                    Domestic  1944-02-14       546831.0            UNSP
# 1                    Domestic  1952-04-17       546831.0            UNSP
# 2                    Domestic  1964-12-01       546829.0        UNSP (2)
# 3               Stockwatering  1977-09-07       546844.0            UNST
# 4               Stockwatering  1977-09-21       546844.0            UNST
# ...                       ...         ...            ...             ...
# 894370            Stock water  1974-04-29       462900.0     Unspecified
# 894371            Stock water  1946-10-01       462900.0     Unspecified
# 894372            Stock water  1913-01-01       462901.0     Unspecified
# 894373       Domestic general  1947-12-01       462900.0     Unspecified
# 894374  No Purpose Identified  1974-06-01       462900.0     Unspecified
#
#         OrganizationID OrganizationUUID State
# 0                 17.0           CSWRCB    CA
# 1                 17.0           CSWRCB    CA
# 2                 17.0           CSWRCB    CA
# 3                 17.0           CSWRCB    CA
# 4                 17.0           CSWRCB    CA
# ...                ...              ...   ...
# 894370            11.0             WSDE    WA
# 894371            11.0             WSDE    WA
# 894372            11.0             WSDE    WA
# 894373            11.0             WSDE    WA
# 894374            11.0             WSDE    WA
#
# [894375 rows x 19 columns]

# %%
SiteWSWCBenUseDict = {
"100 Year Flood Flow" : "Flood Control",
"508-14" : "Other",
"72-12-1 Construction of public works" : "Industrial",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 livestock watering" : "Livestock",
"72-12-1 multiple domestic households" : "Domestic",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Administrative" : "Other",
"Aesthetic" : "Other",
"Aesthetic From Storage" : "Other",
"Aesthetic Storage" : "Other",
"Aesthetics" : "Other",
"Agricultural Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Agriculture Uses" : "Agricultural",
"Agricutural Spraying" : "Agricultural",
"Air Conditioning or Heating" : "Temperature Control",
"All Beneficial Uses" : "Other",
"Anadromous and Resident Fish Habitat (Instream)" : "Fish",
"Aquaculture" : "Aquaculture",
"Aquatic Habitat" : "Instream Flow",
"Aquatic Life Instream" : "Instream Flow",
"Augmentation" : "Other",
"Augmentation well" : "Environmental",
"Average Annual Flow" : "Environmental",
"Bankfull Flow" : "Environmental",
"Base Flow" : "Environmental",
"Brine production well" : "Environmental",
"Campsite" : "Recreation",
"Cathodic protection well" : "Other",
"Cemetery" : "Industrial",
"Channel Maintenance" : "Environmental",
"Closed file" : "Other",
"Commercial" : "Commercial",
"Commercial & indust" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"Commercial Uses" : "Commercial",
"Community type use - mdwca, private or commercial supplied" : "Commercial",
"Construction" : "Industrial",
"Cooling" : "Temperature Control",
"Cooling for indust proces" : "Temperature Control",
"Cooling From Storage" : "Temperature Control",
"Cooling Storage" : "Temperature Control",
"Cranberry" : "Agricultural",
"Cumulative Accretion To River" : "Environmental",
"Cumulative Depletion From River" : "Environmental",
"Dairy" : "Agricultural",
"Dairy Barn Uses" : "Agricultural",
"Dairy operation" : "Industrial",
"Dewatering" : "Other",
"Dewatering well" : "Other",
"Diversion To Storage" : "Other",
"Domestic" : "Domestic",
"Domestic and Livestock" : "Domestic",
"Domestic construction" : "Domestic",
"Domestic Expanded" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic general" : "Domestic",
"Domestic Including Lawn and Garden" : "Domestic",
"Domestic multiple" : "Domestic",
"Domestic single" : "Domestic",
"Domestic Storage" : "Domestic",
"Dust Control" : "Environmental",
"Environmental quality" : "Environmental",
"Erosion Control" : "Environmental",
"Evaporative" : "Other",
"Exploration" : "Other",
"Export From Basin" : "Other",
"Export From State" : "Other",
"Federal Reserved" : "Other",
"Federal Reserved Use" : "Other",
"Feed pen operation" : "Agricultural",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection (Instream)" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Fish and game propogation" : "Fish",
"Fish And Wildlife" : "Fish",
"Fish and Wildlife Preservation and Enhancement" : "Fish",
"Fish Culture" : "Fish",
"Fish Habitat" : "Fish",
"Fish Habitat From Storage" : "Fish",
"Fish Habitat Storage" : "Fish",
"Fish Propagation" : "Fish",
"Fish Propagation From Storage" : "Fish",
"Fish Propagation Storage" : "Fish",
"Fish Raceways" : "Fish",
"Fishery" : "Fish",
"Fishery Enhancement (Instream)" : "Fish",
"Flood Control" : "Flood Control",
"Flood Control Storage" : "Flood Control",
"Flow Augmentation" : "Flood Control",
"Flow Through Fish Pond" : "Flood Control",
"Forest Management" : "Other",
"Frost Protection" : "Environmental",
"Geothermal" : "Power",
"Geo-Thermal (Heating & Cooling)" : "Temperature Control",
"Geothermal boreholes" : "Power",
"Geothermal Heating" : "Temperature Control",
"Geo-Thermal(Energy Production)" : "Temperature Control",
"Greenhouse" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Groundwater Aquifer Storage & Recovery" : "Storage",
"Groundwater Preservation" : "Storage",
"Group Domestic" : "Domestic",
"Harvesting of Cranberries" : "Agricultural",
"Heat Control" : "Temperature Control",
"Heat Exchange" : "Temperature Control",
"Heat protection for crops" : "Temperature Control",
"Heating" : "Temperature Control",
"Heating From Storage" : "Temperature Control",
"Heating Storage" : "Temperature Control",
"Highway" : "Industrial",
"Highway construction" : "Industrial",
"Household Use Only" : "Domestic",
"Human Consumption" : "Domestic",
"Human Consumption and Livestock" : "Domestic",
"Incidental Power" : "Power",
"Individual Irrigation" : "Agricultural",
"Industrial" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Industrial/Manufacturing Uses" : "Industrial",
"Injection" : "Other",
"Institutional" : "Domestic",
"Instream Flow" : "Instream Flow",
"Irrigated agriculture_ground" : "Agricultural",
"Irrigated agriculture_reuse" : "Agricultural",
"Irrigated agriculture_surface" : "Agricultural",
"Irrigation" : "Agricultural",
"Irrigation and Domestic" : "Agricultural",
"Irrigation and Livestock" : "Agricultural",
"Irrigation From Storage" : "Industrial",
"Irrigation Livestock and Domestic" : "Agricultural",
"Irrigation of Cranberries" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Irrigation Unknown" : "Agricultural",
"Laboratory" : "Other",
"Lake Level Maintenance" : "Environmental",
"Lawn And Garden" : "Domestic",
"Livestock" : "Agricultural",
"Livestock and Wildlife" : "Agricultural",
"Livestock_ground" : "Agricultural",
"Livestock_reuse" : "Agricultural",
"Livestock_surface" : "Agricultural",
"Log Deck Sprinkling" : "Industrial",
"Manufacturing" : "Industrial",
"Manufacturing_ground" : "Industrial",
"Manufacturing_reuse" : "Industrial",
"Manufacturing_surface" : "Industrial",
"Meat packing plant" : "Industrial",
"Military - military installations" : "Other",
"Milling" : "Industrial",
"Minimum Stream Flow" : "Environmental",
"Minimum Stream Flow From Storage" : "Environmental",
"Minimum Stream Flow Storage" : "Environmental",
"Minimum Streamflow" : "Environmental",
"Mining" : "Mining",
"Mining From Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Mining Storage" : "Mining",
"Mining_ground" : "Mining",
"Mining_reuse" : "Mining",
"Mining_surface" : "Mining",
"Mitigation" : "Environmental",
"Mitigation By Delivery" : "Flood Control",
"Mitigation By Delivery From Storage" : "Flood Control",
"Mitigation By Delivery Storage" : "Flood Control",
"Mitigation By NonUse" : "Flood Control",
"Mobile home parks" : "Domestic",
"Monitoring well" : "Other",
"Multiple Domestic" : "Domestic",
"Multiple Instream Uses" : "Instream Flow",
"Multiple Purpose" : "Other",
"Multiple Use" : "Other",
"Municipal" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal inter-tie system" : "Other",
"Municipal Storage" : "Municipal",
"Municipal Uses" : "Municipal",
"Municipal_ground" : "Municipal",
"Municipal_reuse" : "Municipal",
"Municipal_surface" : "Municipal",
"Navigation" : "Other",
"Net Effect On River" : "Environmental",
"No pre-1907 water right exists on this land" : "Other",
"No Purpose Identified" : "Unknown",
"No right" : "Unknown",
"No use of right or POD" : "Unknown",
"Non 72-12-1 domestic and livestock watering" : "Other",
"Non 72-12-1 domestic one household" : "Other",
"Non 72-12-1 livestock watering" : "Other",
"Non 72-12-1 multiple domestic households" : "Other",
"Non-profit organizational use" : "Other",
"Nursery Uses" : "Agricultural",
"Observation" : "Other",
"Observation And Testing" : "Other",
"Oil field maintenance" : "Industrial",
"Oil production" : "Industrial",
"Oil Well Flooding" : "Industrial",
"Other" : "Other",
"Other Purpose" : "Other",
"Parks and Recreation" : "Recreation",
"Petroleum processing plant" : "Industrial",
"Pollution Abatement" : "Instream Flow",
"Pollution Abatement (Instream)" : "Instream Flow",
"Pollution control well" : "Instream Flow",
"Pond Maintenance" : "Municipal",
"Poultry and egg operation" : "Industrial",
"Power" : "Power",
"Power Development" : "Power",
"Power From Storage" : "Power",
"Power Generation" : "Power",
"Power Generation Nonconsumptive" : "Power",
"POWER GENERATION, NONCONSUMPTIVE" : "Power",
"Power Storage" : "Power",
"Practicably Irrigable Acreage" : "Agricultural",
"Primary and Supplemental Irrigation" : "Agricultural",
"Public Supply" : "Domestic",
"Public utility" : "Domestic",
"Quasi-Municipal Uses" : "Other",
"Railway" : "Industrial",
"Ram" : "Industrial",
"Recharge" : "Recharge",
"Recharge For Irrigation" : "Agricultural",
"Recreation" : "Recreation",
"Recreation - beautification" : "Recreation",
"Recreation Fish Wildlife" : "Fish",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreational" : "Recreation",
"Required (unique)" : "",
"Restroom" : "Municipal",
"Riparian Habitat (Instream)" : "Instream Flow",
"Riparian Habitat Restoration Project" : "Instream Flow",
"Riparian Maintenance" : "Instream Flow",
"Road Construction" : "Industrial",
"Rural Water" : "Domestic",
"Sale" : "Commercial",
"Sawmill" : "Industrial",
"School use - public, private, parochial, & universities" : "Municipal",
"Secondary recovery of oil" : "Industrial",
"Sediment Control" : "Environmental",
"See Remarks" : "Other",
"Shop" : "Commercial",
"Snow Making" : "Snow Making",
"Stacked water right" : "Other",
"Steam-Electric Power_ground" : "Power",
"Steam-Electric Power_reuse" : "Power",
"Steam-Electric Power_surface" : "Power",
"Stock" : "Livestock",
"Stock water" : "Livestock",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"Stockwatering" : "Livestock",
"Storage" : "Storage",
"Strategic water reserve" : "Storage",
"Stream augmentation" : "Flood Control",
"Streamflow Maintenance From Storage" : "Storage",
"Streamflow Maintenance Storage" : "Storage",
"Subdivision" : "Domestic",
"Subirrigation" : "Agricultural",
"Supplemental Flood Harvesting" : "Flood Control",
"Supplemental Irrigation" : "Agricultural",
"Swimming" : "Recreation",
"Temperature Control" : "Temperature Control",
"Test Well" : "Other",
"To be determined" : "Unknown",
"Transmountain Export" : "Other",
"Trust water, Permanent" : "Other",
"Trust water, Temporary" : "Other",
"Unknown" : "Unknown",
"Use in a Mint Still" : "Industrial",
"Use Within a School" : "Municipal",
"Water Fowl" : "Wildlife",
"Water Quality Improvement" : "Environmental",
"Water Quality Improvement From Storage" : "Environmental",
"Water Quality Improvement Storage" : "Environmental",
"Wild And Scenic River" : "Wildlife",
"Wildlife" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife refuge" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife Waterfowl" : "Wildlife",
"WILDLIFE/WATERFOWL" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = SiteWSWCBenUseDict[String1]
        except:
            outList = "State Specific"
    return outList

dfsite['WSWCBeneficialUse'] = dfsite.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#Site Map Color per point
#Mapdeck uses a build color pacakge called 'colourvalues library', which does use HEX color code, but has to end in an "FF".
WSWCBenUseColorDict = { 
"Agricultural" : "#006400FF",
"Aquaculture" : "#9ACD32FF",
"Commercial" : "#FFFF00FF",
"Domestic" : "#0000FFFF",
"Environmental" : "#32CD32FF",
"Fire" : "#FF0000FF",
"Fish" : "#9370DBFF",
"Flood Control" : "#00FFFFFF",
"Industrial" : "#800080FF",
"Instream Flow" : "#87CEEBFF",
"Livestock" : "#FFD700FF",
"Mining" : "#A52A2AFF",
"Municipal" : "#4B0082FF",
"Power" : "#FFA500FF",
"Recharge" : "#D2691EFF",
"Recreation" : "#FFC0CBFF",
"Snow Making" : "#F0FFF0FF",
"Storage" : "#F5DEB3FF",
"Wildlife" : "#ADFF2FFF",
"State Specific" : "#808080FF",
"Temperature Control" : "#FF69B4FF",
"Unknown" : "#D3D3D3FF"}
 
def assignWSWCBUColor(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return "#D3D3D3FF"
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = WSWCBenUseColorDict[String1]
        except:
            outList = "#D3D3D3FF"
    return outList

dfsite['WBenUseColor'] = dfsite.apply(lambda row: assignWSWCBUColor(row['WSWCBeneficialUse']), axis=1)

# %%
#Sort by SiteUUID and BenUse (this way Agriculture should show up first in the below list)
dfsite = dfsite.sort_values(by=['SiteUUID', 'WSWCBeneficialUse'], ascending=True).reset_index()
dfsite
# Out:
#           index   SiteID  SiteUUID   Longitude   Latitude AllocationNativeID  \
# 0             0  4871731      CA_1 -124.100000  40.963100            A010767
# 1             1  4871732     CA_10 -121.173807  39.875367            A014760
# 2             2  4871733   CA_1000 -122.716594  41.730083            A021986
# 3             3  4871734  CA_10000 -120.647606  40.636866            C000897
# 4             4  4871735  CA_10001 -120.895545  38.450445            C000934
# ...         ...      ...       ...         ...        ...                ...
# 894370  1100995  5628773   WA_9995 -120.162283  46.016114        2.05850e+06
# 894371  1100996  5628774   WA_9996 -120.162290  46.019457        2.05594e+06
# 894372  1100997  5628775   WA_9997 -120.122189  46.021328        2.08828e+06
# 894373  1100998  5628776   WA_9998 -120.122641  46.006227        2.07502e+06
# 894374  1100999  5628777   WA_9999 -120.130926  46.008851        2.05128e+06
#
#         AllocationAmountID  AllocationAmount  AllocationMaximum  \
# 0                2686353.0               NaN                0.0
# 1                2685736.0               NaN                0.0
# 2                2684961.0               NaN                0.0
# 3                2698527.0               NaN                0.0
# 4                2698264.0               NaN                0.0
# ...                    ...               ...                ...
# 894370           3374421.0          0.000000             -999.0
# 894371           3362641.0          0.011140                1.0
# 894372           3381841.0          0.020000                0.2
# 894373           3368483.0          0.015596                2.0
# 894374           3380157.0          0.000000             -999.0
#
#         IrrigatedAcreage  ...  PrimaryUseCategoryCV        BeneficialUseCV  \
# 0                    0.0  ...            Irrigation               Domestic
# 1                    0.0  ...            Irrigation               Domestic
# 2                    0.0  ...            Irrigation               Domestic
# 3                    0.0  ...            Irrigation          Stockwatering
# 4                    0.0  ...            Irrigation          Stockwatering
# ...                  ...  ...                   ...                    ...
# 894370            -999.0  ...            Irrigation            Stock water
# 894371            -999.0  ...            Irrigation            Stock water
# 894372               0.0  ...            Irrigation            Stock water
# 894373            -999.0  ...            Irrigation       Domestic general
# 894374            -999.0  ...            Irrigation  No Purpose Identified
#
#               Date WaterSourceID  WaterSourceName OrganizationID  \
# 0       1944-02-14      546831.0             UNSP           17.0
# 1       1952-04-17      546831.0             UNSP           17.0
# 2       1964-12-01      546829.0         UNSP (2)           17.0
# 3       1977-09-07      546844.0             UNST           17.0
# 4       1977-09-21      546844.0             UNST           17.0
# ...            ...           ...              ...            ...
# 894370  1974-04-29      462900.0      Unspecified           11.0
# 894371  1946-10-01      462900.0      Unspecified           11.0
# 894372  1913-01-01      462901.0      Unspecified           11.0
# 894373  1947-12-01      462900.0      Unspecified           11.0
# 894374  1974-06-01      462900.0      Unspecified           11.0
#
#         OrganizationUUID State WSWCBeneficialUse WBenUseColor
# 0                 CSWRCB    CA          Domestic    #0000FFFF
# 1                 CSWRCB    CA          Domestic    #0000FFFF
# 2                 CSWRCB    CA          Domestic    #0000FFFF
# 3                 CSWRCB    CA         Livestock    #FFD700FF
# 4                 CSWRCB    CA         Livestock    #FFD700FF
# ...                  ...   ...               ...          ...
# 894370              WSDE    WA         Livestock    #FFD700FF
# 894371              WSDE    WA         Livestock    #FFD700FF
# 894372              WSDE    WA         Livestock    #FFD700FF
# 894373              WSDE    WA          Domestic    #0000FFFF
# 894374              WSDE    WA           Unknown    #D3D3D3FF
#
# [894375 rows x 21 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfSite = pd.DataFrame()

#The Columns
outdfSite['SiteUUID'] = dfsite['SiteUUID'].astype(str) 
outdfSite['Lat'] = dfsite['Latitude'].astype(float) 
outdfSite['Long'] = dfsite['Longitude'].astype(float)
outdfSite['WBenUse'] = dfsite['WSWCBeneficialUse'].astype(str)
outdfSite['WBenUseColor'] = dfsite['WBenUseColor'].astype(str)

#Drop Duplicates - SiteUUID
outdfSite = outdfSite.drop_duplicates(['SiteUUID'], keep="first").reset_index(drop=True)

outdfSite
# Out:
#         SiteUUID        Lat        Long    WBenUse WBenUseColor
# 0           CA_1  40.963100 -124.100000   Domestic    #0000FFFF
# 1          CA_10  39.875367 -121.173807   Domestic    #0000FFFF
# 2        CA_1000  41.730083 -122.716594   Domestic    #0000FFFF
# 3       CA_10000  40.636866 -120.647606  Livestock    #FFD700FF
# 4       CA_10001  38.450445 -120.895545  Livestock    #FFD700FF
# ...          ...        ...         ...        ...          ...
# 662394   WA_9995  46.016114 -120.162283  Livestock    #FFD700FF
# 662395   WA_9996  46.019457 -120.162290  Livestock    #FFD700FF
# 662396   WA_9997  46.021328 -120.122189  Livestock    #FFD700FF
# 662397   WA_9998  46.006227 -120.122641   Domestic    #0000FFFF
# 662398   WA_9999  46.008851 -120.130926    Unknown    #D3D3D3FF
#
# [662399 rows x 5 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfSite.to_csv('P_SiteLFAllo.csv', index=False)  # The output

# %% [markdown]
# ### Allo LF Site, for filtering and Table Return Only

# %%
#Needed Libaraies
import os
import numpy as np
import pandas as pd

#Setting work directory, reading inputs, creating dataframe
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
#Allo LeftJoin Sites Input
AllofileInput = "dontopen_AlloLFSite.csv"
dfallo = pd.read_csv(AllofileInput)
dfallo
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        AllocationNativeID  AllocationAmountID  AllocationAmount  \
# 0                 A010767             2686353               NaN
# 1                 A014760             2685736               NaN
# 2                 A021986             2684961               NaN
# 3                 C000897             2698527               NaN
# 4                 C000934             2698264               NaN
# ...                   ...                 ...               ...
# 998479        2.05850e+06             3374421          0.000000
# 998480        2.05594e+06             3362641          0.011140
# 998481        2.08828e+06             3381841          0.020000
# 998482        2.07502e+06             3368483          0.015596
# 998483        2.05128e+06             3380157          0.000000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                     0.0               0.0                     33567
# 1                     0.0               0.0                     22293
# 2                     0.0               0.0                      2282
# 3                     0.0               0.0                     11225
# 4                     0.0               0.0                     10198
# ...                   ...               ...                       ...
# 998479             -999.0            -999.0                     12754
# 998480                1.0            -999.0                      7776
# 998481                0.2               0.0                      5707
# 998482                2.0            -999.0                     20339
# 998483             -999.0            -999.0                      1425
#
#        PrimaryUseCategoryCV        BeneficialUseCV        Date   SiteID  \
# 0                Irrigation               Domestic  1944-02-14  4871731
# 1                Irrigation               Domestic  1952-04-17  4871732
# 2                Irrigation               Domestic  1964-12-01  4871733
# 3                Irrigation          Stockwatering  1977-09-07  4871734
# 4                Irrigation          Stockwatering  1977-09-21  4871735
# ...                     ...                    ...         ...      ...
# 998479           Irrigation            Stock water  1974-04-29  5628773
# 998480           Irrigation            Stock water  1946-10-01  5628774
# 998481           Irrigation            Stock water  1913-01-01  5628775
# 998482           Irrigation       Domestic general  1947-12-01  5628776
# 998483           Irrigation  No Purpose Identified  1974-06-01  5628777
#
#         SiteUUID   Longitude   Latitude  WaterSourceID WaterSourceName  \
# 0           CA_1 -124.100000  40.963100         546831            UNSP
# 1          CA_10 -121.173807  39.875367         546831            UNSP
# 2        CA_1000 -122.716594  41.730083         546829        UNSP (2)
# 3       CA_10000 -120.647606  40.636866         546844            UNST
# 4       CA_10001 -120.895545  38.450445         546844            UNST
# ...          ...         ...        ...            ...             ...
# 998479   WA_9995 -120.162283  46.016114         462900     Unspecified
# 998480   WA_9996 -120.162290  46.019457         462900     Unspecified
# 998481   WA_9997 -120.122189  46.021328         462901     Unspecified
# 998482   WA_9998 -120.122641  46.006227         462900     Unspecified
# 998483   WA_9999 -120.130926  46.008851         462900     Unspecified
#
#         OrganizationID OrganizationUUID State
# 0                   17           CSWRCB    CA
# 1                   17           CSWRCB    CA
# 2                   17           CSWRCB    CA
# 3                   17           CSWRCB    CA
# 4                   17           CSWRCB    CA
# ...                ...              ...   ...
# 998479              11             WSDE    WA
# 998480              11             WSDE    WA
# 998481              11             WSDE    WA
# 998482              11             WSDE    WA
# 998483              11             WSDE    WA
#
# [998484 rows x 18 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
dfallo = dfallo[(dfallo.WaterSourceName != 'test')]
dfallo = dfallo[dfallo['SiteUUID'].notna()]
dfallo = dfallo[dfallo['AllocationPriorityDateID'].notna()]
dfallo = dfallo[dfallo['BeneficialUseCV'].notna()]
dfallo = dfallo[dfallo['Longitude'].notna()]
dfallo = dfallo[dfallo['Latitude'].notna()]
dfallo.reset_index()
# Out:
#          index AllocationNativeID  AllocationAmountID  AllocationAmount  \
# 0            0            A010767             2686353               NaN
# 1            1            A014760             2685736               NaN
# 2            2            A021986             2684961               NaN
# 3            3            C000897             2698527               NaN
# 4            4            C000934             2698264               NaN
# ...        ...                ...                 ...               ...
# 894370  998479        2.05850e+06             3374421          0.000000
# 894371  998480        2.05594e+06             3362641          0.011140
# 894372  998481        2.08828e+06             3381841          0.020000
# 894373  998482        2.07502e+06             3368483          0.015596
# 894374  998483        2.05128e+06             3380157          0.000000
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                     0.0               0.0                     33567
# 1                     0.0               0.0                     22293
# 2                     0.0               0.0                      2282
# 3                     0.0               0.0                     11225
# 4                     0.0               0.0                     10198
# ...                   ...               ...                       ...
# 894370             -999.0            -999.0                     12754
# 894371                1.0            -999.0                      7776
# 894372                0.2               0.0                      5707
# 894373                2.0            -999.0                     20339
# 894374             -999.0            -999.0                      1425
#
#        PrimaryUseCategoryCV        BeneficialUseCV        Date   SiteID  \
# 0                Irrigation               Domestic  1944-02-14  4871731
# 1                Irrigation               Domestic  1952-04-17  4871732
# 2                Irrigation               Domestic  1964-12-01  4871733
# 3                Irrigation          Stockwatering  1977-09-07  4871734
# 4                Irrigation          Stockwatering  1977-09-21  4871735
# ...                     ...                    ...         ...      ...
# 894370           Irrigation            Stock water  1974-04-29  5628773
# 894371           Irrigation            Stock water  1946-10-01  5628774
# 894372           Irrigation            Stock water  1913-01-01  5628775
# 894373           Irrigation       Domestic general  1947-12-01  5628776
# 894374           Irrigation  No Purpose Identified  1974-06-01  5628777
#
#         SiteUUID   Longitude   Latitude  WaterSourceID WaterSourceName  \
# 0           CA_1 -124.100000  40.963100         546831            UNSP
# 1          CA_10 -121.173807  39.875367         546831            UNSP
# 2        CA_1000 -122.716594  41.730083         546829        UNSP (2)
# 3       CA_10000 -120.647606  40.636866         546844            UNST
# 4       CA_10001 -120.895545  38.450445         546844            UNST
# ...          ...         ...        ...            ...             ...
# 894370   WA_9995 -120.162283  46.016114         462900     Unspecified
# 894371   WA_9996 -120.162290  46.019457         462900     Unspecified
# 894372   WA_9997 -120.122189  46.021328         462901     Unspecified
# 894373   WA_9998 -120.122641  46.006227         462900     Unspecified
# 894374   WA_9999 -120.130926  46.008851         462900     Unspecified
#
#         OrganizationID OrganizationUUID State
# 0                   17           CSWRCB    CA
# 1                   17           CSWRCB    CA
# 2                   17           CSWRCB    CA
# 3                   17           CSWRCB    CA
# 4                   17           CSWRCB    CA
# ...                ...              ...   ...
# 894370              11             WSDE    WA
# 894371              11             WSDE    WA
# 894372              11             WSDE    WA
# 894373              11             WSDE    WA
# 894374              11             WSDE    WA
#
# [894375 rows x 19 columns]

# %%
#changing data type of 'Date' to datatype, then changing format of 'Date' to yyyy-mm-dd
dfallo['Date'] = pd.to_datetime(dfallo['Date'], errors = 'coerce')
dfallo['Date'] = pd.to_datetime(dfallo["Date"].dt.strftime('%m/%d/%Ym'))

# %%
#Removing NaN, and missing (999) values from AllocaitonAmount, AllocaitonMaxium, IrrigatedAcerage.
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].fillna(0)
dfallo['AllocationAmount'] = dfallo['AllocationAmount'].replace(999, 0)

dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].fillna(0)
dfallo['AllocationMaximum'] = dfallo['AllocationMaximum'].replace(999, 0)

dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].fillna(0)
dfallo['IrrigatedAcreage'] = dfallo['IrrigatedAcreage'].replace(999, 0)

# %%
alloWSWCBenUseDict = {
"100 Year Flood Flow" : "Flood Control",
"508-14" : "Other",
"72-12-1 Construction of public works" : "Industrial",
"72-12-1 domestic and livestock watering" : "Domestic",
"72-12-1 domestic one household" : "Domestic",
"72-12-1 livestock watering" : "Livestock",
"72-12-1 multiple domestic households" : "Domestic",
"72-12-1 Prospecting or development of natural resource" : "Environmental",
"72-12-1 Sanitary in conjunction with a commercial use" : "Commercial",
"Administrative" : "Other",
"Aesthetic" : "Other",
"Aesthetic From Storage" : "Other",
"Aesthetic Storage" : "Other",
"Aesthetics" : "Other",
"Agricultural Irrigation" : "Agricultural",
"Agriculture" : "Agricultural",
"Agriculture other than irrigation" : "Agricultural",
"Agriculture Uses" : "Agricultural",
"Agricutural Spraying" : "Agricultural",
"Air Conditioning or Heating" : "Temperature Control",
"All Beneficial Uses" : "Other",
"Anadromous and Resident Fish Habitat (Instream)" : "Fish",
"Aquaculture" : "Aquaculture",
"Aquatic Habitat" : "Instream Flow",
"Aquatic Life Instream" : "Instream Flow",
"Augmentation" : "Other",
"Augmentation well" : "Environmental",
"Average Annual Flow" : "Environmental",
"Bankfull Flow" : "Environmental",
"Base Flow" : "Environmental",
"Brine production well" : "Environmental",
"Campsite" : "Recreation",
"Cathodic protection well" : "Other",
"Cemetery" : "Industrial",
"Channel Maintenance" : "Environmental",
"Closed file" : "Other",
"Commercial" : "Commercial",
"Commercial & indust" : "Commercial",
"Commercial From Storage" : "Commercial",
"Commercial Storage" : "Commercial",
"Commercial Uses" : "Commercial",
"Community type use - mdwca, private or commercial supplied" : "Commercial",
"Construction" : "Industrial",
"Cooling" : "Temperature Control",
"Cooling for indust proces" : "Temperature Control",
"Cooling From Storage" : "Temperature Control",
"Cooling Storage" : "Temperature Control",
"Cranberry" : "Agricultural",
"Cumulative Accretion To River" : "Environmental",
"Cumulative Depletion From River" : "Environmental",
"Dairy" : "Agricultural",
"Dairy Barn Uses" : "Agricultural",
"Dairy operation" : "Industrial",
"Dewatering" : "Other",
"Dewatering well" : "Other",
"Diversion To Storage" : "Other",
"Domestic" : "Domestic",
"Domestic and Livestock" : "Domestic",
"Domestic construction" : "Domestic",
"Domestic Expanded" : "Domestic",
"Domestic From Storage" : "Domestic",
"Domestic general" : "Domestic",
"Domestic Including Lawn and Garden" : "Domestic",
"Domestic multiple" : "Domestic",
"Domestic single" : "Domestic",
"Domestic Storage" : "Domestic",
"Dust Control" : "Environmental",
"Environmental quality" : "Environmental",
"Erosion Control" : "Environmental",
"Evaporative" : "Other",
"Exploration" : "Other",
"Export From Basin" : "Other",
"Export From State" : "Other",
"Federal Reserved" : "Other",
"Federal Reserved Use" : "Other",
"Feed pen operation" : "Agricultural",
"Fire" : "Fire",
"Fire Protection" : "Fire",
"Fire Protection (Instream)" : "Fire",
"Fire Protection From Storage" : "Fire",
"Fire Protection Storage" : "Fire",
"Fish and game propogation" : "Fish",
"Fish And Wildlife" : "Fish",
"Fish and Wildlife Preservation and Enhancement" : "Fish",
"Fish Culture" : "Fish",
"Fish Habitat" : "Fish",
"Fish Habitat From Storage" : "Fish",
"Fish Habitat Storage" : "Fish",
"Fish Propagation" : "Fish",
"Fish Propagation From Storage" : "Fish",
"Fish Propagation Storage" : "Fish",
"Fish Raceways" : "Fish",
"Fishery" : "Fish",
"Fishery Enhancement (Instream)" : "Fish",
"Flood Control" : "Flood Control",
"Flood Control Storage" : "Flood Control",
"Flow Augmentation" : "Flood Control",
"Flow Through Fish Pond" : "Flood Control",
"Forest Management" : "Other",
"Frost Protection" : "Environmental",
"Geothermal" : "Power",
"Geo-Thermal (Heating & Cooling)" : "Temperature Control",
"Geothermal boreholes" : "Power",
"Geothermal Heating" : "Temperature Control",
"Geo-Thermal(Energy Production)" : "Temperature Control",
"Greenhouse" : "Environmental",
"Ground Water Recharge" : "Environmental",
"Ground Water Recharge From Storage" : "Environmental",
"Ground Water Recharge Storage" : "Environmental",
"Groundwater Aquifer Storage & Recovery" : "Storage",
"Groundwater Preservation" : "Storage",
"Group Domestic" : "Domestic",
"Harvesting of Cranberries" : "Agricultural",
"Heat Control" : "Temperature Control",
"Heat Exchange" : "Temperature Control",
"Heat protection for crops" : "Temperature Control",
"Heating" : "Temperature Control",
"Heating From Storage" : "Temperature Control",
"Heating Storage" : "Temperature Control",
"Highway" : "Industrial",
"Highway construction" : "Industrial",
"Household Use Only" : "Domestic",
"Human Consumption" : "Domestic",
"Human Consumption and Livestock" : "Domestic",
"Incidental Power" : "Power",
"Individual Irrigation" : "Agricultural",
"Industrial" : "Industrial",
"Industrial From Storage" : "Industrial",
"Industrial Storage" : "Industrial",
"Industrial/Manufacturing Uses" : "Industrial",
"Injection" : "Other",
"Institutional" : "Domestic",
"Instream Flow" : "Instream Flow",
"Irrigated agriculture_ground" : "Agricultural",
"Irrigated agriculture_reuse" : "Agricultural",
"Irrigated agriculture_surface" : "Agricultural",
"Irrigation" : "Agricultural",
"Irrigation and Domestic" : "Agricultural",
"Irrigation and Livestock" : "Agricultural",
"Irrigation From Storage" : "Industrial",
"Irrigation Livestock and Domestic" : "Agricultural",
"Irrigation of Cranberries" : "Agricultural",
"Irrigation Storage" : "Agricultural",
"Irrigation Unknown" : "Agricultural",
"Laboratory" : "Other",
"Lake Level Maintenance" : "Environmental",
"Lawn And Garden" : "Domestic",
"Livestock" : "Agricultural",
"Livestock and Wildlife" : "Agricultural",
"Livestock_ground" : "Agricultural",
"Livestock_reuse" : "Agricultural",
"Livestock_surface" : "Agricultural",
"Log Deck Sprinkling" : "Industrial",
"Manufacturing" : "Industrial",
"Manufacturing_ground" : "Industrial",
"Manufacturing_reuse" : "Industrial",
"Manufacturing_surface" : "Industrial",
"Meat packing plant" : "Industrial",
"Military - military installations" : "Other",
"Milling" : "Industrial",
"Minimum Stream Flow" : "Environmental",
"Minimum Stream Flow From Storage" : "Environmental",
"Minimum Stream Flow Storage" : "Environmental",
"Minimum Streamflow" : "Environmental",
"Mining" : "Mining",
"Mining From Storage" : "Mining",
"Mining or milling or oil" : "Mining",
"Mining Storage" : "Mining",
"Mining_ground" : "Mining",
"Mining_reuse" : "Mining",
"Mining_surface" : "Mining",
"Mitigation" : "Environmental",
"Mitigation By Delivery" : "Flood Control",
"Mitigation By Delivery From Storage" : "Flood Control",
"Mitigation By Delivery Storage" : "Flood Control",
"Mitigation By NonUse" : "Flood Control",
"Mobile home parks" : "Domestic",
"Monitoring well" : "Other",
"Multiple Domestic" : "Domestic",
"Multiple Instream Uses" : "Instream Flow",
"Multiple Purpose" : "Other",
"Multiple Use" : "Other",
"Municipal" : "Municipal",
"Municipal - city or county supplied water" : "Municipal",
"Municipal From Storage" : "Municipal",
"Municipal inter-tie system" : "Other",
"Municipal Storage" : "Municipal",
"Municipal Uses" : "Municipal",
"Municipal_ground" : "Municipal",
"Municipal_reuse" : "Municipal",
"Municipal_surface" : "Municipal",
"Navigation" : "Other",
"Net Effect On River" : "Environmental",
"No pre-1907 water right exists on this land" : "Other",
"No Purpose Identified" : "Unknown",
"No right" : "Unknown",
"No use of right or POD" : "Unknown",
"Non 72-12-1 domestic and livestock watering" : "Other",
"Non 72-12-1 domestic one household" : "Other",
"Non 72-12-1 livestock watering" : "Other",
"Non 72-12-1 multiple domestic households" : "Other",
"Non-profit organizational use" : "Other",
"Nursery Uses" : "Agricultural",
"Observation" : "Other",
"Observation And Testing" : "Other",
"Oil field maintenance" : "Industrial",
"Oil production" : "Industrial",
"Oil Well Flooding" : "Industrial",
"Other" : "Other",
"Other Purpose" : "Other",
"Parks and Recreation" : "Recreation",
"Petroleum processing plant" : "Industrial",
"Pollution Abatement" : "Instream Flow",
"Pollution Abatement (Instream)" : "Instream Flow",
"Pollution control well" : "Instream Flow",
"Pond Maintenance" : "Municipal",
"Poultry and egg operation" : "Industrial",
"Power" : "Power",
"Power Development" : "Power",
"Power From Storage" : "Power",
"Power Generation" : "Power",
"Power Generation Nonconsumptive" : "Power",
"POWER GENERATION, NONCONSUMPTIVE" : "Power",
"Power Storage" : "Power",
"Practicably Irrigable Acreage" : "Agricultural",
"Primary and Supplemental Irrigation" : "Agricultural",
"Public Supply" : "Domestic",
"Public utility" : "Domestic",
"Quasi-Municipal Uses" : "Other",
"Railway" : "Industrial",
"Ram" : "Industrial",
"Recharge" : "Recharge",
"Recharge For Irrigation" : "Agricultural",
"Recreation" : "Recreation",
"Recreation - beautification" : "Recreation",
"Recreation Fish Wildlife" : "Fish",
"Recreation From Storage" : "Recreation",
"Recreation Storage" : "Recreation",
"Recreational" : "Recreation",
"Required (unique)" : "",
"Restroom" : "Municipal",
"Riparian Habitat (Instream)" : "Instream Flow",
"Riparian Habitat Restoration Project" : "Instream Flow",
"Riparian Maintenance" : "Instream Flow",
"Road Construction" : "Industrial",
"Rural Water" : "Domestic",
"Sale" : "Commercial",
"Sawmill" : "Industrial",
"School use - public, private, parochial, & universities" : "Municipal",
"Secondary recovery of oil" : "Industrial",
"Sediment Control" : "Environmental",
"See Remarks" : "Other",
"Shop" : "Commercial",
"Snow Making" : "Snow Making",
"Stacked water right" : "Other",
"Steam-Electric Power_ground" : "Power",
"Steam-Electric Power_reuse" : "Power",
"Steam-Electric Power_surface" : "Power",
"Stock" : "Livestock",
"Stock water" : "Livestock",
"Stockwater" : "Livestock",
"Stockwater From Storage" : "Livestock",
"Stockwater Storage" : "Livestock",
"Stockwatering" : "Livestock",
"Storage" : "Storage",
"Strategic water reserve" : "Storage",
"Stream augmentation" : "Flood Control",
"Streamflow Maintenance From Storage" : "Storage",
"Streamflow Maintenance Storage" : "Storage",
"Subdivision" : "Domestic",
"Subirrigation" : "Agricultural",
"Supplemental Flood Harvesting" : "Flood Control",
"Supplemental Irrigation" : "Agricultural",
"Swimming" : "Recreation",
"Temperature Control" : "Temperature Control",
"Test Well" : "Other",
"To be determined" : "Unknown",
"Transmountain Export" : "Other",
"Trust water, Permanent" : "Other",
"Trust water, Temporary" : "Other",
"Unknown" : "Unknown",
"Use in a Mint Still" : "Industrial",
"Use Within a School" : "Municipal",
"Water Fowl" : "Wildlife",
"Water Quality Improvement" : "Environmental",
"Water Quality Improvement From Storage" : "Environmental",
"Water Quality Improvement Storage" : "Environmental",
"Wild And Scenic River" : "Wildlife",
"Wildlife" : "Wildlife",
"Wildlife From Storage" : "Wildlife",
"Wildlife refuge" : "Wildlife",
"Wildlife Storage" : "Wildlife",
"Wildlife Waterfowl" : "Wildlife",
"WILDLIFE/WATERFOWL" : "Wildlife"}


def assignWSWCBU(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        return np.nan
    else:
        String1 = colrowValue.strip()  # remove whitespace chars
        try:
            outList = alloWSWCBenUseDict[String1]
        except:
            outList = "State Specific"
    return outList

dfallo['WSWCBeneficialUse'] = dfallo.apply(lambda row: assignWSWCBU(row['BeneficialUseCV']), axis=1)

# %%
#Sort by AllocationAmountID and SiteUUID
dfallo = dfallo.sort_values(by=['AllocationAmountID', 'SiteUUID'], ascending=True).reset_index()
dfallo
# Out:
#          index AllocationNativeID  AllocationAmountID  AllocationAmount  \
# 0        11578            A000065             2683610             0.000
# 1         7385            A001880             2683611             0.000
# 2         9253            A005312             2683612             0.000
# 3        13823         A005648C06             2683613             0.000
# 4         3521            A008531             2683614             0.000
# ...        ...                ...                 ...               ...
# 894370  971492        5.44395e+06             3421572             0.000
# 894371  971494        5.44395e+06             3421572             0.000
# 894372  963161        4.74906e+06             3421573             0.013
# 894373  926256        4.50508e+06             3421574             0.011
# 894374  950410        2.27672e+06             3421575             0.800
#
#         AllocationMaximum  IrrigatedAcreage  AllocationPriorityDateID  \
# 0                   0.000              70.0                     41255
# 1                   0.000             414.0                     26615
# 2                   0.000             414.0                     38236
# 3                   0.000              11.0                     17082
# 4                   0.000               0.0                     28462
# ...                   ...               ...                       ...
# 894370           -999.000            -999.0                      9507
# 894371           -999.000            -999.0                      9507
# 894372              1.960            -999.0                     16571
# 894373              0.168            -999.0                     16229
# 894374           -999.000              80.0                     18283
#
#        PrimaryUseCategoryCV  BeneficialUseCV       Date   SiteID  SiteUUID  \
# 0                Irrigation       Irrigation 1915-07-03  4880882  CA_25641
# 1                Irrigation       Irrigation 1920-06-23  4877652  CA_20198
# 2                Irrigation       Irrigation 1926-12-16  4879307  CA_22990
# 3                Irrigation       Irrigation 1927-07-30  4882620  CA_28851
# 4                Irrigation         Domestic 1936-01-04  4874474  CA_14825
# ...                     ...              ...        ...      ...       ...
# 894370           Irrigation        Municipal 2012-10-10  5656052  WA_52275
# 894371           Irrigation        Municipal 2012-10-10  5656053  WA_52276
# 894372           Irrigation          Unknown 1870-06-30  5651410  WA_47633
# 894373           Irrigation  Domestic single 2008-05-19  5629445  WA_25668
# 894374           Irrigation       Irrigation 1949-06-29  5644066  WA_40289
#
#          Longitude   Latitude  WaterSourceID WaterSourceName  OrganizationID  \
# 0      -120.918501  41.099280         546826    WILLOW CREEK              17
# 1      -120.797137  41.777423         546826    WILLOW CREEK              17
# 2      -120.797137  41.777423         546826    WILLOW CREEK              17
# 3      -120.646455  38.179001         546826    WILLOW CREEK              17
# 4      -117.918670  36.839191         546826    WILLOW CREEK              17
# ...            ...        ...            ...             ...             ...
# 894370 -121.994668  47.468937         462900     Unspecified              11
# 894371 -121.994620  47.469105         462900     Unspecified              11
# 894372 -120.620815  46.553486         462901     Unspecified              11
# 894373 -122.018502  48.328529         462901     Unspecified              11
# 894374 -121.987028  47.690661         462901     Unspecified              11
#
#        OrganizationUUID State WSWCBeneficialUse
# 0                CSWRCB    CA      Agricultural
# 1                CSWRCB    CA      Agricultural
# 2                CSWRCB    CA      Agricultural
# 3                CSWRCB    CA      Agricultural
# 4                CSWRCB    CA          Domestic
# ...                 ...   ...               ...
# 894370             WSDE    WA         Municipal
# 894371             WSDE    WA         Municipal
# 894372             WSDE    WA           Unknown
# 894373             WSDE    WA          Domestic
# 894374             WSDE    WA      Agricultural
#
# [894375 rows x 20 columns]

# %%
## Create Sites Dataframe - with attached Allo and Benuse info ##
########################################
outdfallo = pd.DataFrame()

#The Columns
outdfallo['AA_ID'] = dfallo['AllocationAmountID'].astype(str) 
outdfallo['SiteUUID'] = dfallo['SiteUUID'].astype(str)
outdfallo['SN_ID'] = dfallo['AllocationNativeID'].astype(str) 
outdfallo['Lat'] = dfallo['Latitude'].astype(float) 
outdfallo['Long'] = dfallo['Longitude'].astype(float)
outdfallo['WBenUse'] = dfallo['WSWCBeneficialUse'].astype(str)
outdfallo['State'] = dfallo['State'].astype(str) 
outdfallo['AA_CFS'] = dfallo['AllocationAmount'].astype(float) 
outdfallo['AA_AF'] = dfallo['IrrigatedAcreage'].astype(float) 
outdfallo['AAM_AF'] = dfallo['AllocationMaximum'].astype(float) 
outdfallo['PD'] = dfallo['Date']
outdfallo['WSN'] = dfallo['WaterSourceName'].astype(str)

outdfallo
# Out:
#           AA_ID  SiteUUID       SN_ID        Lat        Long       WBenUse  \
# 0       2683610  CA_25641     A000065  41.099280 -120.918501  Agricultural
# 1       2683611  CA_20198     A001880  41.777423 -120.797137  Agricultural
# 2       2683612  CA_22990     A005312  41.777423 -120.797137  Agricultural
# 3       2683613  CA_28851  A005648C06  38.179001 -120.646455  Agricultural
# 4       2683614  CA_14825     A008531  36.839191 -117.918670      Domestic
# ...         ...       ...         ...        ...         ...           ...
# 894370  3421572  WA_52275   5443948.0  47.468937 -121.994668     Municipal
# 894371  3421572  WA_52276   5443948.0  47.469105 -121.994620     Municipal
# 894372  3421573  WA_47633   4749064.0  46.553486 -120.620815       Unknown
# 894373  3421574  WA_25668   4505080.0  48.328529 -122.018502      Domestic
# 894374  3421575  WA_40289   2276721.0  47.690661 -121.987028  Agricultural
#
#        State  AA_CFS  AA_AF   AAM_AF         PD           WSN
# 0         CA   0.000   70.0    0.000 1915-07-03  WILLOW CREEK
# 1         CA   0.000  414.0    0.000 1920-06-23  WILLOW CREEK
# 2         CA   0.000  414.0    0.000 1926-12-16  WILLOW CREEK
# 3         CA   0.000   11.0    0.000 1927-07-30  WILLOW CREEK
# 4         CA   0.000    0.0    0.000 1936-01-04  WILLOW CREEK
# ...      ...     ...    ...      ...        ...           ...
# 894370    WA   0.000 -999.0 -999.000 2012-10-10   Unspecified
# 894371    WA   0.000 -999.0 -999.000 2012-10-10   Unspecified
# 894372    WA   0.013 -999.0    1.960 1870-06-30   Unspecified
# 894373    WA   0.011 -999.0    0.168 2008-05-19   Unspecified
# 894374    WA   0.800   80.0 -999.000 1949-06-29   Unspecified
#
# [894375 rows x 12 columns]

# %%
#Exporting Outbound DataFrame to working csv file.
outdfallo.to_csv('P_AlloLFSite.csv', index=False)  # The output
