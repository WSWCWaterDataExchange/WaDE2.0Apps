# %% [markdown]
# # Pre-processing California Site Specific data for RShiny Visual Test.
# Date Updated: 11/17/2021
#
# Purpose:  To pre-process the site specific data for creating example visuals in RShiny.
#
# Notes:
# - asdf

# %%
# Needed Libararies
import os
import math
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

#Working Directory and Input File
workingDir = "C:/Users/rjame/Documents/RShinyAppPractice/App 3_SiteSpecificAmounts/MapSiteSpecific_ver3/NotEssentialData"
os.chdir(workingDir)

# %% [markdown]
# ###  SiteVariableAmounts_fact
# - Removing duplicate entries from the SiteVariableAmounts_fact.csv file.

# %%
# fileInput = "SiteVariableAmounts_fact.csv"
# df = pd.read_csv(fileInput)
# print(len(df))
# df.head()
# Out:
# 8933652
#    SiteVariableAmountID       Amount  PopulationServed  \
# 0               1708453  31302.17376               360
# 1               1708453  31302.17376               360
# 2               1708453  31302.17376               360
# 3               1708453  31302.17376               360
# 4               1708453  31302.17376               360
#
#                CommunityWaterSupplySystem  ReportYearCV SiteUUID SiteTypeCV  \
# 0  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 1  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 2  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 3  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 4  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
#
#   WaterSourceUUID WaterSourceTypeCV VariableCV    VariableSpecificCV  \
# 0        UTss_WS1     Surface Water  Water Use  Water Use Withdrawal
# ...

# %%
# # drop duplicates
# df = df.drop_duplicates()
# print(len(df))
# df.head()
# Out:
# 425412
#     SiteVariableAmountID       Amount  PopulationServed  \
# 0                1708453  31302.17376               360
# 9                1708453  31302.17376               360
# 44               1708453  31302.17376               360
# 83               1708453  31302.17376               360
# 84               1708454  37017.57066               290
#
#                 CommunityWaterSupplySystem  ReportYearCV SiteUUID SiteTypeCV  \
# 0   Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 9   Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 44  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 83  Leeds Domestic Water Users Association          1989  UTss_S1     Spring
# 84  Leeds Domestic Water Users Association          1991  UTss_S1     Spring
#
#    WaterSourceUUID WaterSourceTypeCV VariableCV    VariableSpecificCV  \
# 0         UTss_WS1     Surface Water  Water Use  Water Use Withdrawal
# ...

# %% [markdown]
# ### Export Outputs

# %%
# #Exporting to Finished File
# df.to_csv('SiteVariableAmounts_fact.csv', index=False)  # The output
