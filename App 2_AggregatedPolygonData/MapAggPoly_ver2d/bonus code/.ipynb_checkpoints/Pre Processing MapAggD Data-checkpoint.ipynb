# %% [markdown]
# # Pre-Processing CSV data for MapAggC
# #### General Approach:
# 1) Read in csv sheet of data.  Export fields into new dataframe.
# 2) Remove bad rows and elements.
# 3) Fix date datatype.
# 4) For ReportingUnit df, include ID value for easy match to shp file in ArcGIS (see below).
# 8) Export completed df as processed csZv.
#
# #### Files Needed
# 1) dontopen_RU.csv,
# 2) dontopen_AggLJAll.csv

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook
pd.options.display.max_rows  # Increases the length of a printed string from a DataFrame
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %% [markdown]
# ## ReportingUnits Table and Export
#
# #### General Notes
# We drop the geometry field at this time.  API returns a encrypted version of it, which we can't work with at this time.  Have to instead match ReportingUnit_dim table to several separate shp files based on Unit Type (e.g., county, HUC8, custom, etc).  Have to build an ID value for this to work.  Each Unit Type file ID and match approach is different, see below.
#
# #### ReportingUnit csv to ArcGIS shp file notes.
# Creating ID to link p-csv to shp file works for every ReportUnitType but HUC8, as the ArcGIS shp we use doesn't incldue name in its data.  Have to cheat, and for all HUC8 types, the format should be "2_" + !HUC_8! + "_" + !StateNum!.  For the time, this was easier to do by hand than by code.
#
# Wyoming also includes "... River Planning Basin" in its REportingUnitName.  Easier just to remove by hand.  Changed one WY shp file entry to Snake-Salt, from Salt-Snake.
#
# California custom DAUCO also worked better using ReportingUnitNativeID.
#
# AZ custom AM alsow worked better using ReportingUnitNative ID.  Shp didn't include a StateNum field, I just added it in.
#
# USBR did work okay with ReportingUnitName.  Did have to update the shapefile with StateNum field = 100.

# %%
#Working Directory and Input File
workingDir = "C:/Users/rjame/Documents/WSWC Documents/Portal Creation Research"
os.chdir(workingDir)

# %%
RU_Input = "dontopen_RU.csv"
df_RU = pd.read_csv(RU_Input)
df_RU
# Out:
#       ReportingUnitID ReportingUnitUUID ReportingUnitNativeID  \
# 0     254              00-01-03          00-01-03
# 1     255              000-01-03         000-01-03
# 2     256              00-07-02          00-07-02
# 3     257              000-01-02         000-01-02
# 4     258              000-02-00         000-02-00
# ...   ...                    ...               ...
# 1214  24123            CAag_RU547        DAU40323
# 1215  24124            CAag_RU548        DAU40423
# 1216  24125            CAag_RU549        DAU40449
# 1217  24126            CAag_RU550        DAU40523
# 1218  24127            CAag_RU551        DAU40549
#
#      ReportingUnitName                ReportingUnitTypeCV  \
# 0     Curlew Valley     Subarea
# 1     Clear Creek       Subarea
# 2     Promontory Point  Subarea
# 3     Yost              Subarea
# 4     Goose Creek       Subarea
# ...           ...           ...
# 1214  Upper Russian     Detailed Analysis Units by County
# 1215  Middle Russian    Detailed Analysis Units by County
# 1216  Middle Russian    Detailed Analysis Units by County
# 1217  Dry Creek         Detailed Analysis Units by County
# 1218  Dry Creek         Detailed Analysis Units by County
#
#      ReportingUnitUpdateDate  ReportingUnitProductVersion StateCV EPSGCodeCV  \
# 0     NaN                    NaN                           UT      EPSG:4326
# 1     NaN                    NaN                           UT      EPSG:4326
# 2     NaN                    NaN                           UT      EPSG:4326
# 3     NaN                    NaN                           UT      EPSG:4326
# 4     NaN                    NaN                           UT      EPSG:4326
# ...   ...                     ..                           ..            ...
# 1214  NaN                    NaN                           CA      EPSG:4326
# 1215  NaN                    NaN                           CA      EPSG:4326
# 1216  NaN                    NaN                           CA      EPSG:4326
# 1217  NaN                    NaN                           CA      EPSG:4326
# 1218  NaN                    NaN                           CA      EPSG:4326
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Geometry
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 1214  NaN
# 1215  NaN
# 1216  NaN
# 1217  NaN
# 1218  NaN
#
# [1219 rows x 10 columns]

# %%
#removeing bad rows of df because they are null for some odd reason
df_RU = df_RU[(df_RU.ReportingUnitUUID != 'test')]

#Dropping fields we don't need.
df_RU = df_RU.drop(['Geometry', 'ReportingUnitUpdateDate', 'ReportingUnitProductVersion'], axis=1)

#Fixing Index
df_RU = df_RU.reset_index()
df_RU = df_RU.drop(columns=['index'])

df_RU
# Out:
#       ReportingUnitID ReportingUnitUUID ReportingUnitNativeID  \
# 0     254              00-01-03          00-01-03
# 1     255              000-01-03         000-01-03
# 2     256              00-07-02          00-07-02
# 3     257              000-01-02         000-01-02
# 4     258              000-02-00         000-02-00
# ...   ...                    ...               ...
# 1214  24123            CAag_RU547        DAU40323
# 1215  24124            CAag_RU548        DAU40423
# 1216  24125            CAag_RU549        DAU40449
# 1217  24126            CAag_RU550        DAU40523
# 1218  24127            CAag_RU551        DAU40549
#
#      ReportingUnitName                ReportingUnitTypeCV StateCV EPSGCodeCV
# 0     Curlew Valley     Subarea                            UT      EPSG:4326
# 1     Clear Creek       Subarea                            UT      EPSG:4326
# 2     Promontory Point  Subarea                            UT      EPSG:4326
# 3     Yost              Subarea                            UT      EPSG:4326
# 4     Goose Creek       Subarea                            UT      EPSG:4326
# ...           ...           ...                            ..            ...
# 1214  Upper Russian     Detailed Analysis Units by County  CA      EPSG:4326
# 1215  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1216  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1217  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
# 1218  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
#
# [1219 rows x 7 columns]

# %%
#Creating Linking Element with Shape File.
#Format Ex: "1_" + !NAME! + "_" + !StateNum!

stateNumDic = {
    "UT" : "46",
    "NM" : "35",
    "NE" : "41",
    "CO" : "41",
    "WY" : "47",
    "CA" : "49",
    "AZ" : "48",
    "TX" : "37",
    "US" : "100"
}

def createTypeNameNum(colrowValueA, colrowValueB, colrowValueC):
    StringA = colrowValueA.strip()  # ReportingUnitTypeCV
    StringB = colrowValueB.strip()  # ReportingUnitName
    StringC = colrowValueC.strip()  # state for StateNumDic
    
    outStringA = ""
    
    if StringA == "County":
        outStringA = "1"
    if StringA == "HUC8":
        outStringA = "2"
    if StringA == "Basin":
        outStringA = "3"
    if StringA == "Planning Area":
        outStringA = "4"
    if StringA == "Active Management Area":
        outStringA = "5"
    if StringA == "Tributary":
        outStringA = "6"
    if StringA == "Subarea":
        outStringA = "7"
    if StringA == "Hydrologic Region":
        outStringA = "8"
    
    outList = outStringA + "_" + StringB + "_" + stateNumDic[StringC]
    return outList

df_RU['TypeNameNum'] = df_RU.apply(lambda row: createTypeNameNum(row['ReportingUnitTypeCV'], row['ReportingUnitName'], row['StateCV']), axis=1)
df_RU
# Out:
#       ReportingUnitID ReportingUnitUUID ReportingUnitNativeID  \
# 0     254              00-01-03          00-01-03
# 1     255              000-01-03         000-01-03
# 2     256              00-07-02          00-07-02
# 3     257              000-01-02         000-01-02
# 4     258              000-02-00         000-02-00
# ...   ...                    ...               ...
# 1214  24123            CAag_RU547        DAU40323
# 1215  24124            CAag_RU548        DAU40423
# 1216  24125            CAag_RU549        DAU40449
# 1217  24126            CAag_RU550        DAU40523
# 1218  24127            CAag_RU551        DAU40549
#
#      ReportingUnitName                ReportingUnitTypeCV StateCV EPSGCodeCV  \
# 0     Curlew Valley     Subarea                            UT      EPSG:4326
# 1     Clear Creek       Subarea                            UT      EPSG:4326
# 2     Promontory Point  Subarea                            UT      EPSG:4326
# 3     Yost              Subarea                            UT      EPSG:4326
# 4     Goose Creek       Subarea                            UT      EPSG:4326
# ...           ...           ...                            ..            ...
# 1214  Upper Russian     Detailed Analysis Units by County  CA      EPSG:4326
# 1215  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1216  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1217  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
# 1218  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
#
#                 TypeNameNum
# 0     7_Curlew Valley_46
# 1     7_Clear Creek_46
# 2     7_Promontory Point_46
# 3     7_Yost_46
# 4     7_Goose Creek_46
# ...                ...
# 1214  _Upper Russian_49
# 1215  _Middle Russian_49
# 1216  _Middle Russian_49
# 1217  _Dry Creek_49
# 1218  _Dry Creek_49
#
# [1219 rows x 8 columns]

# %%
#Creating Linking Element with Shape File.
#Format Ex: "1_" + !ID! + "_" + !StateNum!

stateNumDic = {
    "UT" : "46",
    "NM" : "35",
    "NE" : "41",
    "CO" : "42",
    "WY" : "47",
    "CA" : "49",
    "AZ" : "48",
    "TX" : "37",
    "US" : "100"
}


def createTypeNameNum(colrowValueA, colrowValueB, colrowValueC):
    StringA = colrowValueA.strip()  # ReportingUnitTypeCV
    StringB = colrowValueB.strip()  # ReportingUnitNativeID
    StringC = colrowValueC.strip()  # state for StateNumDic
    
    outStringA = ""
    
    if StringA == "County":
        outStringA = "1"
    if StringA == "HUC8":
        outStringA = "2"
    if StringA == "Basin":
        outStringA = "3"
    if StringA == "Planning Area":
        outStringA = "4"
    if StringA == "Active Management Area":
        outStringA = "5"
    if StringA == "Tributary":
        outStringA = "6"
    if StringA == "Subarea":
        outStringA = "7"
    if StringA == "Hydrologic Region":
        outStringA = "8"
    
    outList = outStringA + "_" + StringB + "_" + stateNumDic[StringC]
    return outList

df_RU['TypeIDNum'] = df_RU.apply(lambda row: createTypeNameNum(row['ReportingUnitTypeCV'], row['ReportingUnitNativeID'], row['StateCV']), axis=1)
df_RU
# Out:
#       ReportingUnitID ReportingUnitUUID ReportingUnitNativeID  \
# 0     254              00-01-03          00-01-03
# 1     255              000-01-03         000-01-03
# 2     256              00-07-02          00-07-02
# 3     257              000-01-02         000-01-02
# 4     258              000-02-00         000-02-00
# ...   ...                    ...               ...
# 1214  24123            CAag_RU547        DAU40323
# 1215  24124            CAag_RU548        DAU40423
# 1216  24125            CAag_RU549        DAU40449
# 1217  24126            CAag_RU550        DAU40523
# 1218  24127            CAag_RU551        DAU40549
#
#      ReportingUnitName                ReportingUnitTypeCV StateCV EPSGCodeCV  \
# 0     Curlew Valley     Subarea                            UT      EPSG:4326
# 1     Clear Creek       Subarea                            UT      EPSG:4326
# 2     Promontory Point  Subarea                            UT      EPSG:4326
# 3     Yost              Subarea                            UT      EPSG:4326
# 4     Goose Creek       Subarea                            UT      EPSG:4326
# ...           ...           ...                            ..            ...
# 1214  Upper Russian     Detailed Analysis Units by County  CA      EPSG:4326
# 1215  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1216  Middle Russian    Detailed Analysis Units by County  CA      EPSG:4326
# 1217  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
# 1218  Dry Creek         Detailed Analysis Units by County  CA      EPSG:4326
#
#                 TypeNameNum       TypeIDNum
# 0     7_Curlew Valley_46     7_00-01-03_46
# 1     7_Clear Creek_46       7_000-01-03_46
# 2     7_Promontory Point_46  7_00-07-02_46
# 3     7_Yost_46              7_000-01-02_46
# 4     7_Goose Creek_46       7_000-02-00_46
# ...                ...                  ...
# 1214  _Upper Russian_49      _DAU40323_49
# 1215  _Middle Russian_49     _DAU40423_49
# 1216  _Middle Russian_49     _DAU40449_49
# 1217  _Dry Creek_49          _DAU40523_49
# 1218  _Dry Creek_49          _DAU40549_49
#
# [1219 rows x 9 columns]

# %%
#The Ouput
df_RU.to_csv('Pagg_ReportingUnit.csv', index=False)

# %% [markdown]
# ## AggregatedAmounts_withOrg

# %%
AAwO_Input = "dontopen_AggLJAll.csv"
df_AAwO = pd.read_csv(AAwO_Input)
df_AAwO.head(5)
# Out:
# C:\Users\rjame\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    AggregatedAmountID  OrganizationID  ReportingUnitID  VariableSpecificID  \
# 0  554278              3               254              115
# 1  554447              3               254              115
# 2  554616              3               254              115
# 3  554785              3               254              115
# 4  554954              3               254              115
#
#    WaterSourceID  MethodID  ReportYearCV  Amount  TimeframeStartID  \
# 0  338412         36        2013          0.0     1.0
# 1  338412         36        2006          3.0     6.0
# 2  338412         36        2012          0.0     8.0
# 3  338412         36        2010          0.0     25.0
# 4  338412         36        2008          3.0     27.0
#
#    TimeframeEndID ReportingUnitUUID ReportingUnitNativeID ReportingUnitName  \
# 0  42.0            00-01-03          00-01-03              Curlew Valley
# 1  28.0            00-01-03          00-01-03              Curlew Valley
# 2  30.0            00-01-03          00-01-03              Curlew Valley
# 3  43.0            00-01-03          00-01-03              Curlew Valley
# 4  40.0            00-01-03          00-01-03              Curlew Valley
#
#   ReportingUnitTypeCV  TimeframeStartID.1  TimeframeEndID.1 WaterSourceTypeCV  \
# 0  Subarea             1.0                 42.0              Unspecified
# 1  Subarea             6.0                 28.0              Unspecified
# 2  Subarea             8.0                 30.0              Unspecified
# 3  Subarea             25.0                43.0              Unspecified
# 4  Subarea             27.0                40.0              Unspecified
#
#    VariableCV         VariableSpecificCV ApplicableResourceTypeCV  \
# 0  Withdrawal  Withdrawal, Public Supply  Modeled
# 1  Withdrawal  Withdrawal, Public Supply  Modeled
# 2  Withdrawal  Withdrawal, Public Supply  Modeled
# 3  Withdrawal  Withdrawal, Public Supply  Modeled
# 4  Withdrawal  Withdrawal, Public Supply  Modeled
#
#   MethodTypeCV State       BeneficialUseCV
# 0  Modeled      UT    Municipal/Industrial
# 1  Modeled      UT    Municipal/Industrial
# 2  Modeled      UT    Municipal/Industrial
# 3  Modeled      UT    Municipal/Industrial
# 4  Modeled      UT    Municipal/Industrial

# %%
date_Input = "dontopen_Date_dim.csv"
df_date = pd.read_csv(date_Input)
df_date.head(5)
# Out:
#    DateID        Date  Year
# 0  1       2013-10-01  2013
# 1  2       2003-09-01  2003
# 2  3       2003-10-01  2003
# 3  4       2006-08-01  2006
# 4  5       2006-09-01  2006

# %%
#Retreiving TimeframeStart from Dates_dim Table
TimeframeStartdict = pd.Series(df_date.Date.values, index = df_date.DateID).to_dict()

# For creating TimeframeStart
def retrieveTimeframeStart(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        val1 = colrowValue
        try:
            outList = TimeframeStartdict[val1]
        except:
            outList = colrowValue
    return outList

df_AAwO['TimeframeStart'] = df_AAwO.apply(lambda row: retrieveTimeframeStart(row['TimeframeStartID']), axis=1)
df_AAwO.head(5)
# Out:
#    AggregatedAmountID  OrganizationID  ReportingUnitID  VariableSpecificID  \
# 0  554278              3               254              115
# 1  554447              3               254              115
# 2  554616              3               254              115
# 3  554785              3               254              115
# 4  554954              3               254              115
#
#    WaterSourceID  MethodID  ReportYearCV  Amount  TimeframeStartID  \
# 0  338412         36        2013          0.0     1.0
# 1  338412         36        2006          3.0     6.0
# 2  338412         36        2012          0.0     8.0
# 3  338412         36        2010          0.0     25.0
# 4  338412         36        2008          3.0     27.0
#
#    TimeframeEndID ReportingUnitUUID ReportingUnitNativeID ReportingUnitName  \
# 0  42.0            00-01-03          00-01-03              Curlew Valley
# 1  28.0            00-01-03          00-01-03              Curlew Valley
# 2  30.0            00-01-03          00-01-03              Curlew Valley
# 3  43.0            00-01-03          00-01-03              Curlew Valley
# 4  40.0            00-01-03          00-01-03              Curlew Valley
#
#   ReportingUnitTypeCV  TimeframeStartID.1  TimeframeEndID.1 WaterSourceTypeCV  \
# 0  Subarea             1.0                 42.0              Unspecified
# 1  Subarea             6.0                 28.0              Unspecified
# 2  Subarea             8.0                 30.0              Unspecified
# 3  Subarea             25.0                43.0              Unspecified
# 4  Subarea             27.0                40.0              Unspecified
#
#    VariableCV         VariableSpecificCV ApplicableResourceTypeCV  \
# 0  Withdrawal  Withdrawal, Public Supply  Modeled
# 1  Withdrawal  Withdrawal, Public Supply  Modeled
# 2  Withdrawal  Withdrawal, Public Supply  Modeled
# 3  Withdrawal  Withdrawal, Public Supply  Modeled
# 4  Withdrawal  Withdrawal, Public Supply  Modeled
#
#   MethodTypeCV State       BeneficialUseCV TimeframeStart
# 0  Modeled      UT    Municipal/Industrial  2013-10-01
# 1  Modeled      UT    Municipal/Industrial  2006-10-01
# 2  Modeled      UT    Municipal/Industrial  2012-10-01
# 3  Modeled      UT    Municipal/Industrial  2010-10-01
# 4  Modeled      UT    Municipal/Industrial  2008-10-01

# %%
#Retreiving TimeframeEnd from Dates_dim Table
TimeframeEnddict = pd.Series(df_date.Date.values, index = df_date.DateID).to_dict()

# For creating TimeframeEnd
def retrieveTimeframeEnd(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        val1 = colrowValue
        try:
            outList = TimeframeEnddict[val1]
        except:
            outList = colrowValue
    return outList

df_AAwO['TimeframeEnd'] = df_AAwO.apply(lambda row: retrieveTimeframeEnd(row['TimeframeEndID']), axis=1)
df_AAwO.head(5)
# Out:
#    AggregatedAmountID  OrganizationID  ReportingUnitID  VariableSpecificID  \
# 0  554278              3               254              115
# 1  554447              3               254              115
# 2  554616              3               254              115
# 3  554785              3               254              115
# 4  554954              3               254              115
#
#    WaterSourceID  MethodID  ReportYearCV  Amount  TimeframeStartID  \
# 0  338412         36        2013          0.0     1.0
# 1  338412         36        2006          3.0     6.0
# 2  338412         36        2012          0.0     8.0
# 3  338412         36        2010          0.0     25.0
# 4  338412         36        2008          3.0     27.0
#
#    TimeframeEndID ReportingUnitUUID ReportingUnitNativeID ReportingUnitName  \
# 0  42.0            00-01-03          00-01-03              Curlew Valley
# 1  28.0            00-01-03          00-01-03              Curlew Valley
# 2  30.0            00-01-03          00-01-03              Curlew Valley
# 3  43.0            00-01-03          00-01-03              Curlew Valley
# 4  40.0            00-01-03          00-01-03              Curlew Valley
#
#   ReportingUnitTypeCV  TimeframeStartID.1  TimeframeEndID.1 WaterSourceTypeCV  \
# 0  Subarea             1.0                 42.0              Unspecified
# 1  Subarea             6.0                 28.0              Unspecified
# 2  Subarea             8.0                 30.0              Unspecified
# 3  Subarea             25.0                43.0              Unspecified
# 4  Subarea             27.0                40.0              Unspecified
#
#    VariableCV         VariableSpecificCV ApplicableResourceTypeCV  \
# 0  Withdrawal  Withdrawal, Public Supply  Modeled
# 1  Withdrawal  Withdrawal, Public Supply  Modeled
# 2  Withdrawal  Withdrawal, Public Supply  Modeled
# 3  Withdrawal  Withdrawal, Public Supply  Modeled
# 4  Withdrawal  Withdrawal, Public Supply  Modeled
#
#   MethodTypeCV State       BeneficialUseCV TimeframeStart TimeframeEnd
# 0  Modeled      UT    Municipal/Industrial  2013-10-01     2013-09-30
# 1  Modeled      UT    Municipal/Industrial  2006-10-01     2006-09-30
# 2  Modeled      UT    Municipal/Industrial  2012-10-01     2012-09-30
# 3  Modeled      UT    Municipal/Industrial  2010-10-01     2010-09-30
# 4  Modeled      UT    Municipal/Industrial  2008-10-01     2008-09-30

# %%
#Dropping fields we don't need.
df_AAwO = df_AAwO.drop(['TimeframeStartID', 'TimeframeEndID'], axis=1)
df_AAwO.head(5)
# Out:
#    AggregatedAmountID  OrganizationID  ReportingUnitID  VariableSpecificID  \
# 0  554278              3               254              115
# 1  554447              3               254              115
# 2  554616              3               254              115
# 3  554785              3               254              115
# 4  554954              3               254              115
#
#    WaterSourceID  MethodID  ReportYearCV  Amount ReportingUnitUUID  \
# 0  338412         36        2013          0.0     00-01-03
# 1  338412         36        2006          3.0     00-01-03
# 2  338412         36        2012          0.0     00-01-03
# 3  338412         36        2010          0.0     00-01-03
# 4  338412         36        2008          3.0     00-01-03
#
#   ReportingUnitNativeID ReportingUnitName ReportingUnitTypeCV  \
# 0  00-01-03              Curlew Valley     Subarea
# 1  00-01-03              Curlew Valley     Subarea
# 2  00-01-03              Curlew Valley     Subarea
# 3  00-01-03              Curlew Valley     Subarea
# 4  00-01-03              Curlew Valley     Subarea
#
#    TimeframeStartID.1  TimeframeEndID.1 WaterSourceTypeCV  VariableCV  \
# 0  1.0                 42.0              Unspecified       Withdrawal
# 1  6.0                 28.0              Unspecified       Withdrawal
# 2  8.0                 30.0              Unspecified       Withdrawal
# 3  25.0                43.0              Unspecified       Withdrawal
# 4  27.0                40.0              Unspecified       Withdrawal
#
#           VariableSpecificCV ApplicableResourceTypeCV MethodTypeCV State  \
# 0  Withdrawal, Public Supply  Modeled                  Modeled      UT
# 1  Withdrawal, Public Supply  Modeled                  Modeled      UT
# 2  Withdrawal, Public Supply  Modeled                  Modeled      UT
# 3  Withdrawal, Public Supply  Modeled                  Modeled      UT
# 4  Withdrawal, Public Supply  Modeled                  Modeled      UT
#
#         BeneficialUseCV TimeframeStart TimeframeEnd
# 0  Municipal/Industrial  2013-10-01     2013-09-30
# 1  Municipal/Industrial  2006-10-01     2006-09-30
# 2  Municipal/Industrial  2012-10-01     2012-09-30
# 3  Municipal/Industrial  2010-10-01     2010-09-30
# 4  Municipal/Industrial  2008-10-01     2008-09-30

# %%
df_AAwO['BeneficialUseCV'].fillna('Unspecified', inplace=True)
df_AAwO
# Out:
#         AggregatedAmountID  OrganizationID  ReportingUnitID  \
# 0       554278              3               254
# 1       554447              3               254
# 2       554616              3               254
# 3       554785              3               254
# 4       554954              3               254
# ...        ...             ..               ...
# 116057  577758              8               23025
# 116058  577781              8               23025
# 116059  577804              8               23025
# 116060  577827              8               23025
# 116061  577850              8               23025
#
#         VariableSpecificID  WaterSourceID  MethodID  ReportYearCV    Amount  \
# 0       115                 338412         36        2013          0.0
# 1       115                 338412         36        2006          3.0
# 2       115                 338412         36        2012          0.0
# 3       115                 338412         36        2010          0.0
# 4       115                 338412         36        2008          3.0
# ...     ...                    ...         ..         ...          ...
# 116057  72                  462891         61        2007          442.0
# 116058  72                  462891         61        2007          2578.0
# 116059  72                  462891         61        2007          79975.0
# 116060  72                  462891         61        2007          473342.0
# 116061  72                  462891         61        2006          278.0
#
#        ReportingUnitUUID ReportingUnitNativeID    ReportingUnitName  \
# 0       00-01-03          00-01-03              Curlew Valley
# 1       00-01-03          00-01-03              Curlew Valley
# 2       00-01-03          00-01-03              Curlew Valley
# 3       00-01-03          00-01-03              Curlew Valley
# 4       00-01-03          00-01-03              Curlew Valley
# ...          ...               ...                        ...
# 116057  TX_9              9                     TRINITY-SAN JACINTO
# 116058  TX_9              9                     TRINITY-SAN JACINTO
# 116059  TX_9              9                     TRINITY-SAN JACINTO
# 116060  TX_9              9                     TRINITY-SAN JACINTO
# 116061  TX_9              9                     TRINITY-SAN JACINTO
#
#        ReportingUnitTypeCV  TimeframeStartID.1  TimeframeEndID.1  \
# 0       Subarea             1.0                 42.0
# 1       Subarea             6.0                 28.0
# 2       Subarea             8.0                 30.0
# 3       Subarea             25.0                43.0
# 4       Subarea             27.0                40.0
# ...         ...              ...                 ...
# 116057  Basin               37752.0             36160.0
# 116058  Basin               37752.0             36160.0
# 116059  Basin               37752.0             36160.0
# 116060  Basin               37752.0             36160.0
# 116061  Basin               37752.0             36160.0
#
#        WaterSourceTypeCV       VariableCV         VariableSpecificCV  \
# 0       Unspecified       Withdrawal       Withdrawal, Public Supply
# 1       Unspecified       Withdrawal       Withdrawal, Public Supply
# 2       Unspecified       Withdrawal       Withdrawal, Public Supply
# 3       Unspecified       Withdrawal       Withdrawal, Public Supply
# 4       Unspecified       Withdrawal       Withdrawal, Public Supply
# ...             ...              ...                             ...
# 116057  Surface           Consumptive Use  Consumptive Use
# 116058  Surface           Consumptive Use  Consumptive Use
# 116059  Surface           Consumptive Use  Consumptive Use
# 116060  Surface           Consumptive Use  Consumptive Use
# 116061  Surface           Consumptive Use  Consumptive Use
#
#        ApplicableResourceTypeCV MethodTypeCV State  \
# 0       Modeled                  Modeled      UT
# 1       Modeled                  Modeled      UT
# 2       Modeled                  Modeled      UT
# 3       Modeled                  Modeled      UT
# 4       Modeled                  Modeled      UT
# ...         ...                      ...      ..
# 116057  Unspecified              Water Use    TX
# 116058  Unspecified              Water Use    TX
# 116059  Unspecified              Water Use    TX
# 116060  Unspecified              Water Use    TX
# 116061  Unspecified              Water Use    TX
#
#                      BeneficialUseCV TimeframeStart TimeframeEnd
# 0       Municipal/Industrial          2013-10-01     2013-09-30
# 1       Municipal/Industrial          2006-10-01     2006-09-30
# 2       Municipal/Industrial          2012-10-01     2012-09-30
# 3       Municipal/Industrial          2010-10-01     2010-09-30
# 4       Municipal/Industrial          2008-10-01     2008-09-30
# ...                      ...                 ...            ...
# 116057  Steam-Electric Power_surface  2020-01-01     2020-12-31
# 116058  Mining_surface                2020-01-01     2020-12-31
# 116059  Manufacturing_surface         2020-01-01     2020-12-31
# 116060  Municipal_surface             2020-01-01     2020-12-31
# 116061  Livestock_surface             2020-01-01     2020-12-31
#
# [116062 rows x 23 columns]

# %%
#The Ouput
df_AAwO.to_csv('Pagg_AggregatedAmountsAll.csv', index=False)
