# %% [markdown]
# # Creating Shapefiles for Web App - HUC8
#
# Inputs:
# 1) Pagg_ReportingUnit.csv.  Contains reportinug unit info from WaDE database.
#
# 2) WaDECounties.shp.  Shapefile of Unitied State counties.
#
# Paring HUC8 to ReportingUnitNativeID

# %%
#Needed Libararies
import os
import numpy as np
import pandas as pd
from datetime import datetime
import geopandas as gpd # the library that lets us read in shapefiles
pd.set_option('display.max_columns', 999)  # How to display all columns of a Pandas DataFrame in Jupyter Notebook

# %%
# Set working directory
workingDir = "C:/Users/rjame/Documents/RShinyAppPractice/CreateAppShapefiles/App2_AggregatedShape""
os.chdir(workingDir)

# Grab AggreagatedAmounts ReportingUnit.csv file.
reportingunits_input = pd.read_csv('SourceFiles/Pagg_ReportingUnit.csv')
df_1RU = pd.DataFrame(reportingunits_input)
df_1RU.head(3)
# Out:
#    ReportingUnitID ReportingUnitUUID ReportingUnitNativeID ReportingUnitName  \
# 0            20733            NM_C_1                 35001        Bernalillo
# 1            20734            NM_C_2                 35003            Catron
# 2            20735            NM_C_3                 35005            Chaves
#
#   ReportingUnitTypeCV StateCV EPSGCodeCV
# 0              County      NM  EPSG:4326
# 1              County      NM  EPSG:4326
# 2              County      NM  EPSG:4326

# %%
# Grab the HUC8 Shapefile.
shapefile_input = gpd.read_file('SourceFiles/HUC8/HUC8_US.shp')
dfs_1HUC8 = pd.DataFrame(shapefile_input)
dfs_1HUC8.head(3)
# Out:
#                                     TNMID METASOURCE SOURCEDATA SOURCEORIG  \
# 0  {4CCAA733-584D-4347-A7F3-4E664ADA8B9B}       None       None       None
# 1  {70274AE7-175E-410E-A1BD-C5B4A8E36460}       None       None       None
# 2  {AC101059-1D6E-465C-AF7F-605322DDFBF9}       None       None       None
#
#   SOURCEFEAT    LOADDATE  GNIS_ID   AREAACRES  AREASQKM STATES      HUC8  \
# 0       None  2012-06-11        0  1104144.63   4468.32  CO,NM  11080001
# 1       None  2012-06-11        0   671679.80   2718.19     NM  11080002
# 2       None  2012-06-11        0  1314676.86   5320.31     NM  11080003
#
#                   NAME  Shape_Leng  Shape_Area  \
# 0  Canadian Headwaters    3.943636    0.450856
# 1             Cimarron    3.006890    0.273469
# 2       Upper Canadian    6.201702    0.531733
#
#                                             geometry
# 0  POLYGON ((-104.18034 36.92065, -104.18082 36.9...
# 1  POLYGON ((-104.49909 36.32423, -104.49957 36.3...
# 2  POLYGON ((-104.21278 35.94052, -104.21295 35.9...

# %%
# HUC8
# State: Utah
###########################################################################

# Create temporal dataframes for state specific and reportingunit type storage
# dfs_1HUC8_UT = dfs_1HUC8[(dfs_1HUC8.STATES == 'UT')]
dfs_1HUC8_UT = dfs_1HUC8
df_1RU_HUC8_UT = df_1RU[(df_1RU.ReportingUnitTypeCV == 'HUC8') & ((df_1RU.StateCV == 'UT'))]

# retreive ReportingUnitUUID.
ReportingUnitUUIDdict = pd.Series(df_1RU_HUC8_UT.ReportingUnitUUID.values, index = df_1RU_HUC8_UT.ReportingUnitNativeID).to_dict()
def retrieveHUC8ID(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue.strip()
        try:
            outList = ReportingUnitUUIDdict[String1]
        except:
            outList = ''
    return outList
dfs_1HUC8_UT['ReportingUnitUUID'] = dfs_1HUC8_UT.apply(lambda row: retrieveHUC8ID(row['HUC8']), axis=1)

# Merging temporal dataframes into one, using left-join.
dfs_1HUC8_UT = pd.merge(dfs_1HUC8_UT, df_1RU_HUC8_UT, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

# Creating new output state specific dataframe with fields of interest.
dfs_2HUC8_UT = pd.DataFrame() #empty dataframe
dfs_2HUC8_UT['OBJECTID'] = dfs_1HUC8_UT.index
dfs_2HUC8_UT['Shape'] = 'Polygon'
dfs_2HUC8_UT['UnitID'] = dfs_1HUC8_UT['ReportingUnitID']
dfs_2HUC8_UT['UnitUUID'] = dfs_1HUC8_UT['ReportingUnitUUID']
dfs_2HUC8_UT['NativeID'] = dfs_1HUC8_UT['ReportingUnitNativeID']
dfs_2HUC8_UT['Name'] = dfs_1HUC8_UT['ReportingUnitName']
dfs_2HUC8_UT['TypeCV'] = dfs_1HUC8_UT['ReportingUnitTypeCV']
dfs_2HUC8_UT['StateCV'] = dfs_1HUC8_UT['StateCV']
dfs_2HUC8_UT['Shape_Length'] = dfs_1HUC8_UT['Shape_Leng']
dfs_2HUC8_UT['Shape_Area'] = dfs_1HUC8_UT['Shape_Area']
dfs_2HUC8_UT['geometry'] = dfs_1HUC8_UT['geometry']

# view output
dfs_2HUC8_UT
# Out:
#       OBJECTID    Shape  UnitID UnitUUID NativeID Name TypeCV StateCV  \
# 0            0  Polygon     NaN               NaN  NaN    NaN     NaN
# 1            1  Polygon     NaN               NaN  NaN    NaN     NaN
# 2            2  Polygon     NaN               NaN  NaN    NaN     NaN
# 3            3  Polygon     NaN               NaN  NaN    NaN     NaN
# 4            4  Polygon     NaN               NaN  NaN    NaN     NaN
# ...        ...      ...     ...      ...      ...  ...    ...     ...
# 2134      2134  Polygon     NaN               NaN  NaN    NaN     NaN
# 2135      2135  Polygon     NaN               NaN  NaN    NaN     NaN
# 2136      2136  Polygon     NaN               NaN  NaN    NaN     NaN
# 2137      2137  Polygon     NaN               NaN  NaN    NaN     NaN
# 2138      2138  Polygon     NaN               NaN  NaN    NaN     NaN
#
#       Shape_Length  Shape_Area  \
# 0         3.943636    0.450856
# 1         3.006890    0.273469
# 2         6.201702    0.531733
# 3         4.275086    0.376770
# 4         3.228884    0.261226
# ...            ...         ...
# 2134     12.338414    0.782879
# 2135      7.191060    0.633310
# 2136      7.392520    0.656249
# 2137      3.216966    0.329257
# 2138      4.443277    0.399892
#
#                                                geometry
# 0     POLYGON ((-104.18034 36.92065, -104.18082 36.9...
# 1     POLYGON ((-104.49909 36.32423, -104.49957 36.3...
# 2     POLYGON ((-104.21278 35.94052, -104.21295 35.9...
# 3     POLYGON ((-105.18148 36.34119, -105.18215 36.3...
# 4     POLYGON ((-104.81254 35.64952, -104.81220 35.6...
# ...                                                 ...
# 2134  POLYGON ((-97.13206 49.87813, -97.13159 49.878...
# 2135  POLYGON ((-97.16067 45.95853, -97.16019 45.958...
# 2136  POLYGON ((-97.05241 49.24424, -97.05239 49.244...
# 2137  POLYGON ((-95.94852 48.56142, -95.94879 48.559...
# 2138  POLYGON ((-96.97390 49.70229, -96.97325 49.702...
#
# [2139 rows x 11 columns]

# %%
# HUC8
# State: CO
###########################################################################

# Create temporal dataframes for state specific and reportingunit type storage
# dfs_1HUC8_CO = dfs_1HUC8[(dfs_1HUC8.STATES == 'CO')]
dfs_1HUC8_CO = dfs_1HUC8
df_1RU_HUC8_CO = df_1RU[(df_1RU.ReportingUnitTypeCV == 'HUC8') & ((df_1RU.StateCV == 'CO'))]

# retreive ReportingUnitUUID.
ReportingUnitUUIDdict = pd.Series(df_1RU_HUC8_CO.ReportingUnitUUID.values, index = df_1RU_HUC8_CO.ReportingUnitNativeID).to_dict()
def retrieveCountyName(colrowValue):
    if colrowValue == '' or pd.isnull(colrowValue):
        outList = ''
    else:
        String1 = colrowValue
        try:
            outList = ReportingUnitUUIDdict[String1]
        except:
            outList = ''
    return outList
dfs_1HUC8_CO['ReportingUnitUUID'] = dfs_1HUC8_CO.apply(lambda row: retrieveCountyName(row['HUC8']), axis=1)

# Merging temporal dataframes into one, using left-join.
dfs_1HUC8_CO = pd.merge(dfs_1HUC8_CO, df_1RU_HUC8_CO, left_on='ReportingUnitUUID', right_on='ReportingUnitUUID', how='left')

# Creating new output state specific dataframe with fields of interest.
dfs_2HUC8_CO = pd.DataFrame() #empty dataframe
dfs_2HUC8_CO['OBJECTID'] = dfs_1HUC8_CO.index
dfs_2HUC8_CO['Shape'] = 'Polygon'
dfs_2HUC8_CO['UnitID'] = dfs_1HUC8_CO['ReportingUnitID']
dfs_2HUC8_CO['UnitUUID'] = dfs_1HUC8_CO['ReportingUnitUUID']
dfs_2HUC8_CO['NativeID'] = dfs_1HUC8_CO['ReportingUnitNativeID']
dfs_2HUC8_CO['Name'] = dfs_1HUC8_CO['ReportingUnitName']
dfs_2HUC8_CO['TypeCV'] = dfs_1HUC8_CO['ReportingUnitTypeCV']
dfs_2HUC8_CO['StateCV'] = dfs_1HUC8_CO['StateCV']
dfs_2HUC8_CO['Shape_Length'] = dfs_1HUC8_CO['Shape_Leng']
dfs_2HUC8_CO['Shape_Area'] = dfs_1HUC8_CO['Shape_Area']
dfs_2HUC8_CO['geometry'] = dfs_1HUC8_CO['geometry']

# view output
dfs_2HUC8_CO.head(3)
# Out:
#    OBJECTID    Shape  UnitID UnitUUID NativeID Name TypeCV StateCV  \
# 0         0  Polygon     NaN               NaN  NaN    NaN     NaN
# 1         1  Polygon     NaN               NaN  NaN    NaN     NaN
# 2         2  Polygon     NaN               NaN  NaN    NaN     NaN
#
#    Shape_Length  Shape_Area                                           geometry
# 0      3.943636    0.450856  POLYGON ((-104.18034 36.92065, -104.18082 36.9...
# 1      3.006890    0.273469  POLYGON ((-104.49909 36.32423, -104.49957 36.3...
# 2      6.201702    0.531733  POLYGON ((-104.21278 35.94052, -104.21295 35.9...

# %%
# Merge dataframes
frames = [dfs_2HUC8_UT, dfs_2HUC8_CO]
outdf = pd.concat(frames)
outdf.head(3)
# Out:
#    OBJECTID    Shape  UnitID UnitUUID NativeID Name TypeCV StateCV  \
# 0         0  Polygon     NaN               NaN  NaN    NaN     NaN
# 1         1  Polygon     NaN               NaN  NaN    NaN     NaN
# 2         2  Polygon     NaN               NaN  NaN    NaN     NaN
#
#    Shape_Length  Shape_Area                                           geometry
# 0      3.943636    0.450856  POLYGON ((-104.18034 36.92065, -104.18082 36.9...
# 1      3.006890    0.273469  POLYGON ((-104.49909 36.32423, -104.49957 36.3...
# 2      6.201702    0.531733  POLYGON ((-104.21278 35.94052, -104.21295 35.9...

# %%
# drop NA rows
outdf = outdf.dropna(subset=['UnitID'])
outdf
# Out:
#       OBJECTID    Shape   UnitID   UnitUUID  NativeID  \
# 59          59  Polygon  24172.0  UTag_RU45  15010010
# 97          97  Polygon  24167.0  UTag_RU40  15010009
# 228        228  Polygon  24169.0  UTag_RU42  14070007
# 229        229  Polygon  24170.0  UTag_RU43  14080201
# 231        231  Polygon  24184.0  UTag_RU57  15010003
# ...        ...      ...      ...        ...       ...
# 2034      2034  Polygon  20881.0  COag_RU34  11020009
# 2037      2037  Polygon  20884.0  COag_RU37  14020002
# 2038      2038  Polygon  20878.0  COag_RU31  14020003
# 2039      2039  Polygon  20862.0  COag_RU15  14020005
# 2040      2040  Polygon  20879.0  COag_RU32  14020006
#
#                                       Name TypeCV StateCV  Shape_Length  \
# 59                            Lower Virgin   HUC8      UT      4.699079
# 97                        Fort Pearce Wash   HUC8      UT      3.953473
# 228                                  Paria   HUC8      UT      3.844277
# 229            Lower San Juan-Four Corners   HUC8      UT      4.895612
# 231                                  Kanab   HUC8      UT      4.286003
# ...                                    ...    ...     ...           ...
# 2034  Upper Arkansas-John Martin Reservoir   HUC8      CO      7.004299
# 2037                        Upper Gunnison   HUC8      CO      5.238936
# 2038                               Tomichi   HUC8      CO      3.160962
# 2039                        Lower Gunnison   HUC8      CO      4.109297
# 2040                           Uncompahgre   HUC8      CO      3.436065
#
#       Shape_Area                                           geometry
# 59      0.540441  POLYGON ((-114.06750 37.60696, -114.06708 37.6...
# 97      0.436551  POLYGON ((-112.75584 37.06340, -112.75670 37.0...
# 228     0.373255  POLYGON ((-112.03395 37.73733, -112.03393 37.7...
# 229     0.524993  POLYGON ((-109.47444 37.84105, -109.47411 37.8...
# 231     0.618366  POLYGON ((-112.38286 37.49863, -112.38270 37.4...
# ...          ...                                                ...
# 2034    1.026645  POLYGON ((-103.63509 38.80092, -103.63364 38.8...
# 2037    0.643883  POLYGON ((-107.03062 38.83861, -107.03026 38.8...
# 2038    0.294426  POLYGON ((-106.56505 38.69850, -106.56484 38.6...
# 2039    0.446387  POLYGON ((-107.85652 39.07754, -107.85617 39.0...
# 2040    0.297415  POLYGON ((-108.07215 38.74298, -108.07055 38.7...
#
# [98 rows x 11 columns]

# %%
# Export the dataframe to a shapefile.
# Note: rememeber that shapefiles autofil in fields names, will need to fix field names in app upload.
dfsOut = gpd.GeoDataFrame(outdf,  crs="EPSG:4326", geometry='geometry') # covert to geodataframe
dfsOut.to_file("Processed_Shapefiles/P_WaDEHUC8.shp") # export shape file
